# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2021/22 (6 CFU) - Dr. Alberto Testolin, Dr. Umberto Michieli
# ---
#
#
# ## Supplementary  material - Neural network manual implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Theoretical Background

# %% [markdown]
# ### Artificial Neuron

# %% [markdown]
# This is the structure of a single artificial neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Fully connected feed-forward network

# %% [markdown]
# A neural network is composed by several artificial neurons, typically organized in layers and connected in different ways. One of the most common neural network is the **fully-connected feed-forward network**, where each neuron is connected to all the neurons of the previous layer. The first layer takes the feature vector as input, and the number of outputs is defined by the number of neurons in the last layer.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# All the linear computation of a single layer (without considering the activation function) can be simply expressed in a matrix form, as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When we include the activation function and we consider more than one layer (2 hidden layers in this example) we still have a quite simple expression for the entire network. $X$ is the input vector, $H_n$ are the linear activations, $Z_n$ are the non-linear activations, and $Y$ is the output.
#
# The computation of this equation is typically referred to as *forward-pass*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# When we use a neural network for a regression or classification problem, we compare the output the network with the actual values given by a training set.
#
# This comparison is quantified by a **loss function**. In this case we consider a Mean Square Error (MSE) function, analogously to the least square problem analyzed in the previous lab.
#
# The main goal is to find a set of parameters $W$ that minimizes the loss function. The rationale behind the **gradient descent** algorithm is to slighlty update the values of the weights depending on their gradient wrt the loss function. The update is repeated until we reach a stopping criteria, e.g. the training loss is not decreasing anymore, or the loss function evaluated on the validation set (**validation loss**) starts to increase (**overfitting**).
#
# It is clear that the main point here is to evaluate the gradient of the weights wrt the loss function. Starting from the output layer, and thanks to the **chain rule**, we can easily leverage previously evaluated gradients to simplify the computation (**back-propagation**).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you apply the chain rule, as you cas see below, most of the computation is shared among the layers.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Doing the math, you have the following gradients. We define the variables $D_n$ to have a reference for the code below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Activation Functions

# %% [markdown]
# There are several non-linear activation function that can be used, each of which has specific properties and tackles specific issues. Here some examples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Generate training and test data

# %% [markdown]
# Let's define the same model used for the OLS implementation of the previous labs.

# %%
# Set random seed
np.random.seed(3)

### Define a simple quadratic model
# y = a + b * x + c * x^2
# a = -1.45, b = 1.12, c = 2.3

def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise
    
### True parameter values
beta_true = [-1.45, 1.12, 2.3]

### Set random seed
np.random.seed(3)

### Generate 10 train points
num_train_points = 10
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std=0.2)

### Generate 10 test points
num_test_points = 10
x_test = np.random.rand(num_test_points)
y_test = poly_model(x_test, beta_true, noise_std=0.2)

### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_test, y_test, color='g', ls='', marker='.', label='Test data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Activation function

# %% [markdown]
# Let's define the activation function *act* and its dervivative *act_der*. We consider a **sigmoid** activation function, which is available in the *scipy* python package in the *scipy.special* module named as *expit*.
#
# Fortunately, the derivative of the sigmoid $\sigma(x)$ is quite simple:
#
# $$
# \sigma(x) = \frac{1}{1+e^{-x}}\\
# \frac{d\sigma}{dx} = \sigma(x) * (1 - \sigma(x))
# $$

# %%
# Define activation function
from scipy.special import expit
act = expit
# 1st derivative
act_der = lambda x: act(x) * (1 - act(x))

# Plot activation function
x_plot = np.linspace(-5,5,1000)
y_act = act(x_plot)
y_act_der = act_der(x_plot)

plt.figure(figsize=(16,10))
plt.plot(x_plot, y_act, label='Sigmoid function')
plt.plot(x_plot, y_act_der, label='Sigmoid 1st derivative')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Network definition

# %% [markdown]
# Let's define the entire network using a class. We are implementing a fully connected feed-forward network with 2 hidden layers. The class has the following structure:
# ```
# class Network():
#
#     def __init__(self, Ni, Nh1, Nh2, No):
#         [...]
#
#     def forward(self, x, additional_out=False):
#         [...]
#
#     def update(self, x, label, lr):
#         [...]
#
#     def plot_weights(self):
#         [...]
#
# ```
#
#
# *   **\_\_init\_\_ method** - Here we initialize all the parameters (weights and biases) of the network. It requires the number of inputs ($N_i$) and outputs ($N_o$) and the number of neurons in the hidden layers ($N_h1$ and $N_h2$). The weights are initialized randomly, following the procedure proposed by Xavier et al. The biases are initialized to zero.
# *   **forward** - Evaluate the output of the network given an input $x$. If the *additional_out* parameter is True, it also outputs the activations of the secon hidden layer $Z_2$, for visualization.
# * **update** - Given a training sample (*x* and *label*), evaluate all the gradients and perform the update of the weigths with a learning rate *lr*.
# * **plot_weights** - Utility function to plot all the weights of the network.

# %%
class Network():
    
    def __init__(self, Ni, Nh1, Nh2, No):
            
        ### WEIGHT INITIALIZATION (Xavier)
        # Initialize hidden weights and biases (layer 1)
        Wh1 = (np.random.rand(Nh1, Ni) - 0.5) * np.sqrt(12 / (Nh1 + Ni))
        Bh1 = np.zeros([Nh1, 1])
        self.WBh1 = np.concatenate([Wh1, Bh1], 1) # Weight matrix including biases
        # Initialize hidden weights and biases (layer 2)
        Wh2 = (np.random.rand(Nh2, Nh1) - 0.5) * np.sqrt(12 / (Nh2 + Nh1))
        Bh2 = np.zeros([Nh2, 1])
        self.WBh2 = np.concatenate([Wh2, Bh2], 1) # Weight matrix including biases
        # Initialize output weights and biases
        Wo = (np.random.rand(No, Nh2) - 0.5) * np.sqrt(12 / (No + Nh2))
        Bo = np.zeros([No, 1])
        self.WBo = np.concatenate([Wo, Bo], 1) # Weight matrix including biases
        
        ### ACTIVATION FUNCTION
        self.act = expit
        self.act_der = lambda x: act(x) * (1 - act(x))
        
    def forward(self, x, additional_out=False):
        
        # Convert to numpy array
        x = np.array(x)
        
        ### Hidden layer 1
        # Add bias term
        X = np.append(x, 1)
        # Forward pass (linear)
        H1 = np.matmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)
        
        ### Hidden layer 2
        # Add bias term
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = np.matmul(self.WBh2, Z1)
        # Activation function
        Z2 = self.act(H2)
        
        ### Output layer
        # Add bias term
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = np.matmul(self.WBo, Z2)
        # NO activation function
        
        if additional_out:
            return Y.squeeze(), Z2
        
        return Y.squeeze()
        
    def update(self, x, label, lr):
        
        # Convert to numpy array
        X = np.array(x)
        
        ### Hidden layer 1
        # Add bias term
        X = np.append(X, 1)
        # Forward pass (linear)
        H1 = np.matmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)
        
        ### Hidden layer 2
        # Add bias term
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = np.matmul(self.WBh2, Z1)
        # Activation function
        Z2 = self.act(H2)
        
        ### Output layer
        # Add bias term
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = np.matmul(self.WBo, Z2)
        # NO activation function
        
        # Evaluate the derivative terms
        D1 = Y - label
        D2 = Z2
        D3 = self.WBo[:,:-1]
        D4 = self.act_der(H2)
        D5 = Z1
        D6 = self.WBh2[:,:-1]
        D7 = self.act_der(H1)
        D8 = X
        
        # Layer Error
        Eo = D1
        Eh2 = np.matmul(Eo, D3) * D4
        Eh1 = np.matmul(Eh2, D6) * D7
        
        
        # Derivative for weight matrices
        dWBo = np.matmul(Eo.reshape(-1,1), D2.reshape(1,-1))
        dWBh2 = np.matmul(Eh2.reshape(-1,1), D5.reshape(1,-1))
        dWBh1 = np.matmul(Eh1.reshape(-1,1), D8.reshape(1,-1))
        
        # Update the weights
        self.WBh1 -= lr * dWBh1
        self.WBh2 -= lr * dWBh2
        self.WBo -= lr * dWBo
        
        # Evaluate loss function
        loss = (Y - label)**2/2
        
        return loss
    
    def plot_weights(self):
    
        fig, axs = plt.subplots(3, 1, figsize=(12,6))
        axs[0].hist(self.WBh1.flatten(), 20)
        axs[1].hist(self.WBh2.flatten(), 50)
        axs[2].hist(self.WBo.flatten(), 20)
        plt.legend()
        plt.grid()
        plt.show()

# %% [markdown]
# Now we can instantiate the actual object.

# %%
### PARAMETERS
Ni = 1 # Number of inputs
Nh1 = 128 # Number of hidden neurons (layer 1)
Nh2 = 512 # Number of hidden neurons (layer 2)
No = 1 # Number of outputs

### Initialize network
net = Network(Ni, Nh1, Nh2, No)

# Access the class members
print('1st hidden layer weigth matrix shape:', net.WBh1.shape)
print('2nd hidden layer weigth matrix shape:', net.WBh2.shape)
print('Output layer weigth matrix shape:', net.WBo.shape)

# Plot weights
plt.close('all')
net.plot_weights()
# Out:
# No handles with labels found to put in legend.
# 1st hidden layer weigth matrix shape: (128, 2)
# 2nd hidden layer weigth matrix shape: (512, 129)
# Output layer weigth matrix shape: (1, 513)

# %% [markdown]
# Let's check what is the output of the network just initialized, without having performed any training step.

# %%
### FORWARD PASS (before training)
# Define the x vector
x_highres = np.linspace(0, 1, 1000)

# Evaluate the output for each input (this can be done as a batch, but for now let's do 1 input at a time)
initial_net_output = []
for x in x_highres:
    net_out = net.forward(x)
    initial_net_output.append(net_out)
initial_net_output = np.array(initial_net_output)
    
# Or in just 1 line of pythonic code!!
initial_net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, initial_net_output, color='g', ls='--', label='Network output (random weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the output is just a random value. Let's train this network.

# %% [markdown]
# # Network training

# %% [markdown]
# Here, a **learning rate decay** can be optionally enabled, which decrease the learning rate from *lr* to *lr_final* during the training.

# %%
#%% TRAINING
num_epochs = 5000
lr = 1e-2
en_decay = False
lr_final = 1e-5
lr_decay = (lr_final / lr)**(1 / num_epochs)

train_loss_log = []
test_loss_log = []
for num_ep in range(num_epochs):
    # Learning rate decay
    if en_decay:
        lr *= lr_decay
    # Train single epoch (sample by sample, no batch for now)
    train_loss_vec = [net.update(x, y, lr) for x, y in zip(x_train, y_train)]
    avg_train_loss = np.mean(train_loss_vec)
    # Test network
    y_test_est = np.array([net.forward(x) for x in x_test])
    avg_test_loss = np.mean((y_test_est - y_test)**2/2)
    # Log
    train_loss_log.append(avg_train_loss)
    test_loss_log.append(avg_test_loss)
    print('Epoch %d - lr: %.5f - Train loss: %.5f - Test loss: %.5f' % (num_ep + 1, lr, avg_train_loss, avg_test_loss))
# Out:
# Epoch 1 - lr: 0.01000 - Train loss: 0.95905 - Test loss: 0.40116
# Epoch 2 - lr: 0.01000 - Train loss: 0.91071 - Test loss: 0.40216
# Epoch 3 - lr: 0.01000 - Train loss: 0.90819 - Test loss: 0.40318
# Epoch 4 - lr: 0.01000 - Train loss: 0.90575 - Test loss: 0.40421
# Epoch 5 - lr: 0.01000 - Train loss: 0.90341 - Test loss: 0.40525
# Epoch 6 - lr: 0.01000 - Train loss: 0.90115 - Test loss: 0.40630
# Epoch 7 - lr: 0.01000 - Train loss: 0.89897 - Test loss: 0.40736
# Epoch 8 - lr: 0.01000 - Train loss: 0.89687 - Test loss: 0.40842
# Epoch 9 - lr: 0.01000 - Train loss: 0.89484 - Test loss: 0.40950
# Epoch 10 - lr: 0.01000 - Train loss: 0.89288 - Test loss: 0.41058
# Epoch 11 - lr: 0.01000 - Train loss: 0.89099 - Test loss: 0.41166
# Epoch 12 - lr: 0.01000 - Train loss: 0.88916 - Test loss: 0.41275
# Epoch 13 - lr: 0.01000 - Train loss: 0.88740 - Test loss: 0.41384
# Epoch 14 - lr: 0.01000 - Train loss: 0.88570 - Test loss: 0.41493
# Epoch 15 - lr: 0.01000 - Train loss: 0.88405 - Test loss: 0.41603
# Epoch 16 - lr: 0.01000 - Train loss: 0.88246 - Test loss: 0.41713
# Epoch 17 - lr: 0.01000 - Train loss: 0.88092 - Test loss: 0.41823
# Epoch 18 - lr: 0.01000 - Train loss: 0.87943 - Test loss: 0.41933
# Epoch 19 - lr: 0.01000 - Train loss: 0.87799 - Test loss: 0.42043
# Epoch 20 - lr: 0.01000 - Train loss: 0.87660 - Test loss: 0.42153
# Epoch 21 - lr: 0.01000 - Train loss: 0.87526 - Test loss: 0.42262
# Epoch 22 - lr: 0.01000 - Train loss: 0.87395 - Test loss: 0.42372
# Epoch 23 - lr: 0.01000 - Train loss: 0.87269 - Test loss: 0.42482
# Epoch 24 - lr: 0.01000 - Train loss: 0.87147 - Test loss: 0.42591
# Epoch 25 - lr: 0.01000 - Train loss: 0.87028 - Test loss: 0.42701
# Epoch 26 - lr: 0.01000 - Train loss: 0.86914 - Test loss: 0.42810
# Epoch 27 - lr: 0.01000 - Train loss: 0.86803 - Test loss: 0.42919
# Epoch 28 - lr: 0.01000 - Train loss: 0.86695 - Test loss: 0.43028
# Epoch 29 - lr: 0.01000 - Train loss: 0.86591 - Test loss: 0.43137
# Epoch 30 - lr: 0.01000 - Train loss: 0.86490 - Test loss: 0.43245
# Epoch 31 - lr: 0.01000 - Train loss: 0.86392 - Test loss: 0.43353
# Epoch 32 - lr: 0.01000 - Train loss: 0.86297 - Test loss: 0.43461
# Epoch 33 - lr: 0.01000 - Train loss: 0.86204 - Test loss: 0.43569
# Epoch 34 - lr: 0.01000 - Train loss: 0.86115 - Test loss: 0.43676
# Epoch 35 - lr: 0.01000 - Train loss: 0.86028 - Test loss: 0.43784
# Epoch 36 - lr: 0.01000 - Train loss: 0.85944 - Test loss: 0.43890
# Epoch 37 - lr: 0.01000 - Train loss: 0.85862 - Test loss: 0.43997
# Epoch 38 - lr: 0.01000 - Train loss: 0.85783 - Test loss: 0.44104
# Epoch 39 - lr: 0.01000 - Train loss: 0.85706 - Test loss: 0.44210
# Epoch 40 - lr: 0.01000 - Train loss: 0.85631 - Test loss: 0.44316
# Epoch 41 - lr: 0.01000 - Train loss: 0.85558 - Test loss: 0.44421
# Epoch 42 - lr: 0.01000 - Train loss: 0.85487 - Test loss: 0.44527
# Epoch 43 - lr: 0.01000 - Train loss: 0.85418 - Test loss: 0.44632
# Epoch 44 - lr: 0.01000 - Train loss: 0.85352 - Test loss: 0.44737
# Epoch 45 - lr: 0.01000 - Train loss: 0.85287 - Test loss: 0.44841
# Epoch 46 - lr: 0.01000 - Train loss: 0.85224 - Test loss: 0.44946
# Epoch 47 - lr: 0.01000 - Train loss: 0.85162 - Test loss: 0.45050
# Epoch 48 - lr: 0.01000 - Train loss: 0.85102 - Test loss: 0.45154
# Epoch 49 - lr: 0.01000 - Train loss: 0.85044 - Test loss: 0.45257
# Epoch 50 - lr: 0.01000 - Train loss: 0.84988 - Test loss: 0.45361
# Epoch 51 - lr: 0.01000 - Train loss: 0.84932 - Test loss: 0.45464
# Epoch 52 - lr: 0.01000 - Train loss: 0.84879 - Test loss: 0.45567
# Epoch 53 - lr: 0.01000 - Train loss: 0.84827 - Test loss: 0.45670
# Epoch 54 - lr: 0.01000 - Train loss: 0.84776 - Test loss: 0.45772
# Epoch 55 - lr: 0.01000 - Train loss: 0.84726 - Test loss: 0.45874
# Epoch 56 - lr: 0.01000 - Train loss: 0.84678 - Test loss: 0.45977
# Epoch 57 - lr: 0.01000 - Train loss: 0.84630 - Test loss: 0.46078
# Epoch 58 - lr: 0.01000 - Train loss: 0.84584 - Test loss: 0.46180
# Epoch 59 - lr: 0.01000 - Train loss: 0.84540 - Test loss: 0.46281
# Epoch 60 - lr: 0.01000 - Train loss: 0.84496 - Test loss: 0.46383
# Epoch 61 - lr: 0.01000 - Train loss: 0.84453 - Test loss: 0.46484
# Epoch 62 - lr: 0.01000 - Train loss: 0.84411 - Test loss: 0.46584
# Epoch 63 - lr: 0.01000 - Train loss: 0.84371 - Test loss: 0.46685
# Epoch 64 - lr: 0.01000 - Train loss: 0.84331 - Test loss: 0.46785
# Epoch 65 - lr: 0.01000 - Train loss: 0.84292 - Test loss: 0.46886
# Epoch 66 - lr: 0.01000 - Train loss: 0.84254 - Test loss: 0.46986
# Epoch 67 - lr: 0.01000 - Train loss: 0.84217 - Test loss: 0.47085
# Epoch 68 - lr: 0.01000 - Train loss: 0.84181 - Test loss: 0.47185
# Epoch 69 - lr: 0.01000 - Train loss: 0.84145 - Test loss: 0.47284
# Epoch 70 - lr: 0.01000 - Train loss: 0.84110 - Test loss: 0.47384
# Epoch 71 - lr: 0.01000 - Train loss: 0.84076 - Test loss: 0.47483
# Epoch 72 - lr: 0.01000 - Train loss: 0.84043 - Test loss: 0.47581
# Epoch 73 - lr: 0.01000 - Train loss: 0.84010 - Test loss: 0.47680
# Epoch 74 - lr: 0.01000 - Train loss: 0.83979 - Test loss: 0.47778
# Epoch 75 - lr: 0.01000 - Train loss: 0.83947 - Test loss: 0.47877
# Epoch 76 - lr: 0.01000 - Train loss: 0.83916 - Test loss: 0.47975
# Epoch 77 - lr: 0.01000 - Train loss: 0.83886 - Test loss: 0.48072
# Epoch 78 - lr: 0.01000 - Train loss: 0.83857 - Test loss: 0.48170
# Epoch 79 - lr: 0.01000 - Train loss: 0.83828 - Test loss: 0.48267
# Epoch 80 - lr: 0.01000 - Train loss: 0.83799 - Test loss: 0.48364
# Epoch 81 - lr: 0.01000 - Train loss: 0.83771 - Test loss: 0.48461
# Epoch 82 - lr: 0.01000 - Train loss: 0.83744 - Test loss: 0.48558
# Epoch 83 - lr: 0.01000 - Train loss: 0.83717 - Test loss: 0.48655
# Epoch 84 - lr: 0.01000 - Train loss: 0.83690 - Test loss: 0.48751
# Epoch 85 - lr: 0.01000 - Train loss: 0.83664 - Test loss: 0.48847
# Epoch 86 - lr: 0.01000 - Train loss: 0.83638 - Test loss: 0.48943
# Epoch 87 - lr: 0.01000 - Train loss: 0.83613 - Test loss: 0.49038
# Epoch 88 - lr: 0.01000 - Train loss: 0.83588 - Test loss: 0.49133
# Epoch 89 - lr: 0.01000 - Train loss: 0.83564 - Test loss: 0.49228
# Epoch 90 - lr: 0.01000 - Train loss: 0.83539 - Test loss: 0.49323
# Epoch 91 - lr: 0.01000 - Train loss: 0.83515 - Test loss: 0.49417
# Epoch 92 - lr: 0.01000 - Train loss: 0.83492 - Test loss: 0.49512
# Epoch 93 - lr: 0.01000 - Train loss: 0.83469 - Test loss: 0.49606
# Epoch 94 - lr: 0.01000 - Train loss: 0.83446 - Test loss: 0.49699
# Epoch 95 - lr: 0.01000 - Train loss: 0.83423 - Test loss: 0.49793
# Epoch 96 - lr: 0.01000 - Train loss: 0.83401 - Test loss: 0.49886
# Epoch 97 - lr: 0.01000 - Train loss: 0.83379 - Test loss: 0.49978
# Epoch 98 - lr: 0.01000 - Train loss: 0.83357 - Test loss: 0.50071
# Epoch 99 - lr: 0.01000 - Train loss: 0.83335 - Test loss: 0.50163
# Epoch 100 - lr: 0.01000 - Train loss: 0.83314 - Test loss: 0.50255
# Epoch 101 - lr: 0.01000 - Train loss: 0.83293 - Test loss: 0.50346
# Epoch 102 - lr: 0.01000 - Train loss: 0.83272 - Test loss: 0.50437
# Epoch 103 - lr: 0.01000 - Train loss: 0.83251 - Test loss: 0.50528
# Epoch 104 - lr: 0.01000 - Train loss: 0.83230 - Test loss: 0.50618
# Epoch 105 - lr: 0.01000 - Train loss: 0.83210 - Test loss: 0.50708
# Epoch 106 - lr: 0.01000 - Train loss: 0.83190 - Test loss: 0.50798
# Epoch 107 - lr: 0.01000 - Train loss: 0.83170 - Test loss: 0.50887
# Epoch 108 - lr: 0.01000 - Train loss: 0.83150 - Test loss: 0.50976
# Epoch 109 - lr: 0.01000 - Train loss: 0.83130 - Test loss: 0.51064
# Epoch 110 - lr: 0.01000 - Train loss: 0.83110 - Test loss: 0.51152
# Epoch 111 - lr: 0.01000 - Train loss: 0.83091 - Test loss: 0.51240
# Epoch 112 - lr: 0.01000 - Train loss: 0.83072 - Test loss: 0.51327
# Epoch 113 - lr: 0.01000 - Train loss: 0.83052 - Test loss: 0.51413
# Epoch 114 - lr: 0.01000 - Train loss: 0.83033 - Test loss: 0.51500
# Epoch 115 - lr: 0.01000 - Train loss: 0.83014 - Test loss: 0.51585
# Epoch 116 - lr: 0.01000 - Train loss: 0.82995 - Test loss: 0.51671
# Epoch 117 - lr: 0.01000 - Train loss: 0.82976 - Test loss: 0.51756
# Epoch 118 - lr: 0.01000 - Train loss: 0.82958 - Test loss: 0.51840
# Epoch 119 - lr: 0.01000 - Train loss: 0.82939 - Test loss: 0.51924
# Epoch 120 - lr: 0.01000 - Train loss: 0.82920 - Test loss: 0.52007
# Epoch 121 - lr: 0.01000 - Train loss: 0.82902 - Test loss: 0.52090
# Epoch 122 - lr: 0.01000 - Train loss: 0.82883 - Test loss: 0.52172
# Epoch 123 - lr: 0.01000 - Train loss: 0.82865 - Test loss: 0.52254
# Epoch 124 - lr: 0.01000 - Train loss: 0.82847 - Test loss: 0.52335
# Epoch 125 - lr: 0.01000 - Train loss: 0.82828 - Test loss: 0.52416
# Epoch 126 - lr: 0.01000 - Train loss: 0.82810 - Test loss: 0.52496
# Epoch 127 - lr: 0.01000 - Train loss: 0.82792 - Test loss: 0.52575
# Epoch 128 - lr: 0.01000 - Train loss: 0.82774 - Test loss: 0.52654
# Epoch 129 - lr: 0.01000 - Train loss: 0.82756 - Test loss: 0.52733
# Epoch 130 - lr: 0.01000 - Train loss: 0.82737 - Test loss: 0.52810
# Epoch 131 - lr: 0.01000 - Train loss: 0.82719 - Test loss: 0.52888
# Epoch 132 - lr: 0.01000 - Train loss: 0.82701 - Test loss: 0.52964
# Epoch 133 - lr: 0.01000 - Train loss: 0.82683 - Test loss: 0.53040
# Epoch 134 - lr: 0.01000 - Train loss: 0.82665 - Test loss: 0.53115
# Epoch 135 - lr: 0.01000 - Train loss: 0.82647 - Test loss: 0.53190
# Epoch 136 - lr: 0.01000 - Train loss: 0.82629 - Test loss: 0.53264
# Epoch 137 - lr: 0.01000 - Train loss: 0.82611 - Test loss: 0.53337
# Epoch 138 - lr: 0.01000 - Train loss: 0.82593 - Test loss: 0.53410
# Epoch 139 - lr: 0.01000 - Train loss: 0.82575 - Test loss: 0.53482
# Epoch 140 - lr: 0.01000 - Train loss: 0.82557 - Test loss: 0.53553
# Epoch 141 - lr: 0.01000 - Train loss: 0.82539 - Test loss: 0.53624
# Epoch 142 - lr: 0.01000 - Train loss: 0.82521 - Test loss: 0.53694
# Epoch 143 - lr: 0.01000 - Train loss: 0.82503 - Test loss: 0.53763
# Epoch 144 - lr: 0.01000 - Train loss: 0.82485 - Test loss: 0.53831
# Epoch 145 - lr: 0.01000 - Train loss: 0.82467 - Test loss: 0.53899
# Epoch 146 - lr: 0.01000 - Train loss: 0.82449 - Test loss: 0.53966
# Epoch 147 - lr: 0.01000 - Train loss: 0.82431 - Test loss: 0.54032
# Epoch 148 - lr: 0.01000 - Train loss: 0.82412 - Test loss: 0.54098
# Epoch 149 - lr: 0.01000 - Train loss: 0.82394 - Test loss: 0.54162
# Epoch 150 - lr: 0.01000 - Train loss: 0.82376 - Test loss: 0.54226
# Epoch 151 - lr: 0.01000 - Train loss: 0.82358 - Test loss: 0.54290
# Epoch 152 - lr: 0.01000 - Train loss: 0.82340 - Test loss: 0.54352
# Epoch 153 - lr: 0.01000 - Train loss: 0.82321 - Test loss: 0.54414
# Epoch 154 - lr: 0.01000 - Train loss: 0.82303 - Test loss: 0.54475
# Epoch 155 - lr: 0.01000 - Train loss: 0.82285 - Test loss: 0.54535
# Epoch 156 - lr: 0.01000 - Train loss: 0.82266 - Test loss: 0.54594
# Epoch 157 - lr: 0.01000 - Train loss: 0.82248 - Test loss: 0.54653
# Epoch 158 - lr: 0.01000 - Train loss: 0.82230 - Test loss: 0.54710
# Epoch 159 - lr: 0.01000 - Train loss: 0.82211 - Test loss: 0.54767
# Epoch 160 - lr: 0.01000 - Train loss: 0.82193 - Test loss: 0.54823
# Epoch 161 - lr: 0.01000 - Train loss: 0.82174 - Test loss: 0.54879
# Epoch 162 - lr: 0.01000 - Train loss: 0.82155 - Test loss: 0.54933
# Epoch 163 - lr: 0.01000 - Train loss: 0.82137 - Test loss: 0.54987
# Epoch 164 - lr: 0.01000 - Train loss: 0.82118 - Test loss: 0.55039
# Epoch 165 - lr: 0.01000 - Train loss: 0.82099 - Test loss: 0.55091
# Epoch 166 - lr: 0.01000 - Train loss: 0.82081 - Test loss: 0.55142
# Epoch 167 - lr: 0.01000 - Train loss: 0.82062 - Test loss: 0.55192
# Epoch 168 - lr: 0.01000 - Train loss: 0.82043 - Test loss: 0.55242
# Epoch 169 - lr: 0.01000 - Train loss: 0.82024 - Test loss: 0.55290
# Epoch 170 - lr: 0.01000 - Train loss: 0.82005 - Test loss: 0.55338
# Epoch 171 - lr: 0.01000 - Train loss: 0.81986 - Test loss: 0.55385
# Epoch 172 - lr: 0.01000 - Train loss: 0.81967 - Test loss: 0.55431
# Epoch 173 - lr: 0.01000 - Train loss: 0.81948 - Test loss: 0.55476
# Epoch 174 - lr: 0.01000 - Train loss: 0.81929 - Test loss: 0.55520
# Epoch 175 - lr: 0.01000 - Train loss: 0.81910 - Test loss: 0.55563
# Epoch 176 - lr: 0.01000 - Train loss: 0.81891 - Test loss: 0.55605
# Epoch 177 - lr: 0.01000 - Train loss: 0.81871 - Test loss: 0.55647
# Epoch 178 - lr: 0.01000 - Train loss: 0.81852 - Test loss: 0.55688
# Epoch 179 - lr: 0.01000 - Train loss: 0.81833 - Test loss: 0.55727
# Epoch 180 - lr: 0.01000 - Train loss: 0.81813 - Test loss: 0.55766
# Epoch 181 - lr: 0.01000 - Train loss: 0.81794 - Test loss: 0.55804
# Epoch 182 - lr: 0.01000 - Train loss: 0.81774 - Test loss: 0.55841
# Epoch 183 - lr: 0.01000 - Train loss: 0.81755 - Test loss: 0.55877
# Epoch 184 - lr: 0.01000 - Train loss: 0.81735 - Test loss: 0.55913
# Epoch 185 - lr: 0.01000 - Train loss: 0.81715 - Test loss: 0.55947
# Epoch 186 - lr: 0.01000 - Train loss: 0.81695 - Test loss: 0.55981
# Epoch 187 - lr: 0.01000 - Train loss: 0.81676 - Test loss: 0.56013
# Epoch 188 - lr: 0.01000 - Train loss: 0.81656 - Test loss: 0.56045
# Epoch 189 - lr: 0.01000 - Train loss: 0.81636 - Test loss: 0.56076
# Epoch 190 - lr: 0.01000 - Train loss: 0.81616 - Test loss: 0.56106
# Epoch 191 - lr: 0.01000 - Train loss: 0.81596 - Test loss: 0.56135
# Epoch 192 - lr: 0.01000 - Train loss: 0.81576 - Test loss: 0.56163
# Epoch 193 - lr: 0.01000 - Train loss: 0.81556 - Test loss: 0.56190
# Epoch 194 - lr: 0.01000 - Train loss: 0.81536 - Test loss: 0.56217
# Epoch 195 - lr: 0.01000 - Train loss: 0.81516 - Test loss: 0.56242
# Epoch 196 - lr: 0.01000 - Train loss: 0.81495 - Test loss: 0.56267
# Epoch 197 - lr: 0.01000 - Train loss: 0.81475 - Test loss: 0.56291
# Epoch 198 - lr: 0.01000 - Train loss: 0.81455 - Test loss: 0.56314
# Epoch 199 - lr: 0.01000 - Train loss: 0.81434 - Test loss: 0.56336
# Epoch 200 - lr: 0.01000 - Train loss: 0.81414 - Test loss: 0.56357
# Epoch 201 - lr: 0.01000 - Train loss: 0.81393 - Test loss: 0.56377
# Epoch 202 - lr: 0.01000 - Train loss: 0.81373 - Test loss: 0.56396
# Epoch 203 - lr: 0.01000 - Train loss: 0.81352 - Test loss: 0.56415
# Epoch 204 - lr: 0.01000 - Train loss: 0.81331 - Test loss: 0.56432
# Epoch 205 - lr: 0.01000 - Train loss: 0.81311 - Test loss: 0.56449
# Epoch 206 - lr: 0.01000 - Train loss: 0.81290 - Test loss: 0.56465
# Epoch 207 - lr: 0.01000 - Train loss: 0.81269 - Test loss: 0.56480
# Epoch 208 - lr: 0.01000 - Train loss: 0.81248 - Test loss: 0.56494
# Epoch 209 - lr: 0.01000 - Train loss: 0.81227 - Test loss: 0.56507
# Epoch 210 - lr: 0.01000 - Train loss: 0.81206 - Test loss: 0.56520
# Epoch 211 - lr: 0.01000 - Train loss: 0.81185 - Test loss: 0.56531
# Epoch 212 - lr: 0.01000 - Train loss: 0.81164 - Test loss: 0.56542
# Epoch 213 - lr: 0.01000 - Train loss: 0.81143 - Test loss: 0.56552
# Epoch 214 - lr: 0.01000 - Train loss: 0.81122 - Test loss: 0.56561
# Epoch 215 - lr: 0.01000 - Train loss: 0.81100 - Test loss: 0.56569
# Epoch 216 - lr: 0.01000 - Train loss: 0.81079 - Test loss: 0.56577
# Epoch 217 - lr: 0.01000 - Train loss: 0.81058 - Test loss: 0.56583
# Epoch 218 - lr: 0.01000 - Train loss: 0.81036 - Test loss: 0.56589
# Epoch 219 - lr: 0.01000 - Train loss: 0.81015 - Test loss: 0.56594
# Epoch 220 - lr: 0.01000 - Train loss: 0.80993 - Test loss: 0.56598
# Epoch 221 - lr: 0.01000 - Train loss: 0.80972 - Test loss: 0.56601
# Epoch 222 - lr: 0.01000 - Train loss: 0.80950 - Test loss: 0.56604
# Epoch 223 - lr: 0.01000 - Train loss: 0.80929 - Test loss: 0.56605
# Epoch 224 - lr: 0.01000 - Train loss: 0.80907 - Test loss: 0.56606
# Epoch 225 - lr: 0.01000 - Train loss: 0.80885 - Test loss: 0.56606
# Epoch 226 - lr: 0.01000 - Train loss: 0.80863 - Test loss: 0.56606
# Epoch 227 - lr: 0.01000 - Train loss: 0.80841 - Test loss: 0.56604
# Epoch 228 - lr: 0.01000 - Train loss: 0.80820 - Test loss: 0.56602
# Epoch 229 - lr: 0.01000 - Train loss: 0.80798 - Test loss: 0.56599
# Epoch 230 - lr: 0.01000 - Train loss: 0.80776 - Test loss: 0.56595
# Epoch 231 - lr: 0.01000 - Train loss: 0.80754 - Test loss: 0.56590
# Epoch 232 - lr: 0.01000 - Train loss: 0.80731 - Test loss: 0.56585
# Epoch 233 - lr: 0.01000 - Train loss: 0.80709 - Test loss: 0.56579
# Epoch 234 - lr: 0.01000 - Train loss: 0.80687 - Test loss: 0.56572
# Epoch 235 - lr: 0.01000 - Train loss: 0.80665 - Test loss: 0.56565
# Epoch 236 - lr: 0.01000 - Train loss: 0.80643 - Test loss: 0.56556
# Epoch 237 - lr: 0.01000 - Train loss: 0.80620 - Test loss: 0.56547
# Epoch 238 - lr: 0.01000 - Train loss: 0.80598 - Test loss: 0.56538
# Epoch 239 - lr: 0.01000 - Train loss: 0.80575 - Test loss: 0.56527
# Epoch 240 - lr: 0.01000 - Train loss: 0.80553 - Test loss: 0.56516
# Epoch 241 - lr: 0.01000 - Train loss: 0.80530 - Test loss: 0.56504
# Epoch 242 - lr: 0.01000 - Train loss: 0.80508 - Test loss: 0.56491
# Epoch 243 - lr: 0.01000 - Train loss: 0.80485 - Test loss: 0.56478
# Epoch 244 - lr: 0.01000 - Train loss: 0.80462 - Test loss: 0.56464
# Epoch 245 - lr: 0.01000 - Train loss: 0.80440 - Test loss: 0.56450
# Epoch 246 - lr: 0.01000 - Train loss: 0.80417 - Test loss: 0.56434
# Epoch 247 - lr: 0.01000 - Train loss: 0.80394 - Test loss: 0.56418
# Epoch 248 - lr: 0.01000 - Train loss: 0.80371 - Test loss: 0.56402
# Epoch 249 - lr: 0.01000 - Train loss: 0.80348 - Test loss: 0.56384
# Epoch 250 - lr: 0.01000 - Train loss: 0.80325 - Test loss: 0.56366
# Epoch 251 - lr: 0.01000 - Train loss: 0.80302 - Test loss: 0.56348
# Epoch 252 - lr: 0.01000 - Train loss: 0.80279 - Test loss: 0.56328
# Epoch 253 - lr: 0.01000 - Train loss: 0.80256 - Test loss: 0.56308
# Epoch 254 - lr: 0.01000 - Train loss: 0.80233 - Test loss: 0.56288
# Epoch 255 - lr: 0.01000 - Train loss: 0.80210 - Test loss: 0.56267
# Epoch 256 - lr: 0.01000 - Train loss: 0.80186 - Test loss: 0.56245
# Epoch 257 - lr: 0.01000 - Train loss: 0.80163 - Test loss: 0.56223
# Epoch 258 - lr: 0.01000 - Train loss: 0.80140 - Test loss: 0.56200
# Epoch 259 - lr: 0.01000 - Train loss: 0.80116 - Test loss: 0.56176
# Epoch 260 - lr: 0.01000 - Train loss: 0.80093 - Test loss: 0.56152
# Epoch 261 - lr: 0.01000 - Train loss: 0.80069 - Test loss: 0.56127
# Epoch 262 - lr: 0.01000 - Train loss: 0.80046 - Test loss: 0.56102
# Epoch 263 - lr: 0.01000 - Train loss: 0.80022 - Test loss: 0.56076
# Epoch 264 - lr: 0.01000 - Train loss: 0.79999 - Test loss: 0.56050
# Epoch 265 - lr: 0.01000 - Train loss: 0.79975 - Test loss: 0.56023
# Epoch 266 - lr: 0.01000 - Train loss: 0.79951 - Test loss: 0.55995
# Epoch 267 - lr: 0.01000 - Train loss: 0.79927 - Test loss: 0.55967
# Epoch 268 - lr: 0.01000 - Train loss: 0.79903 - Test loss: 0.55939
# Epoch 269 - lr: 0.01000 - Train loss: 0.79880 - Test loss: 0.55910
# Epoch 270 - lr: 0.01000 - Train loss: 0.79856 - Test loss: 0.55880
# Epoch 271 - lr: 0.01000 - Train loss: 0.79832 - Test loss: 0.55850
# Epoch 272 - lr: 0.01000 - Train loss: 0.79808 - Test loss: 0.55819
# Epoch 273 - lr: 0.01000 - Train loss: 0.79784 - Test loss: 0.55788
# Epoch 274 - lr: 0.01000 - Train loss: 0.79759 - Test loss: 0.55756
# Epoch 275 - lr: 0.01000 - Train loss: 0.79735 - Test loss: 0.55724
# Epoch 276 - lr: 0.01000 - Train loss: 0.79711 - Test loss: 0.55692
# Epoch 277 - lr: 0.01000 - Train loss: 0.79687 - Test loss: 0.55659
# Epoch 278 - lr: 0.01000 - Train loss: 0.79662 - Test loss: 0.55625
# Epoch 279 - lr: 0.01000 - Train loss: 0.79638 - Test loss: 0.55591
# Epoch 280 - lr: 0.01000 - Train loss: 0.79614 - Test loss: 0.55557
# Epoch 281 - lr: 0.01000 - Train loss: 0.79589 - Test loss: 0.55522
# Epoch 282 - lr: 0.01000 - Train loss: 0.79565 - Test loss: 0.55486
# Epoch 283 - lr: 0.01000 - Train loss: 0.79540 - Test loss: 0.55450
# Epoch 284 - lr: 0.01000 - Train loss: 0.79515 - Test loss: 0.55414
# Epoch 285 - lr: 0.01000 - Train loss: 0.79491 - Test loss: 0.55378
# Epoch 286 - lr: 0.01000 - Train loss: 0.79466 - Test loss: 0.55340
# Epoch 287 - lr: 0.01000 - Train loss: 0.79441 - Test loss: 0.55303
# Epoch 288 - lr: 0.01000 - Train loss: 0.79416 - Test loss: 0.55265
# Epoch 289 - lr: 0.01000 - Train loss: 0.79392 - Test loss: 0.55227
# Epoch 290 - lr: 0.01000 - Train loss: 0.79367 - Test loss: 0.55188
# Epoch 291 - lr: 0.01000 - Train loss: 0.79342 - Test loss: 0.55149
# Epoch 292 - lr: 0.01000 - Train loss: 0.79317 - Test loss: 0.55109
# Epoch 293 - lr: 0.01000 - Train loss: 0.79292 - Test loss: 0.55070
# Epoch 294 - lr: 0.01000 - Train loss: 0.79267 - Test loss: 0.55029
# Epoch 295 - lr: 0.01000 - Train loss: 0.79241 - Test loss: 0.54989
# Epoch 296 - lr: 0.01000 - Train loss: 0.79216 - Test loss: 0.54948
# Epoch 297 - lr: 0.01000 - Train loss: 0.79191 - Test loss: 0.54907
# Epoch 298 - lr: 0.01000 - Train loss: 0.79166 - Test loss: 0.54865
# Epoch 299 - lr: 0.01000 - Train loss: 0.79140 - Test loss: 0.54823
# Epoch 300 - lr: 0.01000 - Train loss: 0.79115 - Test loss: 0.54781
# Epoch 301 - lr: 0.01000 - Train loss: 0.79089 - Test loss: 0.54738
# Epoch 302 - lr: 0.01000 - Train loss: 0.79064 - Test loss: 0.54695
# Epoch 303 - lr: 0.01000 - Train loss: 0.79038 - Test loss: 0.54652
# Epoch 304 - lr: 0.01000 - Train loss: 0.79013 - Test loss: 0.54608
# Epoch 305 - lr: 0.01000 - Train loss: 0.78987 - Test loss: 0.54564
# Epoch 306 - lr: 0.01000 - Train loss: 0.78961 - Test loss: 0.54520
# Epoch 307 - lr: 0.01000 - Train loss: 0.78935 - Test loss: 0.54476
# Epoch 308 - lr: 0.01000 - Train loss: 0.78910 - Test loss: 0.54431
# Epoch 309 - lr: 0.01000 - Train loss: 0.78884 - Test loss: 0.54386
# Epoch 310 - lr: 0.01000 - Train loss: 0.78858 - Test loss: 0.54341
# Epoch 311 - lr: 0.01000 - Train loss: 0.78832 - Test loss: 0.54295
# Epoch 312 - lr: 0.01000 - Train loss: 0.78806 - Test loss: 0.54249
# Epoch 313 - lr: 0.01000 - Train loss: 0.78780 - Test loss: 0.54203
# Epoch 314 - lr: 0.01000 - Train loss: 0.78754 - Test loss: 0.54157
# Epoch 315 - lr: 0.01000 - Train loss: 0.78727 - Test loss: 0.54110
# Epoch 316 - lr: 0.01000 - Train loss: 0.78701 - Test loss: 0.54063
# Epoch 317 - lr: 0.01000 - Train loss: 0.78675 - Test loss: 0.54016
# Epoch 318 - lr: 0.01000 - Train loss: 0.78648 - Test loss: 0.53969
# Epoch 319 - lr: 0.01000 - Train loss: 0.78622 - Test loss: 0.53921
# Epoch 320 - lr: 0.01000 - Train loss: 0.78596 - Test loss: 0.53873
# Epoch 321 - lr: 0.01000 - Train loss: 0.78569 - Test loss: 0.53825
# Epoch 322 - lr: 0.01000 - Train loss: 0.78542 - Test loss: 0.53777
# Epoch 323 - lr: 0.01000 - Train loss: 0.78516 - Test loss: 0.53729
# Epoch 324 - lr: 0.01000 - Train loss: 0.78489 - Test loss: 0.53680
# Epoch 325 - lr: 0.01000 - Train loss: 0.78462 - Test loss: 0.53631
# Epoch 326 - lr: 0.01000 - Train loss: 0.78436 - Test loss: 0.53582
# Epoch 327 - lr: 0.01000 - Train loss: 0.78409 - Test loss: 0.53533
# Epoch 328 - lr: 0.01000 - Train loss: 0.78382 - Test loss: 0.53483
# Epoch 329 - lr: 0.01000 - Train loss: 0.78355 - Test loss: 0.53434
# Epoch 330 - lr: 0.01000 - Train loss: 0.78328 - Test loss: 0.53384
# Epoch 331 - lr: 0.01000 - Train loss: 0.78301 - Test loss: 0.53334
# Epoch 332 - lr: 0.01000 - Train loss: 0.78274 - Test loss: 0.53284
# Epoch 333 - lr: 0.01000 - Train loss: 0.78246 - Test loss: 0.53234
# Epoch 334 - lr: 0.01000 - Train loss: 0.78219 - Test loss: 0.53183
# Epoch 335 - lr: 0.01000 - Train loss: 0.78192 - Test loss: 0.53132
# Epoch 336 - lr: 0.01000 - Train loss: 0.78165 - Test loss: 0.53082
# Epoch 337 - lr: 0.01000 - Train loss: 0.78137 - Test loss: 0.53031
# Epoch 338 - lr: 0.01000 - Train loss: 0.78110 - Test loss: 0.52980
# Epoch 339 - lr: 0.01000 - Train loss: 0.78082 - Test loss: 0.52929
# Epoch 340 - lr: 0.01000 - Train loss: 0.78054 - Test loss: 0.52877
# Epoch 341 - lr: 0.01000 - Train loss: 0.78027 - Test loss: 0.52826
# Epoch 342 - lr: 0.01000 - Train loss: 0.77999 - Test loss: 0.52774
# Epoch 343 - lr: 0.01000 - Train loss: 0.77971 - Test loss: 0.52722
# Epoch 344 - lr: 0.01000 - Train loss: 0.77943 - Test loss: 0.52671
# Epoch 345 - lr: 0.01000 - Train loss: 0.77916 - Test loss: 0.52619
# Epoch 346 - lr: 0.01000 - Train loss: 0.77888 - Test loss: 0.52567
# Epoch 347 - lr: 0.01000 - Train loss: 0.77859 - Test loss: 0.52514
# Epoch 348 - lr: 0.01000 - Train loss: 0.77831 - Test loss: 0.52462
# Epoch 349 - lr: 0.01000 - Train loss: 0.77803 - Test loss: 0.52410
# Epoch 350 - lr: 0.01000 - Train loss: 0.77775 - Test loss: 0.52357
# Epoch 351 - lr: 0.01000 - Train loss: 0.77747 - Test loss: 0.52305
# Epoch 352 - lr: 0.01000 - Train loss: 0.77718 - Test loss: 0.52252
# Epoch 353 - lr: 0.01000 - Train loss: 0.77690 - Test loss: 0.52199
# Epoch 354 - lr: 0.01000 - Train loss: 0.77662 - Test loss: 0.52146
# Epoch 355 - lr: 0.01000 - Train loss: 0.77633 - Test loss: 0.52093
# Epoch 356 - lr: 0.01000 - Train loss: 0.77604 - Test loss: 0.52040
# Epoch 357 - lr: 0.01000 - Train loss: 0.77576 - Test loss: 0.51987
# Epoch 358 - lr: 0.01000 - Train loss: 0.77547 - Test loss: 0.51934
# Epoch 359 - lr: 0.01000 - Train loss: 0.77518 - Test loss: 0.51881
# Epoch 360 - lr: 0.01000 - Train loss: 0.77489 - Test loss: 0.51828
# Epoch 361 - lr: 0.01000 - Train loss: 0.77460 - Test loss: 0.51774
# Epoch 362 - lr: 0.01000 - Train loss: 0.77431 - Test loss: 0.51721
# Epoch 363 - lr: 0.01000 - Train loss: 0.77402 - Test loss: 0.51668
# Epoch 364 - lr: 0.01000 - Train loss: 0.77373 - Test loss: 0.51614
# Epoch 365 - lr: 0.01000 - Train loss: 0.77344 - Test loss: 0.51561
# Epoch 366 - lr: 0.01000 - Train loss: 0.77315 - Test loss: 0.51507
# Epoch 367 - lr: 0.01000 - Train loss: 0.77285 - Test loss: 0.51453
# Epoch 368 - lr: 0.01000 - Train loss: 0.77256 - Test loss: 0.51400
# Epoch 369 - lr: 0.01000 - Train loss: 0.77226 - Test loss: 0.51346
# Epoch 370 - lr: 0.01000 - Train loss: 0.77197 - Test loss: 0.51292
# Epoch 371 - lr: 0.01000 - Train loss: 0.77167 - Test loss: 0.51238
# Epoch 372 - lr: 0.01000 - Train loss: 0.77138 - Test loss: 0.51184
# Epoch 373 - lr: 0.01000 - Train loss: 0.77108 - Test loss: 0.51131
# Epoch 374 - lr: 0.01000 - Train loss: 0.77078 - Test loss: 0.51077
# Epoch 375 - lr: 0.01000 - Train loss: 0.77048 - Test loss: 0.51023
# Epoch 376 - lr: 0.01000 - Train loss: 0.77018 - Test loss: 0.50969
# Epoch 377 - lr: 0.01000 - Train loss: 0.76988 - Test loss: 0.50915
# Epoch 378 - lr: 0.01000 - Train loss: 0.76958 - Test loss: 0.50861
# Epoch 379 - lr: 0.01000 - Train loss: 0.76928 - Test loss: 0.50807
# Epoch 380 - lr: 0.01000 - Train loss: 0.76897 - Test loss: 0.50753
# Epoch 381 - lr: 0.01000 - Train loss: 0.76867 - Test loss: 0.50699
# Epoch 382 - lr: 0.01000 - Train loss: 0.76837 - Test loss: 0.50645
# Epoch 383 - lr: 0.01000 - Train loss: 0.76806 - Test loss: 0.50591
# Epoch 384 - lr: 0.01000 - Train loss: 0.76776 - Test loss: 0.50537
# Epoch 385 - lr: 0.01000 - Train loss: 0.76745 - Test loss: 0.50483
# Epoch 386 - lr: 0.01000 - Train loss: 0.76714 - Test loss: 0.50429
# Epoch 387 - lr: 0.01000 - Train loss: 0.76683 - Test loss: 0.50375
# Epoch 388 - lr: 0.01000 - Train loss: 0.76652 - Test loss: 0.50321
# Epoch 389 - lr: 0.01000 - Train loss: 0.76621 - Test loss: 0.50267
# Epoch 390 - lr: 0.01000 - Train loss: 0.76590 - Test loss: 0.50213
# Epoch 391 - lr: 0.01000 - Train loss: 0.76559 - Test loss: 0.50159
# Epoch 392 - lr: 0.01000 - Train loss: 0.76528 - Test loss: 0.50105
# Epoch 393 - lr: 0.01000 - Train loss: 0.76497 - Test loss: 0.50051
# Epoch 394 - lr: 0.01000 - Train loss: 0.76465 - Test loss: 0.49997
# Epoch 395 - lr: 0.01000 - Train loss: 0.76434 - Test loss: 0.49943
# Epoch 396 - lr: 0.01000 - Train loss: 0.76402 - Test loss: 0.49889
# Epoch 397 - lr: 0.01000 - Train loss: 0.76371 - Test loss: 0.49835
# Epoch 398 - lr: 0.01000 - Train loss: 0.76339 - Test loss: 0.49781
# Epoch 399 - lr: 0.01000 - Train loss: 0.76307 - Test loss: 0.49727
# Epoch 400 - lr: 0.01000 - Train loss: 0.76275 - Test loss: 0.49673
# Epoch 401 - lr: 0.01000 - Train loss: 0.76243 - Test loss: 0.49619
# Epoch 402 - lr: 0.01000 - Train loss: 0.76211 - Test loss: 0.49565
# Epoch 403 - lr: 0.01000 - Train loss: 0.76179 - Test loss: 0.49512
# Epoch 404 - lr: 0.01000 - Train loss: 0.76147 - Test loss: 0.49458
# Epoch 405 - lr: 0.01000 - Train loss: 0.76115 - Test loss: 0.49404
# Epoch 406 - lr: 0.01000 - Train loss: 0.76082 - Test loss: 0.49350
# Epoch 407 - lr: 0.01000 - Train loss: 0.76050 - Test loss: 0.49297
# Epoch 408 - lr: 0.01000 - Train loss: 0.76017 - Test loss: 0.49243
# Epoch 409 - lr: 0.01000 - Train loss: 0.75984 - Test loss: 0.49189
# Epoch 410 - lr: 0.01000 - Train loss: 0.75952 - Test loss: 0.49136
# Epoch 411 - lr: 0.01000 - Train loss: 0.75919 - Test loss: 0.49082
# Epoch 412 - lr: 0.01000 - Train loss: 0.75886 - Test loss: 0.49029
# Epoch 413 - lr: 0.01000 - Train loss: 0.75853 - Test loss: 0.48975
# Epoch 414 - lr: 0.01000 - Train loss: 0.75820 - Test loss: 0.48922
# Epoch 415 - lr: 0.01000 - Train loss: 0.75786 - Test loss: 0.48868
# Epoch 416 - lr: 0.01000 - Train loss: 0.75753 - Test loss: 0.48815
# Epoch 417 - lr: 0.01000 - Train loss: 0.75720 - Test loss: 0.48762
# Epoch 418 - lr: 0.01000 - Train loss: 0.75686 - Test loss: 0.48708
# Epoch 419 - lr: 0.01000 - Train loss: 0.75652 - Test loss: 0.48655
# Epoch 420 - lr: 0.01000 - Train loss: 0.75619 - Test loss: 0.48602
# Epoch 421 - lr: 0.01000 - Train loss: 0.75585 - Test loss: 0.48549
# Epoch 422 - lr: 0.01000 - Train loss: 0.75551 - Test loss: 0.48496
# Epoch 423 - lr: 0.01000 - Train loss: 0.75517 - Test loss: 0.48442
# Epoch 424 - lr: 0.01000 - Train loss: 0.75483 - Test loss: 0.48389
# Epoch 425 - lr: 0.01000 - Train loss: 0.75448 - Test loss: 0.48336
# Epoch 426 - lr: 0.01000 - Train loss: 0.75414 - Test loss: 0.48283
# Epoch 427 - lr: 0.01000 - Train loss: 0.75380 - Test loss: 0.48231
# Epoch 428 - lr: 0.01000 - Train loss: 0.75345 - Test loss: 0.48178
# Epoch 429 - lr: 0.01000 - Train loss: 0.75310 - Test loss: 0.48125
# Epoch 430 - lr: 0.01000 - Train loss: 0.75275 - Test loss: 0.48072
# Epoch 431 - lr: 0.01000 - Train loss: 0.75241 - Test loss: 0.48019
# Epoch 432 - lr: 0.01000 - Train loss: 0.75206 - Test loss: 0.47967
# Epoch 433 - lr: 0.01000 - Train loss: 0.75170 - Test loss: 0.47914
# Epoch 434 - lr: 0.01000 - Train loss: 0.75135 - Test loss: 0.47861
# Epoch 435 - lr: 0.01000 - Train loss: 0.75100 - Test loss: 0.47809
# Epoch 436 - lr: 0.01000 - Train loss: 0.75064 - Test loss: 0.47756
# Epoch 437 - lr: 0.01000 - Train loss: 0.75029 - Test loss: 0.47704
# Epoch 438 - lr: 0.01000 - Train loss: 0.74993 - Test loss: 0.47652
# Epoch 439 - lr: 0.01000 - Train loss: 0.74957 - Test loss: 0.47599
# Epoch 440 - lr: 0.01000 - Train loss: 0.74921 - Test loss: 0.47547
# Epoch 441 - lr: 0.01000 - Train loss: 0.74885 - Test loss: 0.47495
# Epoch 442 - lr: 0.01000 - Train loss: 0.74849 - Test loss: 0.47443
# Epoch 443 - lr: 0.01000 - Train loss: 0.74813 - Test loss: 0.47390
# Epoch 444 - lr: 0.01000 - Train loss: 0.74777 - Test loss: 0.47338
# Epoch 445 - lr: 0.01000 - Train loss: 0.74740 - Test loss: 0.47286
# Epoch 446 - lr: 0.01000 - Train loss: 0.74703 - Test loss: 0.47234
# Epoch 447 - lr: 0.01000 - Train loss: 0.74667 - Test loss: 0.47182
# Epoch 448 - lr: 0.01000 - Train loss: 0.74630 - Test loss: 0.47130
# Epoch 449 - lr: 0.01000 - Train loss: 0.74593 - Test loss: 0.47079
# Epoch 450 - lr: 0.01000 - Train loss: 0.74555 - Test loss: 0.47027
# Epoch 451 - lr: 0.01000 - Train loss: 0.74518 - Test loss: 0.46975
# Epoch 452 - lr: 0.01000 - Train loss: 0.74481 - Test loss: 0.46923
# Epoch 453 - lr: 0.01000 - Train loss: 0.74443 - Test loss: 0.46872
# Epoch 454 - lr: 0.01000 - Train loss: 0.74405 - Test loss: 0.46820
# Epoch 455 - lr: 0.01000 - Train loss: 0.74368 - Test loss: 0.46768
# Epoch 456 - lr: 0.01000 - Train loss: 0.74330 - Test loss: 0.46717
# Epoch 457 - lr: 0.01000 - Train loss: 0.74292 - Test loss: 0.46665
# Epoch 458 - lr: 0.01000 - Train loss: 0.74253 - Test loss: 0.46614
# Epoch 459 - lr: 0.01000 - Train loss: 0.74215 - Test loss: 0.46563
# Epoch 460 - lr: 0.01000 - Train loss: 0.74176 - Test loss: 0.46511
# Epoch 461 - lr: 0.01000 - Train loss: 0.74138 - Test loss: 0.46460
# Epoch 462 - lr: 0.01000 - Train loss: 0.74099 - Test loss: 0.46409
# Epoch 463 - lr: 0.01000 - Train loss: 0.74060 - Test loss: 0.46358
# Epoch 464 - lr: 0.01000 - Train loss: 0.74021 - Test loss: 0.46306
# Epoch 465 - lr: 0.01000 - Train loss: 0.73982 - Test loss: 0.46255
# Epoch 466 - lr: 0.01000 - Train loss: 0.73942 - Test loss: 0.46204
# Epoch 467 - lr: 0.01000 - Train loss: 0.73903 - Test loss: 0.46153
# Epoch 468 - lr: 0.01000 - Train loss: 0.73863 - Test loss: 0.46102
# Epoch 469 - lr: 0.01000 - Train loss: 0.73823 - Test loss: 0.46051
# Epoch 470 - lr: 0.01000 - Train loss: 0.73783 - Test loss: 0.46000
# Epoch 471 - lr: 0.01000 - Train loss: 0.73743 - Test loss: 0.45949
# Epoch 472 - lr: 0.01000 - Train loss: 0.73703 - Test loss: 0.45899
# Epoch 473 - lr: 0.01000 - Train loss: 0.73662 - Test loss: 0.45848
# Epoch 474 - lr: 0.01000 - Train loss: 0.73622 - Test loss: 0.45797
# Epoch 475 - lr: 0.01000 - Train loss: 0.73581 - Test loss: 0.45746
# Epoch 476 - lr: 0.01000 - Train loss: 0.73540 - Test loss: 0.45696
# Epoch 477 - lr: 0.01000 - Train loss: 0.73499 - Test loss: 0.45645
# Epoch 478 - lr: 0.01000 - Train loss: 0.73457 - Test loss: 0.45594
# Epoch 479 - lr: 0.01000 - Train loss: 0.73416 - Test loss: 0.45544
# Epoch 480 - lr: 0.01000 - Train loss: 0.73374 - Test loss: 0.45493
# Epoch 481 - lr: 0.01000 - Train loss: 0.73333 - Test loss: 0.45442
# Epoch 482 - lr: 0.01000 - Train loss: 0.73291 - Test loss: 0.45392
# Epoch 483 - lr: 0.01000 - Train loss: 0.73248 - Test loss: 0.45342
# Epoch 484 - lr: 0.01000 - Train loss: 0.73206 - Test loss: 0.45291
# Epoch 485 - lr: 0.01000 - Train loss: 0.73164 - Test loss: 0.45241
# Epoch 486 - lr: 0.01000 - Train loss: 0.73121 - Test loss: 0.45190
# Epoch 487 - lr: 0.01000 - Train loss: 0.73078 - Test loss: 0.45140
# Epoch 488 - lr: 0.01000 - Train loss: 0.73035 - Test loss: 0.45089
# Epoch 489 - lr: 0.01000 - Train loss: 0.72992 - Test loss: 0.45039
# Epoch 490 - lr: 0.01000 - Train loss: 0.72948 - Test loss: 0.44989
# Epoch 491 - lr: 0.01000 - Train loss: 0.72905 - Test loss: 0.44939
# Epoch 492 - lr: 0.01000 - Train loss: 0.72861 - Test loss: 0.44888
# Epoch 493 - lr: 0.01000 - Train loss: 0.72817 - Test loss: 0.44838
# Epoch 494 - lr: 0.01000 - Train loss: 0.72773 - Test loss: 0.44788
# Epoch 495 - lr: 0.01000 - Train loss: 0.72728 - Test loss: 0.44738
# Epoch 496 - lr: 0.01000 - Train loss: 0.72684 - Test loss: 0.44687
# Epoch 497 - lr: 0.01000 - Train loss: 0.72639 - Test loss: 0.44637
# Epoch 498 - lr: 0.01000 - Train loss: 0.72594 - Test loss: 0.44587
# Epoch 499 - lr: 0.01000 - Train loss: 0.72549 - Test loss: 0.44537
# Epoch 500 - lr: 0.01000 - Train loss: 0.72503 - Test loss: 0.44487
# Epoch 501 - lr: 0.01000 - Train loss: 0.72458 - Test loss: 0.44436
# Epoch 502 - lr: 0.01000 - Train loss: 0.72412 - Test loss: 0.44386
# Epoch 503 - lr: 0.01000 - Train loss: 0.72366 - Test loss: 0.44336
# Epoch 504 - lr: 0.01000 - Train loss: 0.72320 - Test loss: 0.44286
# Epoch 505 - lr: 0.01000 - Train loss: 0.72273 - Test loss: 0.44236
# Epoch 506 - lr: 0.01000 - Train loss: 0.72226 - Test loss: 0.44186
# Epoch 507 - lr: 0.01000 - Train loss: 0.72179 - Test loss: 0.44136
# Epoch 508 - lr: 0.01000 - Train loss: 0.72132 - Test loss: 0.44085
# Epoch 509 - lr: 0.01000 - Train loss: 0.72085 - Test loss: 0.44035
# Epoch 510 - lr: 0.01000 - Train loss: 0.72037 - Test loss: 0.43985
# Epoch 511 - lr: 0.01000 - Train loss: 0.71989 - Test loss: 0.43935
# Epoch 512 - lr: 0.01000 - Train loss: 0.71941 - Test loss: 0.43885
# Epoch 513 - lr: 0.01000 - Train loss: 0.71893 - Test loss: 0.43834
# Epoch 514 - lr: 0.01000 - Train loss: 0.71844 - Test loss: 0.43784
# Epoch 515 - lr: 0.01000 - Train loss: 0.71796 - Test loss: 0.43734
# Epoch 516 - lr: 0.01000 - Train loss: 0.71747 - Test loss: 0.43684
# Epoch 517 - lr: 0.01000 - Train loss: 0.71697 - Test loss: 0.43634
# Epoch 518 - lr: 0.01000 - Train loss: 0.71648 - Test loss: 0.43583
# Epoch 519 - lr: 0.01000 - Train loss: 0.71598 - Test loss: 0.43533
# Epoch 520 - lr: 0.01000 - Train loss: 0.71548 - Test loss: 0.43483
# Epoch 521 - lr: 0.01000 - Train loss: 0.71498 - Test loss: 0.43432
# Epoch 522 - lr: 0.01000 - Train loss: 0.71447 - Test loss: 0.43382
# Epoch 523 - lr: 0.01000 - Train loss: 0.71396 - Test loss: 0.43332
# Epoch 524 - lr: 0.01000 - Train loss: 0.71345 - Test loss: 0.43281
# Epoch 525 - lr: 0.01000 - Train loss: 0.71294 - Test loss: 0.43231
# Epoch 526 - lr: 0.01000 - Train loss: 0.71242 - Test loss: 0.43180
# Epoch 527 - lr: 0.01000 - Train loss: 0.71190 - Test loss: 0.43130
# Epoch 528 - lr: 0.01000 - Train loss: 0.71138 - Test loss: 0.43079
# Epoch 529 - lr: 0.01000 - Train loss: 0.71086 - Test loss: 0.43029
# Epoch 530 - lr: 0.01000 - Train loss: 0.71033 - Test loss: 0.42978
# Epoch 531 - lr: 0.01000 - Train loss: 0.70980 - Test loss: 0.42927
# Epoch 532 - lr: 0.01000 - Train loss: 0.70927 - Test loss: 0.42876
# Epoch 533 - lr: 0.01000 - Train loss: 0.70873 - Test loss: 0.42826
# Epoch 534 - lr: 0.01000 - Train loss: 0.70819 - Test loss: 0.42775
# Epoch 535 - lr: 0.01000 - Train loss: 0.70765 - Test loss: 0.42724
# Epoch 536 - lr: 0.01000 - Train loss: 0.70710 - Test loss: 0.42673
# Epoch 537 - lr: 0.01000 - Train loss: 0.70655 - Test loss: 0.42622
# Epoch 538 - lr: 0.01000 - Train loss: 0.70600 - Test loss: 0.42571
# Epoch 539 - lr: 0.01000 - Train loss: 0.70545 - Test loss: 0.42520
# Epoch 540 - lr: 0.01000 - Train loss: 0.70489 - Test loss: 0.42469
# Epoch 541 - lr: 0.01000 - Train loss: 0.70433 - Test loss: 0.42417
# Epoch 542 - lr: 0.01000 - Train loss: 0.70377 - Test loss: 0.42366
# Epoch 543 - lr: 0.01000 - Train loss: 0.70320 - Test loss: 0.42315
# Epoch 544 - lr: 0.01000 - Train loss: 0.70263 - Test loss: 0.42263
# Epoch 545 - lr: 0.01000 - Train loss: 0.70205 - Test loss: 0.42212
# Epoch 546 - lr: 0.01000 - Train loss: 0.70148 - Test loss: 0.42160
# Epoch 547 - lr: 0.01000 - Train loss: 0.70090 - Test loss: 0.42108
# Epoch 548 - lr: 0.01000 - Train loss: 0.70031 - Test loss: 0.42056
# Epoch 549 - lr: 0.01000 - Train loss: 0.69972 - Test loss: 0.42005
# Epoch 550 - lr: 0.01000 - Train loss: 0.69913 - Test loss: 0.41953
# Epoch 551 - lr: 0.01000 - Train loss: 0.69854 - Test loss: 0.41901
# Epoch 552 - lr: 0.01000 - Train loss: 0.69794 - Test loss: 0.41848
# Epoch 553 - lr: 0.01000 - Train loss: 0.69734 - Test loss: 0.41796
# Epoch 554 - lr: 0.01000 - Train loss: 0.69673 - Test loss: 0.41744
# Epoch 555 - lr: 0.01000 - Train loss: 0.69612 - Test loss: 0.41691
# Epoch 556 - lr: 0.01000 - Train loss: 0.69551 - Test loss: 0.41639
# Epoch 557 - lr: 0.01000 - Train loss: 0.69489 - Test loss: 0.41586
# Epoch 558 - lr: 0.01000 - Train loss: 0.69427 - Test loss: 0.41533
# Epoch 559 - lr: 0.01000 - Train loss: 0.69365 - Test loss: 0.41481
# Epoch 560 - lr: 0.01000 - Train loss: 0.69302 - Test loss: 0.41428
# Epoch 561 - lr: 0.01000 - Train loss: 0.69238 - Test loss: 0.41374
# Epoch 562 - lr: 0.01000 - Train loss: 0.69175 - Test loss: 0.41321
# Epoch 563 - lr: 0.01000 - Train loss: 0.69111 - Test loss: 0.41268
# Epoch 564 - lr: 0.01000 - Train loss: 0.69046 - Test loss: 0.41214
# Epoch 565 - lr: 0.01000 - Train loss: 0.68981 - Test loss: 0.41161
# Epoch 566 - lr: 0.01000 - Train loss: 0.68916 - Test loss: 0.41107
# Epoch 567 - lr: 0.01000 - Train loss: 0.68850 - Test loss: 0.41053
# Epoch 568 - lr: 0.01000 - Train loss: 0.68784 - Test loss: 0.40999
# Epoch 569 - lr: 0.01000 - Train loss: 0.68717 - Test loss: 0.40945
# Epoch 570 - lr: 0.01000 - Train loss: 0.68650 - Test loss: 0.40890
# Epoch 571 - lr: 0.01000 - Train loss: 0.68583 - Test loss: 0.40836
# Epoch 572 - lr: 0.01000 - Train loss: 0.68515 - Test loss: 0.40781
# Epoch 573 - lr: 0.01000 - Train loss: 0.68446 - Test loss: 0.40727
# Epoch 574 - lr: 0.01000 - Train loss: 0.68378 - Test loss: 0.40672
# Epoch 575 - lr: 0.01000 - Train loss: 0.68308 - Test loss: 0.40617
# Epoch 576 - lr: 0.01000 - Train loss: 0.68238 - Test loss: 0.40561
# Epoch 577 - lr: 0.01000 - Train loss: 0.68168 - Test loss: 0.40506
# Epoch 578 - lr: 0.01000 - Train loss: 0.68097 - Test loss: 0.40450
# Epoch 579 - lr: 0.01000 - Train loss: 0.68026 - Test loss: 0.40394
# Epoch 580 - lr: 0.01000 - Train loss: 0.67954 - Test loss: 0.40338
# Epoch 581 - lr: 0.01000 - Train loss: 0.67882 - Test loss: 0.40282
# Epoch 582 - lr: 0.01000 - Train loss: 0.67809 - Test loss: 0.40226
# Epoch 583 - lr: 0.01000 - Train loss: 0.67736 - Test loss: 0.40169
# Epoch 584 - lr: 0.01000 - Train loss: 0.67662 - Test loss: 0.40113
# Epoch 585 - lr: 0.01000 - Train loss: 0.67588 - Test loss: 0.40056
# Epoch 586 - lr: 0.01000 - Train loss: 0.67513 - Test loss: 0.39999
# Epoch 587 - lr: 0.01000 - Train loss: 0.67438 - Test loss: 0.39941
# Epoch 588 - lr: 0.01000 - Train loss: 0.67362 - Test loss: 0.39884
# Epoch 589 - lr: 0.01000 - Train loss: 0.67285 - Test loss: 0.39826
# Epoch 590 - lr: 0.01000 - Train loss: 0.67208 - Test loss: 0.39768
# Epoch 591 - lr: 0.01000 - Train loss: 0.67131 - Test loss: 0.39710
# Epoch 592 - lr: 0.01000 - Train loss: 0.67052 - Test loss: 0.39651
# Epoch 593 - lr: 0.01000 - Train loss: 0.66974 - Test loss: 0.39592
# Epoch 594 - lr: 0.01000 - Train loss: 0.66894 - Test loss: 0.39534
# Epoch 595 - lr: 0.01000 - Train loss: 0.66814 - Test loss: 0.39474
# Epoch 596 - lr: 0.01000 - Train loss: 0.66734 - Test loss: 0.39415
# Epoch 597 - lr: 0.01000 - Train loss: 0.66653 - Test loss: 0.39355
# Epoch 598 - lr: 0.01000 - Train loss: 0.66571 - Test loss: 0.39295
# Epoch 599 - lr: 0.01000 - Train loss: 0.66489 - Test loss: 0.39235
# Epoch 600 - lr: 0.01000 - Train loss: 0.66406 - Test loss: 0.39175
# Epoch 601 - lr: 0.01000 - Train loss: 0.66322 - Test loss: 0.39114
# Epoch 602 - lr: 0.01000 - Train loss: 0.66238 - Test loss: 0.39053
# Epoch 603 - lr: 0.01000 - Train loss: 0.66153 - Test loss: 0.38992
# Epoch 604 - lr: 0.01000 - Train loss: 0.66068 - Test loss: 0.38930
# Epoch 605 - lr: 0.01000 - Train loss: 0.65982 - Test loss: 0.38869
# Epoch 606 - lr: 0.01000 - Train loss: 0.65895 - Test loss: 0.38807
# Epoch 607 - lr: 0.01000 - Train loss: 0.65807 - Test loss: 0.38744
# Epoch 608 - lr: 0.01000 - Train loss: 0.65719 - Test loss: 0.38681
# Epoch 609 - lr: 0.01000 - Train loss: 0.65630 - Test loss: 0.38618
# Epoch 610 - lr: 0.01000 - Train loss: 0.65541 - Test loss: 0.38555
# Epoch 611 - lr: 0.01000 - Train loss: 0.65450 - Test loss: 0.38492
# Epoch 612 - lr: 0.01000 - Train loss: 0.65359 - Test loss: 0.38428
# Epoch 613 - lr: 0.01000 - Train loss: 0.65268 - Test loss: 0.38363
# Epoch 614 - lr: 0.01000 - Train loss: 0.65175 - Test loss: 0.38299
# Epoch 615 - lr: 0.01000 - Train loss: 0.65082 - Test loss: 0.38234
# Epoch 616 - lr: 0.01000 - Train loss: 0.64988 - Test loss: 0.38168
# Epoch 617 - lr: 0.01000 - Train loss: 0.64893 - Test loss: 0.38103
# Epoch 618 - lr: 0.01000 - Train loss: 0.64798 - Test loss: 0.38037
# Epoch 619 - lr: 0.01000 - Train loss: 0.64702 - Test loss: 0.37971
# Epoch 620 - lr: 0.01000 - Train loss: 0.64604 - Test loss: 0.37904
# Epoch 621 - lr: 0.01000 - Train loss: 0.64507 - Test loss: 0.37837
# Epoch 622 - lr: 0.01000 - Train loss: 0.64408 - Test loss: 0.37769
# Epoch 623 - lr: 0.01000 - Train loss: 0.64309 - Test loss: 0.37702
# Epoch 624 - lr: 0.01000 - Train loss: 0.64208 - Test loss: 0.37633
# Epoch 625 - lr: 0.01000 - Train loss: 0.64107 - Test loss: 0.37565
# Epoch 626 - lr: 0.01000 - Train loss: 0.64005 - Test loss: 0.37496
# Epoch 627 - lr: 0.01000 - Train loss: 0.63902 - Test loss: 0.37426
# Epoch 628 - lr: 0.01000 - Train loss: 0.63799 - Test loss: 0.37356
# Epoch 629 - lr: 0.01000 - Train loss: 0.63694 - Test loss: 0.37286
# Epoch 630 - lr: 0.01000 - Train loss: 0.63589 - Test loss: 0.37216
# Epoch 631 - lr: 0.01000 - Train loss: 0.63482 - Test loss: 0.37144
# Epoch 632 - lr: 0.01000 - Train loss: 0.63375 - Test loss: 0.37073
# Epoch 633 - lr: 0.01000 - Train loss: 0.63267 - Test loss: 0.37001
# Epoch 634 - lr: 0.01000 - Train loss: 0.63158 - Test loss: 0.36929
# Epoch 635 - lr: 0.01000 - Train loss: 0.63048 - Test loss: 0.36856
# Epoch 636 - lr: 0.01000 - Train loss: 0.62937 - Test loss: 0.36782
# Epoch 637 - lr: 0.01000 - Train loss: 0.62825 - Test loss: 0.36709
# Epoch 638 - lr: 0.01000 - Train loss: 0.62712 - Test loss: 0.36634
# Epoch 639 - lr: 0.01000 - Train loss: 0.62598 - Test loss: 0.36560
# Epoch 640 - lr: 0.01000 - Train loss: 0.62484 - Test loss: 0.36484
# Epoch 641 - lr: 0.01000 - Train loss: 0.62368 - Test loss: 0.36409
# Epoch 642 - lr: 0.01000 - Train loss: 0.62251 - Test loss: 0.36332
# Epoch 643 - lr: 0.01000 - Train loss: 0.62133 - Test loss: 0.36256
# Epoch 644 - lr: 0.01000 - Train loss: 0.62014 - Test loss: 0.36178
# Epoch 645 - lr: 0.01000 - Train loss: 0.61894 - Test loss: 0.36100
# Epoch 646 - lr: 0.01000 - Train loss: 0.61773 - Test loss: 0.36022
# Epoch 647 - lr: 0.01000 - Train loss: 0.61651 - Test loss: 0.35943
# Epoch 648 - lr: 0.01000 - Train loss: 0.61528 - Test loss: 0.35864
# Epoch 649 - lr: 0.01000 - Train loss: 0.61403 - Test loss: 0.35784
# Epoch 650 - lr: 0.01000 - Train loss: 0.61278 - Test loss: 0.35703
# Epoch 651 - lr: 0.01000 - Train loss: 0.61151 - Test loss: 0.35622
# Epoch 652 - lr: 0.01000 - Train loss: 0.61024 - Test loss: 0.35541
# Epoch 653 - lr: 0.01000 - Train loss: 0.60895 - Test loss: 0.35458
# Epoch 654 - lr: 0.01000 - Train loss: 0.60765 - Test loss: 0.35375
# Epoch 655 - lr: 0.01000 - Train loss: 0.60634 - Test loss: 0.35292
# Epoch 656 - lr: 0.01000 - Train loss: 0.60501 - Test loss: 0.35208
# Epoch 657 - lr: 0.01000 - Train loss: 0.60368 - Test loss: 0.35123
# Epoch 658 - lr: 0.01000 - Train loss: 0.60233 - Test loss: 0.35038
# Epoch 659 - lr: 0.01000 - Train loss: 0.60097 - Test loss: 0.34952
# Epoch 660 - lr: 0.01000 - Train loss: 0.59959 - Test loss: 0.34865
# Epoch 661 - lr: 0.01000 - Train loss: 0.59821 - Test loss: 0.34778
# Epoch 662 - lr: 0.01000 - Train loss: 0.59681 - Test loss: 0.34690
# Epoch 663 - lr: 0.01000 - Train loss: 0.59540 - Test loss: 0.34602
# Epoch 664 - lr: 0.01000 - Train loss: 0.59397 - Test loss: 0.34512
# Epoch 665 - lr: 0.01000 - Train loss: 0.59254 - Test loss: 0.34422
# Epoch 666 - lr: 0.01000 - Train loss: 0.59109 - Test loss: 0.34332
# Epoch 667 - lr: 0.01000 - Train loss: 0.58962 - Test loss: 0.34240
# Epoch 668 - lr: 0.01000 - Train loss: 0.58814 - Test loss: 0.34148
# Epoch 669 - lr: 0.01000 - Train loss: 0.58665 - Test loss: 0.34056
# Epoch 670 - lr: 0.01000 - Train loss: 0.58515 - Test loss: 0.33962
# Epoch 671 - lr: 0.01000 - Train loss: 0.58363 - Test loss: 0.33868
# Epoch 672 - lr: 0.01000 - Train loss: 0.58209 - Test loss: 0.33773
# Epoch 673 - lr: 0.01000 - Train loss: 0.58055 - Test loss: 0.33677
# Epoch 674 - lr: 0.01000 - Train loss: 0.57898 - Test loss: 0.33581
# Epoch 675 - lr: 0.01000 - Train loss: 0.57740 - Test loss: 0.33483
# Epoch 676 - lr: 0.01000 - Train loss: 0.57581 - Test loss: 0.33385
# Epoch 677 - lr: 0.01000 - Train loss: 0.57421 - Test loss: 0.33286
# Epoch 678 - lr: 0.01000 - Train loss: 0.57258 - Test loss: 0.33187
# Epoch 679 - lr: 0.01000 - Train loss: 0.57094 - Test loss: 0.33086
# Epoch 680 - lr: 0.01000 - Train loss: 0.56929 - Test loss: 0.32985
# Epoch 681 - lr: 0.01000 - Train loss: 0.56762 - Test loss: 0.32883
# Epoch 682 - lr: 0.01000 - Train loss: 0.56594 - Test loss: 0.32780
# Epoch 683 - lr: 0.01000 - Train loss: 0.56424 - Test loss: 0.32676
# Epoch 684 - lr: 0.01000 - Train loss: 0.56252 - Test loss: 0.32571
# Epoch 685 - lr: 0.01000 - Train loss: 0.56079 - Test loss: 0.32466
# Epoch 686 - lr: 0.01000 - Train loss: 0.55904 - Test loss: 0.32359
# Epoch 687 - lr: 0.01000 - Train loss: 0.55727 - Test loss: 0.32252
# Epoch 688 - lr: 0.01000 - Train loss: 0.55549 - Test loss: 0.32144
# Epoch 689 - lr: 0.01000 - Train loss: 0.55369 - Test loss: 0.32034
# Epoch 690 - lr: 0.01000 - Train loss: 0.55187 - Test loss: 0.31924
# Epoch 691 - lr: 0.01000 - Train loss: 0.55004 - Test loss: 0.31813
# Epoch 692 - lr: 0.01000 - Train loss: 0.54819 - Test loss: 0.31701
# Epoch 693 - lr: 0.01000 - Train loss: 0.54632 - Test loss: 0.31588
# Epoch 694 - lr: 0.01000 - Train loss: 0.54443 - Test loss: 0.31475
# Epoch 695 - lr: 0.01000 - Train loss: 0.54253 - Test loss: 0.31360
# Epoch 696 - lr: 0.01000 - Train loss: 0.54060 - Test loss: 0.31244
# Epoch 697 - lr: 0.01000 - Train loss: 0.53866 - Test loss: 0.31127
# Epoch 698 - lr: 0.01000 - Train loss: 0.53670 - Test loss: 0.31009
# Epoch 699 - lr: 0.01000 - Train loss: 0.53472 - Test loss: 0.30891
# Epoch 700 - lr: 0.01000 - Train loss: 0.53273 - Test loss: 0.30771
# Epoch 701 - lr: 0.01000 - Train loss: 0.53071 - Test loss: 0.30650
# Epoch 702 - lr: 0.01000 - Train loss: 0.52868 - Test loss: 0.30528
# Epoch 703 - lr: 0.01000 - Train loss: 0.52662 - Test loss: 0.30405
# Epoch 704 - lr: 0.01000 - Train loss: 0.52455 - Test loss: 0.30281
# Epoch 705 - lr: 0.01000 - Train loss: 0.52246 - Test loss: 0.30156
# Epoch 706 - lr: 0.01000 - Train loss: 0.52035 - Test loss: 0.30030
# Epoch 707 - lr: 0.01000 - Train loss: 0.51822 - Test loss: 0.29903
# Epoch 708 - lr: 0.01000 - Train loss: 0.51606 - Test loss: 0.29775
# Epoch 709 - lr: 0.01000 - Train loss: 0.51389 - Test loss: 0.29645
# Epoch 710 - lr: 0.01000 - Train loss: 0.51170 - Test loss: 0.29515
# Epoch 711 - lr: 0.01000 - Train loss: 0.50949 - Test loss: 0.29383
# Epoch 712 - lr: 0.01000 - Train loss: 0.50726 - Test loss: 0.29250
# Epoch 713 - lr: 0.01000 - Train loss: 0.50500 - Test loss: 0.29116
# Epoch 714 - lr: 0.01000 - Train loss: 0.50273 - Test loss: 0.28981
# Epoch 715 - lr: 0.01000 - Train loss: 0.50044 - Test loss: 0.28845
# Epoch 716 - lr: 0.01000 - Train loss: 0.49812 - Test loss: 0.28708
# Epoch 717 - lr: 0.01000 - Train loss: 0.49578 - Test loss: 0.28569
# Epoch 718 - lr: 0.01000 - Train loss: 0.49343 - Test loss: 0.28430
# ...
# Epoch 4766 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05120
# Epoch 4767 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05120
# Epoch 4768 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05120
# Epoch 4769 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05120
# Epoch 4770 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05120
# Epoch 4771 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05120
# Epoch 4772 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05120
# Epoch 4773 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05120
# Epoch 4774 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05120
# Epoch 4775 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05120
# Epoch 4776 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05120
# Epoch 4777 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05120
# Epoch 4778 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05120
# Epoch 4779 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05120
# Epoch 4780 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05120
# Epoch 4781 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05120
# Epoch 4782 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05120
# Epoch 4783 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05120
# Epoch 4784 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05120
# Epoch 4785 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05120
# Epoch 4786 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05120
# Epoch 4787 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05120
# Epoch 4788 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05120
# Epoch 4789 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05120
# Epoch 4790 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05120
# Epoch 4791 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05120
# Epoch 4792 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05120
# Epoch 4793 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05120
# Epoch 4794 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05120
# Epoch 4795 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05120
# Epoch 4796 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05120
# Epoch 4797 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05120
# Epoch 4798 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05121
# Epoch 4799 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05121
# Epoch 4800 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05121
# Epoch 4801 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05121
# Epoch 4802 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05121
# Epoch 4803 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05121
# Epoch 4804 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05121
# Epoch 4805 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05121
# Epoch 4806 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05121
# Epoch 4807 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05121
# Epoch 4808 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05121
# Epoch 4809 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05121
# Epoch 4810 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05121
# Epoch 4811 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05121
# Epoch 4812 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05121
# Epoch 4813 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05121
# Epoch 4814 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05121
# Epoch 4815 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05121
# Epoch 4816 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05121
# Epoch 4817 - lr: 0.01000 - Train loss: 0.04286 - Test loss: 0.05121
# Epoch 4818 - lr: 0.01000 - Train loss: 0.04286 - Test loss: 0.05121
# Epoch 4819 - lr: 0.01000 - Train loss: 0.04286 - Test loss: 0.05121
# Epoch 4820 - lr: 0.01000 - Train loss: 0.04285 - Test loss: 0.05121
# Epoch 4821 - lr: 0.01000 - Train loss: 0.04285 - Test loss: 0.05121
# Epoch 4822 - lr: 0.01000 - Train loss: 0.04285 - Test loss: 0.05121
# Epoch 4823 - lr: 0.01000 - Train loss: 0.04285 - Test loss: 0.05121
# Epoch 4824 - lr: 0.01000 - Train loss: 0.04284 - Test loss: 0.05121
# Epoch 4825 - lr: 0.01000 - Train loss: 0.04284 - Test loss: 0.05121
# Epoch 4826 - lr: 0.01000 - Train loss: 0.04284 - Test loss: 0.05121
# Epoch 4827 - lr: 0.01000 - Train loss: 0.04283 - Test loss: 0.05121
# Epoch 4828 - lr: 0.01000 - Train loss: 0.04283 - Test loss: 0.05121
# Epoch 4829 - lr: 0.01000 - Train loss: 0.04283 - Test loss: 0.05121
# Epoch 4830 - lr: 0.01000 - Train loss: 0.04282 - Test loss: 0.05121
# Epoch 4831 - lr: 0.01000 - Train loss: 0.04282 - Test loss: 0.05121
# Epoch 4832 - lr: 0.01000 - Train loss: 0.04282 - Test loss: 0.05121
# Epoch 4833 - lr: 0.01000 - Train loss: 0.04282 - Test loss: 0.05121
# Epoch 4834 - lr: 0.01000 - Train loss: 0.04281 - Test loss: 0.05121
# Epoch 4835 - lr: 0.01000 - Train loss: 0.04281 - Test loss: 0.05121
# Epoch 4836 - lr: 0.01000 - Train loss: 0.04281 - Test loss: 0.05121
# Epoch 4837 - lr: 0.01000 - Train loss: 0.04280 - Test loss: 0.05121
# Epoch 4838 - lr: 0.01000 - Train loss: 0.04280 - Test loss: 0.05121
# Epoch 4839 - lr: 0.01000 - Train loss: 0.04280 - Test loss: 0.05121
# Epoch 4840 - lr: 0.01000 - Train loss: 0.04280 - Test loss: 0.05121
# Epoch 4841 - lr: 0.01000 - Train loss: 0.04279 - Test loss: 0.05121
# Epoch 4842 - lr: 0.01000 - Train loss: 0.04279 - Test loss: 0.05121
# Epoch 4843 - lr: 0.01000 - Train loss: 0.04279 - Test loss: 0.05121
# Epoch 4844 - lr: 0.01000 - Train loss: 0.04278 - Test loss: 0.05121
# Epoch 4845 - lr: 0.01000 - Train loss: 0.04278 - Test loss: 0.05121
# Epoch 4846 - lr: 0.01000 - Train loss: 0.04278 - Test loss: 0.05121
# Epoch 4847 - lr: 0.01000 - Train loss: 0.04277 - Test loss: 0.05122
# Epoch 4848 - lr: 0.01000 - Train loss: 0.04277 - Test loss: 0.05122
# Epoch 4849 - lr: 0.01000 - Train loss: 0.04277 - Test loss: 0.05122
# Epoch 4850 - lr: 0.01000 - Train loss: 0.04277 - Test loss: 0.05122
# Epoch 4851 - lr: 0.01000 - Train loss: 0.04276 - Test loss: 0.05122
# Epoch 4852 - lr: 0.01000 - Train loss: 0.04276 - Test loss: 0.05122
# Epoch 4853 - lr: 0.01000 - Train loss: 0.04276 - Test loss: 0.05122
# Epoch 4854 - lr: 0.01000 - Train loss: 0.04275 - Test loss: 0.05122
# Epoch 4855 - lr: 0.01000 - Train loss: 0.04275 - Test loss: 0.05122
# Epoch 4856 - lr: 0.01000 - Train loss: 0.04275 - Test loss: 0.05122
# Epoch 4857 - lr: 0.01000 - Train loss: 0.04275 - Test loss: 0.05122
# Epoch 4858 - lr: 0.01000 - Train loss: 0.04274 - Test loss: 0.05122
# Epoch 4859 - lr: 0.01000 - Train loss: 0.04274 - Test loss: 0.05122
# Epoch 4860 - lr: 0.01000 - Train loss: 0.04274 - Test loss: 0.05122
# Epoch 4861 - lr: 0.01000 - Train loss: 0.04273 - Test loss: 0.05122
# Epoch 4862 - lr: 0.01000 - Train loss: 0.04273 - Test loss: 0.05122
# Epoch 4863 - lr: 0.01000 - Train loss: 0.04273 - Test loss: 0.05122
# Epoch 4864 - lr: 0.01000 - Train loss: 0.04272 - Test loss: 0.05122
# Epoch 4865 - lr: 0.01000 - Train loss: 0.04272 - Test loss: 0.05122
# Epoch 4866 - lr: 0.01000 - Train loss: 0.04272 - Test loss: 0.05122
# Epoch 4867 - lr: 0.01000 - Train loss: 0.04272 - Test loss: 0.05122
# Epoch 4868 - lr: 0.01000 - Train loss: 0.04271 - Test loss: 0.05122
# Epoch 4869 - lr: 0.01000 - Train loss: 0.04271 - Test loss: 0.05122
# Epoch 4870 - lr: 0.01000 - Train loss: 0.04271 - Test loss: 0.05122
# Epoch 4871 - lr: 0.01000 - Train loss: 0.04270 - Test loss: 0.05122
# Epoch 4872 - lr: 0.01000 - Train loss: 0.04270 - Test loss: 0.05122
# Epoch 4873 - lr: 0.01000 - Train loss: 0.04270 - Test loss: 0.05122
# Epoch 4874 - lr: 0.01000 - Train loss: 0.04270 - Test loss: 0.05122
# Epoch 4875 - lr: 0.01000 - Train loss: 0.04269 - Test loss: 0.05122
# Epoch 4876 - lr: 0.01000 - Train loss: 0.04269 - Test loss: 0.05122
# Epoch 4877 - lr: 0.01000 - Train loss: 0.04269 - Test loss: 0.05122
# Epoch 4878 - lr: 0.01000 - Train loss: 0.04268 - Test loss: 0.05122
# Epoch 4879 - lr: 0.01000 - Train loss: 0.04268 - Test loss: 0.05122
# Epoch 4880 - lr: 0.01000 - Train loss: 0.04268 - Test loss: 0.05122
# Epoch 4881 - lr: 0.01000 - Train loss: 0.04267 - Test loss: 0.05122
# Epoch 4882 - lr: 0.01000 - Train loss: 0.04267 - Test loss: 0.05122
# Epoch 4883 - lr: 0.01000 - Train loss: 0.04267 - Test loss: 0.05122
# Epoch 4884 - lr: 0.01000 - Train loss: 0.04267 - Test loss: 0.05122
# Epoch 4885 - lr: 0.01000 - Train loss: 0.04266 - Test loss: 0.05122
# Epoch 4886 - lr: 0.01000 - Train loss: 0.04266 - Test loss: 0.05122
# Epoch 4887 - lr: 0.01000 - Train loss: 0.04266 - Test loss: 0.05122
# Epoch 4888 - lr: 0.01000 - Train loss: 0.04265 - Test loss: 0.05122
# Epoch 4889 - lr: 0.01000 - Train loss: 0.04265 - Test loss: 0.05122
# Epoch 4890 - lr: 0.01000 - Train loss: 0.04265 - Test loss: 0.05122
# Epoch 4891 - lr: 0.01000 - Train loss: 0.04265 - Test loss: 0.05122
# Epoch 4892 - lr: 0.01000 - Train loss: 0.04264 - Test loss: 0.05122
# Epoch 4893 - lr: 0.01000 - Train loss: 0.04264 - Test loss: 0.05122
# Epoch 4894 - lr: 0.01000 - Train loss: 0.04264 - Test loss: 0.05122
# Epoch 4895 - lr: 0.01000 - Train loss: 0.04263 - Test loss: 0.05122
# Epoch 4896 - lr: 0.01000 - Train loss: 0.04263 - Test loss: 0.05122
# Epoch 4897 - lr: 0.01000 - Train loss: 0.04263 - Test loss: 0.05122
# Epoch 4898 - lr: 0.01000 - Train loss: 0.04262 - Test loss: 0.05122
# Epoch 4899 - lr: 0.01000 - Train loss: 0.04262 - Test loss: 0.05122
# Epoch 4900 - lr: 0.01000 - Train loss: 0.04262 - Test loss: 0.05122
# Epoch 4901 - lr: 0.01000 - Train loss: 0.04262 - Test loss: 0.05122
# Epoch 4902 - lr: 0.01000 - Train loss: 0.04261 - Test loss: 0.05122
# Epoch 4903 - lr: 0.01000 - Train loss: 0.04261 - Test loss: 0.05122
# Epoch 4904 - lr: 0.01000 - Train loss: 0.04261 - Test loss: 0.05122
# Epoch 4905 - lr: 0.01000 - Train loss: 0.04260 - Test loss: 0.05123
# Epoch 4906 - lr: 0.01000 - Train loss: 0.04260 - Test loss: 0.05123
# Epoch 4907 - lr: 0.01000 - Train loss: 0.04260 - Test loss: 0.05123
# Epoch 4908 - lr: 0.01000 - Train loss: 0.04259 - Test loss: 0.05123
# Epoch 4909 - lr: 0.01000 - Train loss: 0.04259 - Test loss: 0.05123
# Epoch 4910 - lr: 0.01000 - Train loss: 0.04259 - Test loss: 0.05123
# Epoch 4911 - lr: 0.01000 - Train loss: 0.04259 - Test loss: 0.05123
# Epoch 4912 - lr: 0.01000 - Train loss: 0.04258 - Test loss: 0.05123
# Epoch 4913 - lr: 0.01000 - Train loss: 0.04258 - Test loss: 0.05123
# Epoch 4914 - lr: 0.01000 - Train loss: 0.04258 - Test loss: 0.05123
# Epoch 4915 - lr: 0.01000 - Train loss: 0.04257 - Test loss: 0.05123
# Epoch 4916 - lr: 0.01000 - Train loss: 0.04257 - Test loss: 0.05123
# Epoch 4917 - lr: 0.01000 - Train loss: 0.04257 - Test loss: 0.05123
# Epoch 4918 - lr: 0.01000 - Train loss: 0.04257 - Test loss: 0.05123
# Epoch 4919 - lr: 0.01000 - Train loss: 0.04256 - Test loss: 0.05123
# Epoch 4920 - lr: 0.01000 - Train loss: 0.04256 - Test loss: 0.05123
# Epoch 4921 - lr: 0.01000 - Train loss: 0.04256 - Test loss: 0.05123
# Epoch 4922 - lr: 0.01000 - Train loss: 0.04255 - Test loss: 0.05123
# Epoch 4923 - lr: 0.01000 - Train loss: 0.04255 - Test loss: 0.05123
# Epoch 4924 - lr: 0.01000 - Train loss: 0.04255 - Test loss: 0.05123
# Epoch 4925 - lr: 0.01000 - Train loss: 0.04254 - Test loss: 0.05123
# Epoch 4926 - lr: 0.01000 - Train loss: 0.04254 - Test loss: 0.05123
# Epoch 4927 - lr: 0.01000 - Train loss: 0.04254 - Test loss: 0.05123
# Epoch 4928 - lr: 0.01000 - Train loss: 0.04254 - Test loss: 0.05123
# Epoch 4929 - lr: 0.01000 - Train loss: 0.04253 - Test loss: 0.05123
# Epoch 4930 - lr: 0.01000 - Train loss: 0.04253 - Test loss: 0.05123
# Epoch 4931 - lr: 0.01000 - Train loss: 0.04253 - Test loss: 0.05123
# Epoch 4932 - lr: 0.01000 - Train loss: 0.04252 - Test loss: 0.05123
# Epoch 4933 - lr: 0.01000 - Train loss: 0.04252 - Test loss: 0.05123
# Epoch 4934 - lr: 0.01000 - Train loss: 0.04252 - Test loss: 0.05123
# Epoch 4935 - lr: 0.01000 - Train loss: 0.04251 - Test loss: 0.05123
# Epoch 4936 - lr: 0.01000 - Train loss: 0.04251 - Test loss: 0.05123
# Epoch 4937 - lr: 0.01000 - Train loss: 0.04251 - Test loss: 0.05123
# Epoch 4938 - lr: 0.01000 - Train loss: 0.04251 - Test loss: 0.05123
# Epoch 4939 - lr: 0.01000 - Train loss: 0.04250 - Test loss: 0.05123
# Epoch 4940 - lr: 0.01000 - Train loss: 0.04250 - Test loss: 0.05123
# Epoch 4941 - lr: 0.01000 - Train loss: 0.04250 - Test loss: 0.05123
# Epoch 4942 - lr: 0.01000 - Train loss: 0.04249 - Test loss: 0.05123
# Epoch 4943 - lr: 0.01000 - Train loss: 0.04249 - Test loss: 0.05123
# Epoch 4944 - lr: 0.01000 - Train loss: 0.04249 - Test loss: 0.05123
# Epoch 4945 - lr: 0.01000 - Train loss: 0.04249 - Test loss: 0.05123
# Epoch 4946 - lr: 0.01000 - Train loss: 0.04248 - Test loss: 0.05123
# Epoch 4947 - lr: 0.01000 - Train loss: 0.04248 - Test loss: 0.05123
# Epoch 4948 - lr: 0.01000 - Train loss: 0.04248 - Test loss: 0.05123
# Epoch 4949 - lr: 0.01000 - Train loss: 0.04247 - Test loss: 0.05123
# Epoch 4950 - lr: 0.01000 - Train loss: 0.04247 - Test loss: 0.05123
# Epoch 4951 - lr: 0.01000 - Train loss: 0.04247 - Test loss: 0.05123
# Epoch 4952 - lr: 0.01000 - Train loss: 0.04246 - Test loss: 0.05123
# Epoch 4953 - lr: 0.01000 - Train loss: 0.04246 - Test loss: 0.05123
# Epoch 4954 - lr: 0.01000 - Train loss: 0.04246 - Test loss: 0.05123
# Epoch 4955 - lr: 0.01000 - Train loss: 0.04246 - Test loss: 0.05123
# Epoch 4956 - lr: 0.01000 - Train loss: 0.04245 - Test loss: 0.05123
# Epoch 4957 - lr: 0.01000 - Train loss: 0.04245 - Test loss: 0.05123
# Epoch 4958 - lr: 0.01000 - Train loss: 0.04245 - Test loss: 0.05123
# Epoch 4959 - lr: 0.01000 - Train loss: 0.04244 - Test loss: 0.05123
# Epoch 4960 - lr: 0.01000 - Train loss: 0.04244 - Test loss: 0.05123
# Epoch 4961 - lr: 0.01000 - Train loss: 0.04244 - Test loss: 0.05123
# Epoch 4962 - lr: 0.01000 - Train loss: 0.04243 - Test loss: 0.05123
# Epoch 4963 - lr: 0.01000 - Train loss: 0.04243 - Test loss: 0.05123
# Epoch 4964 - lr: 0.01000 - Train loss: 0.04243 - Test loss: 0.05123
# Epoch 4965 - lr: 0.01000 - Train loss: 0.04243 - Test loss: 0.05123
# Epoch 4966 - lr: 0.01000 - Train loss: 0.04242 - Test loss: 0.05123
# Epoch 4967 - lr: 0.01000 - Train loss: 0.04242 - Test loss: 0.05123
# Epoch 4968 - lr: 0.01000 - Train loss: 0.04242 - Test loss: 0.05123
# Epoch 4969 - lr: 0.01000 - Train loss: 0.04241 - Test loss: 0.05123
# Epoch 4970 - lr: 0.01000 - Train loss: 0.04241 - Test loss: 0.05123
# Epoch 4971 - lr: 0.01000 - Train loss: 0.04241 - Test loss: 0.05123
# Epoch 4972 - lr: 0.01000 - Train loss: 0.04240 - Test loss: 0.05123
# Epoch 4973 - lr: 0.01000 - Train loss: 0.04240 - Test loss: 0.05123
# Epoch 4974 - lr: 0.01000 - Train loss: 0.04240 - Test loss: 0.05123
# Epoch 4975 - lr: 0.01000 - Train loss: 0.04240 - Test loss: 0.05123
# Epoch 4976 - lr: 0.01000 - Train loss: 0.04239 - Test loss: 0.05123
# Epoch 4977 - lr: 0.01000 - Train loss: 0.04239 - Test loss: 0.05123
# Epoch 4978 - lr: 0.01000 - Train loss: 0.04239 - Test loss: 0.05123
# Epoch 4979 - lr: 0.01000 - Train loss: 0.04238 - Test loss: 0.05123
# Epoch 4980 - lr: 0.01000 - Train loss: 0.04238 - Test loss: 0.05124
# Epoch 4981 - lr: 0.01000 - Train loss: 0.04238 - Test loss: 0.05124
# Epoch 4982 - lr: 0.01000 - Train loss: 0.04237 - Test loss: 0.05124
# Epoch 4983 - lr: 0.01000 - Train loss: 0.04237 - Test loss: 0.05124
# Epoch 4984 - lr: 0.01000 - Train loss: 0.04237 - Test loss: 0.05124
# Epoch 4985 - lr: 0.01000 - Train loss: 0.04237 - Test loss: 0.05124
# Epoch 4986 - lr: 0.01000 - Train loss: 0.04236 - Test loss: 0.05124
# Epoch 4987 - lr: 0.01000 - Train loss: 0.04236 - Test loss: 0.05124
# Epoch 4988 - lr: 0.01000 - Train loss: 0.04236 - Test loss: 0.05124
# Epoch 4989 - lr: 0.01000 - Train loss: 0.04235 - Test loss: 0.05124
# Epoch 4990 - lr: 0.01000 - Train loss: 0.04235 - Test loss: 0.05124
# Epoch 4991 - lr: 0.01000 - Train loss: 0.04235 - Test loss: 0.05124
# Epoch 4992 - lr: 0.01000 - Train loss: 0.04234 - Test loss: 0.05124
# Epoch 4993 - lr: 0.01000 - Train loss: 0.04234 - Test loss: 0.05124
# Epoch 4994 - lr: 0.01000 - Train loss: 0.04234 - Test loss: 0.05124
# Epoch 4995 - lr: 0.01000 - Train loss: 0.04234 - Test loss: 0.05124
# Epoch 4996 - lr: 0.01000 - Train loss: 0.04233 - Test loss: 0.05124
# Epoch 4997 - lr: 0.01000 - Train loss: 0.04233 - Test loss: 0.05124
# Epoch 4998 - lr: 0.01000 - Train loss: 0.04233 - Test loss: 0.05124
# Epoch 4999 - lr: 0.01000 - Train loss: 0.04232 - Test loss: 0.05124
# Epoch 5000 - lr: 0.01000 - Train loss: 0.04232 - Test loss: 0.05124

# %% [markdown]
# Plot train and test loss during training

# %%
plt.close('all')
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(test_loss_log, label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot weights after training

# %%
net.plot_weights()
# Out:
# No handles with labels found to put in legend.

# %%
### FORWARD PASS (after training)
net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, net_output, color='g', ls='--', label='Network output (trained weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Now the output is better, but it can still be improved by a large margin. Try to improve it by changing the network structure and the training hyper-parameters, but remember: **THIS MUST BE DONE ON A VALIDATION SET!**

# %% [markdown]
# # Analyze activations

# %% [markdown]
# By enabling the *additional_out* parameter of the *forward* method, we can see the activations of the last layer for a given input. Let's try with 3 different input values: $x=0.1$, $x=0.9$ and $x=2.5$.

# %%
x1 = 0.1
y1, z1 = net.forward(x1, additional_out=True)
x2 = 0.9
y2, z2 = net.forward(x2, additional_out=True)
x3 = 2.5
y3, z3 = net.forward(x3, additional_out=True)

fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1, use_line_collection=True)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2, use_line_collection=True)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3, use_line_collection=True)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# As you may have noticed, some neurons are contributing much more than the others. Maybe the number of neurons is too high? Try to make some changes and see what happens.
#
# In the last case the input is $x=2.5$, far away from the training space $[0,1]$. The behavior of the network seems to be quite confused, maybe it is not generalizing very well, try to do some tests to check this hypothesis.
