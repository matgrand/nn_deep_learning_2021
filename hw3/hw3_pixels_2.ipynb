# %% [markdown]
# # HOMEWORK 3 NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2021/22 (6 CFU) - Dr. Alberto Testolin, Dr. Umberto Michieli
# ---
# Student: Matteo Grandin
# ---
# id: 2020374

# %% [markdown]
# # Reinforced Learning

# %% [markdown]
# ### General overview
# In this homework you will learn how to implement and test neural network models for
# solving reinforcement learning problems. The basic tasks for the homework will require to implement some
# extensions to the code that you have seen in the Lab. The advanced tasks will require to train and test your
# learning agent on a different type of input (image pixels) or Gym environment. You can just choose one of
# the advanced tasks to get the maximum grade. If you are interested in improving your skills, feel free to try
# both advanced tasks. Given the higher computational complexity of RL, in this homework you don’t need to
# tune learning hyperparameters using search procedures and cross-validation; however, you are encouraged
# to play with model hyperparameters to find a satisfactory configuration.
#
#
# - 3 pt: use the notebook of Lab 07 to study how the exploration profile (either using eps-greedy or
# softmax) impacts the learning curve. Tune a bit the model hyperparameters or tweak the reward
# function to speed-up learning convergence (i.e., reach the same accuracy with fewer training episodes).
#
# YOU CAN DO JUST 1 OR BOTH
# - 5 pt: extend the notebook used in Lab 07, in order to learn to control the CartPole environment using
# directly the screen pixels, rather than the compact state representation used during the Lab (cart
# position, cart velocity, pole angle, pole angular velocity). NB: this will require to change the
# “observation_space” and to look for smart ways of encoding the pixels in a compact way to reduce
# computational complexity (e.g., crop the image around the pole, use difference of consecutive frames
# as input to consider temporal context, etc.).
#
# OR
#
# - 5 pt: train a deep RL agent on a different Gym environment. You are free to choose whatever Gym
# environment you like from the available list, or even explore other simulation platforms.

# %%
# Boolean value to check if we are in colab or not
colab = False 
show_video = False
show_render = False

# %%
if colab:
    # !pip install gym
else:
    # %pip install gym
# Out:
# Requirement already satisfied: gym in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (4.8.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import torch
import numpy as np
import gym
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torch.nn.functional as F
import os
from torch import nn
from collections import deque # this python module implements exactly what we need for the replay memeory

#import opencv
import cv2

#use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")

#create a folder called training
if not os.path.exists('training'):
    os.makedirs('training')

# %%
if colab:
    # !apt update
    # !apt-get install python-opengl -y
    # !apt install xvfb -y
    # !pip install pyvirtualdisplay
    # !pip install piglet
    import glob
    import io
    import base64
    import os
    from IPython.display import HTML
    from IPython import display as ipythondisplay
    from pyvirtualdisplay import Display
    from gym.wrappers import Monitor

    display = Display(visible=0, size=(1400, 900))
    display.start()

    if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
        # !bash ../xvfb start
        # %env DISPLAY=:1

    """
    Utility functions to enable video recording of gym environment and displaying it
    To enable video, just do "env = wrap_env(env)""
    """

    def show_videos():
        mp4list = glob.glob('video/*.mp4')
        mp4list.sort()
        for mp4 in mp4list:
            print(f"\nSHOWING VIDEO {mp4}")
            video = io.open(mp4, 'r+b').read()
            encoded = base64.b64encode(video)
            ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                        loop controls style="height: 400px;">
                        <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                    </video>'''.format(encoded.decode('ascii'))))
            
    def wrap_env(env, video_callable=None):
        env = Monitor(env, './video', force=True, video_callable=video_callable)
        return env

# %%
class ReplayMemory(object):

    def __init__(self, capacity, x=32, y=16):
        #if x and y are small u can fit everything in gpu memory
        self.memory = torch.zeros((capacity, 3, y, x), dtype=torch.float32, device=device) #capacity, action, reward, 2 states
        self.x = x
        self.y = y 
        self.memory_index = 0
        self.capacity = capacity
        self.full = False
        #self.memory = deque(maxlen=capacity) # Define a queue with maxlen "capacity"

    def push(self, state, action, next_state, reward, dyn):
        if state is None or action is None or reward is None:
            print("WARNING: None value passed to ReplayMemory.push()")
            return
        # TODO: Add the tuple (state, action, next_state, reward) to the queue
        self.memory[self.memory_index][0] = torch.from_numpy(state).float().to(device)
        self.memory[self.memory_index][1,0,0] = action
        self.memory[self.memory_index][1,1,0] = reward
        self.memory[self.memory_index][1,8,:4] = torch.from_numpy(dyn).float().to(device)
        if next_state is not None:
            self.memory[self.memory_index][2] = torch.from_numpy(next_state).float().to(device) 
            self.memory[self.memory_index][1,1,1] = 1 # bool true
        else:
            self.memory[self.memory_index][1,1,1] = 0 #mask is false
        #increase the index, and wrap it around if it is bigger than the capacity
        if self.memory_index == self.capacity-1:
            self.full = True
        self.memory_index = (self.memory_index + 1) % self.memory.shape[0]
        
        # self.memory.append((state, action, next_state, reward))
        # print(f"state: {state.shape}, action: {action}, next_state: {next_state.shape}, reward: {reward}")

    def sample(self, batch_size):
        batch_size = min(batch_size, len(self)) # Get all the samples if the requested batch_size is higher than the number of sample currently in the memory
        # select indeces
        pull = self.capacity if self.full else self.memory_index-1
        indeces = np.random.choice(pull, batch_size, replace=False)
        # return the samples
        ret = self.memory[indeces, :]
        # ret = torch.from_numpy(ret).float().to(device)
        states = ret[:,0].unsqueeze(1)
        actions = ret[:,1,0,0].long()
        rewards = ret[:,1,1,0]
        dyn = ret[:,1,8,:4].float()
        non_final_mask = ret[:,1,1,1].bool()
        non_final_next_states = ret[:,2].unsqueeze(1)
        non_final_next_states = non_final_next_states[non_final_mask]

        #print(f"states: {states.shape}, actions: {actions.shape}, rewards: {rewards.shape}, non_final_next_states: {non_final_next_states.shape}, non_final_mask: {non_final_mask.shape}")

        return states, actions, rewards, non_final_next_states, non_final_mask, dyn
        # return random.sample(self.memory, batch_size) # Randomly select "batch_size" samples

    def __len__(self):
        if self.full:
            return self.capacity
        else:
            return self.memory_index
        # return len(self.memory) # Return the number of samples currently stored in the memory

# %%
class DQN(nn.Module):

    def __init__(self, state_space_dim, action_space_dim):
        super().__init__()
        n_hid = 128
        
        self.conv = nn.Sequential( #128x64 #32x32
            # First convolutional layer
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=4, stride=2), #61x29 #15x15
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=2), #19x8 #7x7
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=2), #7x1 #3x3
            nn.ReLU(True),
        )

        self.flatten = nn.Flatten()
        
        self.linear = nn.Sequential(
            
            #inpt layer
            nn.Linear(64*3*3, n_hid), 
            nn.ReLU(True),
            # nn.Tanh(),
            #nn.Dropout(0.2), #bad
            #hidden layer
            nn.Linear(n_hid, n_hid),
            nn.ReLU(True),
            # nn.Tanh(),
            #nn.Dropout(0.2), #bad
            #outpt layer
            nn.Linear(n_hid, action_space_dim),
                )

    def forward(self, x):
        x = self.conv(x)
        x = self.flatten(x)
        x = self.linear(x)
        return x

# %% [markdown]
# ## Exploration Policy

# %%
def choose_action_epsilon_greedy(net, state, epsilon):
    if epsilon > 1 or epsilon < 0:
        raise Exception('The epsilon value must be between 0 and 1')
                
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = state[np.newaxis, :]
        state = torch.tensor(state, dtype=torch.float32,device=device) # Convert the state to tensor
        net_out = net(state)
        net_out = net_out[:,:2]
        

    # Get the best action (argmax of the network output)
    best_action = int(net_out.argmax())
    # Get the number of possible actions
    action_space_dim = net_out.shape[-1]

    # Select a non optimal action with probability epsilon, otherwise choose the best action
    if random.random() < epsilon:
        # List of non-optimal actions
        non_optimal_actions = [a for a in range(action_space_dim) if a != best_action]
        # Select randomly
        action = random.choice(non_optimal_actions)
    else:
        # Select best action
        action = best_action
        
    return action, net_out.cpu().numpy()

# %%
def choose_action_softmax(net, state, temperature):
    if temperature < 0:
        raise Exception('The temperature value must be greater than or equal to 0 ')
        
    # If the temperature is 0, just select the best action using the eps-greedy policy with epsilon = 0
    if temperature == 0:
        return choose_action_epsilon_greedy(net, state, 0)
    
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(1)
        net_out = net(state)
        net_out = net_out[:,:2]

    # Apply softmax with temp
    temperature = max(temperature, 1e-8) # set a minimum to the temperature for numerical stability
    softmax_out = F.softmax(net_out/temperature, dim=1).squeeze().cpu().numpy()
                
    # Sample the action using softmax output as mass pdf
    all_possible_actions = np.arange(0, softmax_out.shape[-1])
    # print(f"softmax_out: {softmax_out}, all_possible_actions: {all_possible_actions}")
    action = np.random.choice(all_possible_actions, p=softmax_out) # this samples a random element from "all_possible_actions" with the probability distribution p (softmax_out in this case)
    
    return action, net_out.cpu().numpy()

# %% [markdown]
# ### Exploration profile

# %%
### Define exploration profile
def get_exploration_profile(initial_value=0.5, num_iterations=1000, speed = 3): # speed = speed of convergence, bigger is faster to reach 0
    if initial_value < 0:
        raise Exception('The initial value must be > 0')
    if initial_value > 1:
        exp_decay = np.exp(-np.log(initial_value) / num_iterations * speed) # We compute the exponential decay in such a way the shape of the exploration profile does not depend on the number of iterations
    else :
        exp_decay = np.exp(np.log(initial_value) / num_iterations * speed)
    exploration_profile = [initial_value * (exp_decay ** i) for i in range(num_iterations)]
    return exploration_profile

exploration_profile = get_exploration_profile()

### Plot exploration profile
plt.figure(figsize=(12,3))
plt.plot(exploration_profile)
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Exploration profile (Softmax temperature)')
# Out:
# Text(0, 0.5, 'Exploration profile (Softmax temperature)')

# %% [markdown]
# # Gym Environment (CartPole-v1)

# %%
### Create environment
env = gym.make('CartPole-v1') # Initialize the Gym environment
env.seed(0) # Set a random seed for the environment (reproducible results)

# Get the shapes of the state space (observation_space) and action space (action_space)
# state_space_dim = env.observation_space.shape[0]
action_space_dim = env.action_space.n  #

if colab:
  env = wrap_env(env, video_callable=lambda episode_id: True)

# %%
#function to get the frame
def get_frame(env, prev_frame, resize=(32,32), device=device, plot=False):
    # Get the current frame 
    frame = env.render(mode='rgb_array')
    pos = env.state[0] #-2.4 to 2.4 in the frame
    c = round(pos*300/2.4 + 300) #center of the cart
    #convert to grayscale
    frame = np.mean(frame, axis=2)
    original_frame = frame
    #convert to binary
    frame[frame < 255] = 0
    frame = frame / 255
    frame = (1 - frame) 
    frame[frame==0] = 1/3
    frame[frame==1] = 2/3    

    if prev_frame is not None:
        diff = 2*frame - prev_frame
    else :
        diff = frame / 2

    prev_frame = frame

    #draw a small square in the absolute middle of diff
    diff[150:170,270:274] = 0.1
    diff[150:170,326:330] = 0.9
    
    if c < 64 or c > (600-64): #out of frame
        diff = np.zeros((300,300))
    else:
        diff = diff[150:300, (c-64):(c+64)]

    diff = cv2.resize(diff, resize, interpolation=cv2.INTER_CUBIC)
    diff = diff[np.newaxis, :]

    if plot and not colab:
        #show diff with opencv
        cv2.imshow('diff', diff[0])
        #cv2.imshow('prev_frame',prev_frame)
        cv2.waitKey(1)
    
    return diff, prev_frame

# %%
# if not colab:
#     env.seed(1)
#     observation = env.reset()
#     #set seed
#     frame, prev_frame = get_frame(env, None)
#     for t in range(500):
#         frame, prev_frame = get_frame(env, prev_frame, plot=True)
#         action = env.action_space.sample()
#         observation, reward, done, info = env.step(action)
#         done = False

#         c = env.state[0]*300/2.4 + 300
#         #if c < 64 or c > (600-64):
#             #done = True #doesn't work in colab
        
#         if done:
#             print("Episode finished after {} timesteps".format(t+1))
#             break
#     env.close()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Network update

# %%
# ### PARAMETERS
# gamma = 0.95  #0.97 gamma parameter for the long term reward #0.99999 # 0.9
# replay_memory_capacity = 10000   #10000 Replay memory capacity #10000 # 5000
# lr = 2e-2   #1e-2 Optimizer learning rate #1e-2 # 0.12
# target_net_update_steps = 10   #10 Number of episodes to wait before updating the target network #10 # 8
# batch_size = 256   #128 Number of samples to take from the replay memory for each update #256 # 256
# bad_state_penalty = 0  #0 Penalty to the reward when we are in a bad state (in this case when the pole falls down)  #0 # 0
# min_samples_for_training = 1111   #1000 Minimum samples in the replay memory to enable the training #1000 # 500
# use_epsilon_greedy = False   #False Use epsilon greedy exploration or not #True # False
# #set up exploration profile for softmax
# initial_value = 5 #5 Initial temperature/epsilon value for the exploration profile #0.5 # 5
# num_iterations = 1700 # Number of episodes 1000, #300 # 120
# convergence_speed = 6 #6 Speed of convergence of the exploration profile # 1 # 0.8
# exploration_profile = get_exploration_profile(initial_value, num_iterations, speed = convergence_speed)

# %%
# Set random seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

laod_good_model = False

x,y = 32,32 #32, 16
state_space_dim = x * y #the image is 32*16

### PARAMETERS
gamma = 0.95   #0.97 gamma parameter for the long term reward #0.99999 # 0.9
replay_memory_capacity = 10000   #10000 Replay memory capacity #10000 # 5000
lr = 3e-2   #1e-2 Optimizer learning rate #1e-2 # 0.12
target_net_update_steps = 5   #10 Number of episodes to wait before updating the target network #10 # 8
batch_size = 128   #128 Number of samples to take from the replay memory for each update #256 # 256
bad_state_penalty = 0   #0 Penalty to the reward when we are in a bad state (in this case when the pole falls down)  #0 # 0
min_samples_for_training = 1000   #1000 Minimum samples in the replay memory to enable the training #1000 # 500
use_epsilon_greedy = False   #False Use epsilon greedy exploration or not #True # False
#set up exploration profile for softmax
initial_value = 5 #5 Initial temperature/epsilon value for the exploration profile #0.5 # 5
num_iterations = 1000 # Number of episodes 1000, #300 # 120
convergence_speed = 6 #6 Speed of convergence of the exploration profile # 1 # 0.8
exploration_profile = get_exploration_profile(initial_value, num_iterations, speed = convergence_speed)

# %% [markdown]
# lowering target_net_update_steps from 10 to 8 had a huge impact, learning rate could be set higher too and gamma could be lowered.

# %%
### Initialize the replay memory
replay_mem = ReplayMemory(replay_memory_capacity, x=x, y=y)

### Initialize the policy network
policy_net = DQN(state_space_dim, action_space_dim +4).to(device) #+4 because we want to use the state to finetune the network

### Initialize the target network with the same weights of the policy network
target_net = DQN(state_space_dim, action_space_dim+4).to(device) #+4 because we want to use the state to finetune the network
target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

### Initialize the optimizer
optimizer = torch.optim.SGD(policy_net.parameters(), lr=lr) # The optimizer will update ONLY the parameters of the policy network

### Initialize the loss function (Huber loss)
loss_fn = nn.SmoothL1Loss()

losses, dyn_losses, scores = [],[],[]

# %%
def update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size):
        
  # Sample the data from the replay memory
  states, actions, rewards, non_final_next_states, non_final_mask, dyn = replay_mem.sample(batch_size)


  # Compute all the Q values (forward pass)
  policy_net.train()
  out = policy_net(states)
  q_values = out[:,:action_space_dim]
  dyn_pred = out[:,action_space_dim:]

  dyn_loss_fn = nn.MSELoss()
  dyn_loss = 8.0*dyn_loss_fn(dyn_pred, dyn) #dyn_pred is the predicted dynamics, dyn is the actual dynamics
  #print(f'Dyn loss: {dyn_loss}')

  # Select the proper Q value for the corresponding action taken Q(s_t, a)
  state_action_values = q_values.gather(1, actions.unsqueeze(1))

  # Compute the value function of the next states using the target network V(s_{t+1}) = max_a( Q_target(s_{t+1}, a)) )
  with torch.no_grad():
    target_net.eval()
    out = target_net(non_final_next_states)
    q_values_target = out[:,:action_space_dim]
  next_state_max_q_values = torch.zeros(batch_size, device=device)
  next_state_max_q_values[non_final_mask] = q_values_target.max(dim=1)[0]

  # Compute the expected Q values
  expected_state_action_values = rewards + (next_state_max_q_values * gamma)
  expected_state_action_values = expected_state_action_values.unsqueeze(1) # Set the required tensor shape

  # Compute the Huber loss
  loss = loss_fn(state_action_values, expected_state_action_values)

  # Optimize the model
  optimizer.zero_grad()
  loss.backward(retain_graph=True)
  dyn_loss.backward() #backpropagate the dynamics loss
  # Apply gradient clipping (clip all the gradients greater than 2 for training stability)
  nn.utils.clip_grad_norm_(policy_net.parameters(), 2)
  optimizer.step()
  return loss.item(), dyn_loss.item()

# %%
if not laod_good_model: #TRAIN
    # Initialize the Gym environment
    env = gym.make('CartPole-v1') 
    env.seed(0) # Set a random seed for the environment (reproducible results)

    # This is for creating the output video in Colab, not required outside Colab
    if colab:
        env = wrap_env(env, video_callable=lambda episode_id: episode_id % 100 == 0) # Save a video every 100 episodes

    good_scores_counter = 0

    #list of losses and scores
    for episode_num, tau in enumerate(tqdm(exploration_profile)):
        if use_epsilon_greedy:
            epsilon = tau

        # Reset the environment and get the initial state
        dyn = env.reset()
        state, prev_frame = get_frame(env, None, resize=(x,y))
        # Reset the score. The final score will be the total amount of steps before the pole falls
        score = 0
        done = False

        tot_reward = 0

        # Go on until the pole falls off
        episode_loss = []
        episode_dyn_loss = []
        while not done:
            # Choose the action following the policy
            action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=tau)
            
            # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
            dyn, reward, done, info = env.step(action)
            next_state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=True)

            #penalty based on the cart being off the screen
            c = env.state[0]*300/2.4 + 300
            if c < 64 or c > (600-64):
                reward -= 100
            
            # We apply a (linear) penalty when the cart is far from center
            pos_weight = 1.0
            reward = reward - pos_weight * np.abs(dyn[0]) 

            #linear penalty for the angle
            angle_weight = 4.0
            reward = reward - angle_weight * np.abs(dyn[2])

            # Update the final score (+1 for each step)
            score += 1

            # Apply penalty for bad state
            if done: # if the pole has fallen down 
                reward += bad_state_penalty
                next_state = None

            tot_reward += reward

            # Update the replay memory
            replay_mem.push(state, action, next_state, reward, dyn)

            # # lower learning rate after a certain number of steps, important if the learning rate is very aggressive
            # # in the early stages of the training 
            # if episode_num > 120:
            #     for param_group in optimizer.param_groups:
            #         param_group['lr'] = 2e-3


            # Update the network
            if len(replay_mem) > min_samples_for_training: # we enable the training only if we have enough samples in the replay memory, otherwise the training will use the same samples too often
                loss, dyn_loss = update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size)
                episode_loss.append(loss)
                episode_dyn_loss.append(dyn_loss)

                
            # Visually render the environment (disable to speed up the training)
            if not colab and show_render:
                env.render()

            # Set the current state for the next iteration
            state = next_state
        #end of while loop

        #get episode loss
        average_episode_loss = np.mean(episode_loss)
        losses.append(average_episode_loss)
        average_episode_dyn_loss = np.mean(episode_dyn_loss)
        dyn_losses.append(average_episode_dyn_loss)
        #get episode score
        scores.append(score)

        # Update the target network every target_net_update_steps episodes
        if episode_num % target_net_update_steps == 0:
            #print('Updating target network...')
            target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

        # #tests
        # if score > 300:
        #   optimizer = torch.optim.SGD(policy_net.parameters(), lr=1e-2) ###############################################################################
        #   if score > 400:
        #     optimizer = torch.optim.SGD(policy_net.parameters(), lr=5e-3) ###############################################################################
        # if score < 100:
        #     optimizer = torch.optim.SGD(policy_net.parameters(), lr=3e-2)

        if episode_num > 0.6*num_iterations:
            break 
        #Print the final score
        print(f"EPISODE: {episode_num + 1} - FINAL SCORE: {score} - Temp/epsilon: {tau:.4f}, Loss: {average_episode_loss:.2f} - Dyn Loss: {average_episode_dyn_loss:.2f} - Tot Reward: {tot_reward:.2f}")  
    env.close()


    #save the model
    torch.save(policy_net.state_dict(), f'training/cartpole_policy_net_{num_iterations}.pt')
    #save scores and losses
    np.save(f'training/cartpole_scores_{num_iterations}.npy', scores)
    np.save(f'training/cartpole_losses_{num_iterations}.npy', losses)
    np.save(f'training/cartpole_dyn_losses_{num_iterations}.npy', dyn_losses)

else: #LOAD MODEL
    #load the model
    policy_net.load_state_dict(torch.load(f'training/cartpole_policy_net_{num_iterations}.pt'))
    target_net.load_state_dict(torch.load(f'training/cartpole_policy_net_{num_iterations}.pt'))
    #load scores and losses
    scores = np.load(f'training/cartpole_scores_{num_iterations}.npy')
    losses = np.load(f'training/cartpole_losses_{num_iterations}.npy')
    dyn_losses = np.load(f'training/cartpole_dyn_losses_{num_iterations}.npy')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# EPISODE: 1 - FINAL SCORE: 12 - Temp/epsilon: 5.0000, Loss: nan - Dyn Loss: nan - Tot Reward: 7.18
# EPISODE: 2 - FINAL SCORE: 17 - Temp/epsilon: 4.9519, Loss: nan - Dyn Loss: nan - Tot Reward: 10.60
# EPISODE: 3 - FINAL SCORE: 41 - Temp/epsilon: 4.9044, Loss: nan - Dyn Loss: nan - Tot Reward: 26.08
# EPISODE: 4 - FINAL SCORE: 19 - Temp/epsilon: 4.8572, Loss: nan - Dyn Loss: nan - Tot Reward: 13.30
# EPISODE: 5 - FINAL SCORE: 24 - Temp/epsilon: 4.8105, Loss: nan - Dyn Loss: nan - Tot Reward: 15.19
# EPISODE: 6 - FINAL SCORE: 16 - Temp/epsilon: 4.7643, Loss: nan - Dyn Loss: nan - Tot Reward: 10.41
# EPISODE: 7 - FINAL SCORE: 30 - Temp/epsilon: 4.7185, Loss: nan - Dyn Loss: nan - Tot Reward: 19.62
# EPISODE: 8 - FINAL SCORE: 29 - Temp/epsilon: 4.6732, Loss: nan - Dyn Loss: nan - Tot Reward: 17.38
# EPISODE: 9 - FINAL SCORE: 15 - Temp/epsilon: 4.6283, Loss: nan - Dyn Loss: nan - Tot Reward: 10.24
# EPISODE: 10 - FINAL SCORE: 21 - Temp/epsilon: 4.5838, Loss: nan - Dyn Loss: nan - Tot Reward: 11.44
# EPISODE: 11 - FINAL SCORE: 31 - Temp/epsilon: 4.5397, Loss: nan - Dyn Loss: nan - Tot Reward: 19.05
# EPISODE: 12 - FINAL SCORE: 59 - Temp/epsilon: 4.4961, Loss: nan - Dyn Loss: nan - Tot Reward: 34.12
# EPISODE: 13 - FINAL SCORE: 29 - Temp/epsilon: 4.4529, Loss: nan - Dyn Loss: nan - Tot Reward: 17.99
# EPISODE: 14 - FINAL SCORE: 26 - Temp/epsilon: 4.4101, Loss: nan - Dyn Loss: nan - Tot Reward: 16.24
# EPISODE: 15 - FINAL SCORE: 18 - Temp/epsilon: 4.3677, Loss: nan - Dyn Loss: nan - Tot Reward: 10.64
# EPISODE: 16 - FINAL SCORE: 14 - Temp/epsilon: 4.3258, Loss: nan - Dyn Loss: nan - Tot Reward: 9.47
# EPISODE: 17 - FINAL SCORE: 17 - Temp/epsilon: 4.2842, Loss: nan - Dyn Loss: nan - Tot Reward: 12.77
# EPISODE: 18 - FINAL SCORE: 27 - Temp/epsilon: 4.2430, Loss: nan - Dyn Loss: nan - Tot Reward: 13.94
# EPISODE: 19 - FINAL SCORE: 20 - Temp/epsilon: 4.2022, Loss: nan - Dyn Loss: nan - Tot Reward: 11.54
# EPISODE: 20 - FINAL SCORE: 21 - Temp/epsilon: 4.1619, Loss: nan - Dyn Loss: nan - Tot Reward: 8.80
# EPISODE: 21 - FINAL SCORE: 19 - Temp/epsilon: 4.1219, Loss: nan - Dyn Loss: nan - Tot Reward: 8.78
# EPISODE: 22 - FINAL SCORE: 35 - Temp/epsilon: 4.0823, Loss: nan - Dyn Loss: nan - Tot Reward: 28.33
# EPISODE: 23 - FINAL SCORE: 13 - Temp/epsilon: 4.0430, Loss: nan - Dyn Loss: nan - Tot Reward: 7.80
# EPISODE: 24 - FINAL SCORE: 19 - Temp/epsilon: 4.0042, Loss: nan - Dyn Loss: nan - Tot Reward: 13.99
# EPISODE: 25 - FINAL SCORE: 15 - Temp/epsilon: 3.9657, Loss: nan - Dyn Loss: nan - Tot Reward: 8.96
# EPISODE: 26 - FINAL SCORE: 29 - Temp/epsilon: 3.9276, Loss: nan - Dyn Loss: nan - Tot Reward: 22.36
# EPISODE: 27 - FINAL SCORE: 13 - Temp/epsilon: 3.8898, Loss: nan - Dyn Loss: nan - Tot Reward: 9.00
# EPISODE: 28 - FINAL SCORE: 31 - Temp/epsilon: 3.8524, Loss: nan - Dyn Loss: nan - Tot Reward: 17.36
# EPISODE: 29 - FINAL SCORE: 16 - Temp/epsilon: 3.8154, Loss: nan - Dyn Loss: nan - Tot Reward: 9.73
# EPISODE: 30 - FINAL SCORE: 26 - Temp/epsilon: 3.7788, Loss: nan - Dyn Loss: nan - Tot Reward: 14.74
# EPISODE: 31 - FINAL SCORE: 9 - Temp/epsilon: 3.7424, Loss: nan - Dyn Loss: nan - Tot Reward: 4.64
# EPISODE: 32 - FINAL SCORE: 44 - Temp/epsilon: 3.7065, Loss: nan - Dyn Loss: nan - Tot Reward: 22.91
# EPISODE: 33 - FINAL SCORE: 19 - Temp/epsilon: 3.6709, Loss: nan - Dyn Loss: nan - Tot Reward: 10.05
# EPISODE: 34 - FINAL SCORE: 21 - Temp/epsilon: 3.6356, Loss: nan - Dyn Loss: nan - Tot Reward: 14.44
# EPISODE: 35 - FINAL SCORE: 18 - Temp/epsilon: 3.6006, Loss: nan - Dyn Loss: nan - Tot Reward: 9.13
# EPISODE: 36 - FINAL SCORE: 14 - Temp/epsilon: 3.5660, Loss: nan - Dyn Loss: nan - Tot Reward: 9.63
# EPISODE: 37 - FINAL SCORE: 15 - Temp/epsilon: 3.5318, Loss: nan - Dyn Loss: nan - Tot Reward: 8.89
# EPISODE: 38 - FINAL SCORE: 30 - Temp/epsilon: 3.4978, Loss: nan - Dyn Loss: nan - Tot Reward: 18.30
# EPISODE: 39 - FINAL SCORE: 36 - Temp/epsilon: 3.4642, Loss: nan - Dyn Loss: nan - Tot Reward: 20.40
# EPISODE: 40 - FINAL SCORE: 31 - Temp/epsilon: 3.4309, Loss: nan - Dyn Loss: nan - Tot Reward: 16.46
# EPISODE: 41 - FINAL SCORE: 18 - Temp/epsilon: 3.3980, Loss: nan - Dyn Loss: nan - Tot Reward: 11.14
# EPISODE: 42 - FINAL SCORE: 26 - Temp/epsilon: 3.3653, Loss: nan - Dyn Loss: nan - Tot Reward: 15.96
# EPISODE: 43 - FINAL SCORE: 16 - Temp/epsilon: 3.3330, Loss: nan - Dyn Loss: nan - Tot Reward: 8.12
# EPISODE: 44 - FINAL SCORE: 10 - Temp/epsilon: 3.3009, Loss: 0.22 - Dyn Loss: 1.95 - Tot Reward: 5.60
# EPISODE: 45 - FINAL SCORE: 16 - Temp/epsilon: 3.2692, Loss: 0.15 - Dyn Loss: 1.94 - Tot Reward: 11.41
# EPISODE: 46 - FINAL SCORE: 24 - Temp/epsilon: 3.2378, Loss: 0.09 - Dyn Loss: 2.09 - Tot Reward: 14.81
# EPISODE: 47 - FINAL SCORE: 21 - Temp/epsilon: 3.2067, Loss: 0.17 - Dyn Loss: 2.12 - Tot Reward: 13.55
# EPISODE: 48 - FINAL SCORE: 45 - Temp/epsilon: 3.1759, Loss: 0.07 - Dyn Loss: 2.02 - Tot Reward: 24.52
# EPISODE: 49 - FINAL SCORE: 12 - Temp/epsilon: 3.1453, Loss: 0.06 - Dyn Loss: 2.21 - Tot Reward: 6.12
# EPISODE: 50 - FINAL SCORE: 32 - Temp/epsilon: 3.1151, Loss: 0.06 - Dyn Loss: 2.19 - Tot Reward: 18.15
# EPISODE: 51 - FINAL SCORE: 34 - Temp/epsilon: 3.0852, Loss: 0.06 - Dyn Loss: 2.08 - Tot Reward: 23.98
# EPISODE: 52 - FINAL SCORE: 17 - Temp/epsilon: 3.0555, Loss: 0.11 - Dyn Loss: 1.96 - Tot Reward: 10.43
# EPISODE: 53 - FINAL SCORE: 21 - Temp/epsilon: 3.0262, Loss: 0.09 - Dyn Loss: 1.74 - Tot Reward: 12.99
# EPISODE: 54 - FINAL SCORE: 38 - Temp/epsilon: 2.9971, Loss: 0.08 - Dyn Loss: 1.79 - Tot Reward: 14.02
# EPISODE: 55 - FINAL SCORE: 19 - Temp/epsilon: 2.9683, Loss: 0.08 - Dyn Loss: 1.67 - Tot Reward: 11.05
# EPISODE: 56 - FINAL SCORE: 19 - Temp/epsilon: 2.9397, Loss: 0.09 - Dyn Loss: 1.75 - Tot Reward: 14.37
# EPISODE: 57 - FINAL SCORE: 50 - Temp/epsilon: 2.9115, Loss: 0.11 - Dyn Loss: 1.65 - Tot Reward: 27.15
# EPISODE: 58 - FINAL SCORE: 19 - Temp/epsilon: 2.8835, Loss: 0.09 - Dyn Loss: 1.55 - Tot Reward: 10.84
# EPISODE: 59 - FINAL SCORE: 24 - Temp/epsilon: 2.8558, Loss: 0.09 - Dyn Loss: 1.52 - Tot Reward: 16.79
# EPISODE: 60 - FINAL SCORE: 41 - Temp/epsilon: 2.8284, Loss: 0.08 - Dyn Loss: 1.44 - Tot Reward: 29.34
# EPISODE: 61 - FINAL SCORE: 19 - Temp/epsilon: 2.8012, Loss: 0.07 - Dyn Loss: 1.30 - Tot Reward: 10.69
# EPISODE: 62 - FINAL SCORE: 15 - Temp/epsilon: 2.7743, Loss: 0.16 - Dyn Loss: 1.31 - Tot Reward: 9.56
# EPISODE: 63 - FINAL SCORE: 51 - Temp/epsilon: 2.7476, Loss: 0.10 - Dyn Loss: 1.19 - Tot Reward: 31.45
# EPISODE: 64 - FINAL SCORE: 21 - Temp/epsilon: 2.7212, Loss: 0.10 - Dyn Loss: 1.02 - Tot Reward: 13.10
# EPISODE: 65 - FINAL SCORE: 20 - Temp/epsilon: 2.6950, Loss: 0.10 - Dyn Loss: 1.01 - Tot Reward: 10.73
# EPISODE: 66 - FINAL SCORE: 26 - Temp/epsilon: 2.6691, Loss: 0.09 - Dyn Loss: 0.89 - Tot Reward: 13.11
# EPISODE: 67 - FINAL SCORE: 17 - Temp/epsilon: 2.6435, Loss: 0.13 - Dyn Loss: 0.97 - Tot Reward: 7.79
# EPISODE: 68 - FINAL SCORE: 14 - Temp/epsilon: 2.6181, Loss: 0.12 - Dyn Loss: 0.92 - Tot Reward: 7.17
# EPISODE: 69 - FINAL SCORE: 15 - Temp/epsilon: 2.5929, Loss: 0.12 - Dyn Loss: 0.86 - Tot Reward: 8.10
# EPISODE: 70 - FINAL SCORE: 11 - Temp/epsilon: 2.5680, Loss: 0.11 - Dyn Loss: 0.88 - Tot Reward: 5.80
# EPISODE: 71 - FINAL SCORE: 28 - Temp/epsilon: 2.5433, Loss: 0.11 - Dyn Loss: 0.83 - Tot Reward: 15.77
# EPISODE: 72 - FINAL SCORE: 9 - Temp/epsilon: 2.5189, Loss: 0.21 - Dyn Loss: 0.78 - Tot Reward: 4.49
# EPISODE: 73 - FINAL SCORE: 17 - Temp/epsilon: 2.4947, Loss: 0.15 - Dyn Loss: 0.85 - Tot Reward: 10.37
# EPISODE: 74 - FINAL SCORE: 35 - Temp/epsilon: 2.4707, Loss: 0.16 - Dyn Loss: 0.79 - Tot Reward: 23.79
# EPISODE: 75 - FINAL SCORE: 39 - Temp/epsilon: 2.4470, Loss: 0.15 - Dyn Loss: 0.79 - Tot Reward: 18.21
# EPISODE: 76 - FINAL SCORE: 15 - Temp/epsilon: 2.4234, Loss: 0.12 - Dyn Loss: 0.83 - Tot Reward: 7.68
# EPISODE: 77 - FINAL SCORE: 17 - Temp/epsilon: 2.4002, Loss: 0.19 - Dyn Loss: 0.81 - Tot Reward: 10.32
# EPISODE: 78 - FINAL SCORE: 20 - Temp/epsilon: 2.3771, Loss: 0.28 - Dyn Loss: 0.71 - Tot Reward: 14.74
# EPISODE: 79 - FINAL SCORE: 13 - Temp/epsilon: 2.3542, Loss: 0.28 - Dyn Loss: 0.72 - Tot Reward: 7.65
# EPISODE: 80 - FINAL SCORE: 27 - Temp/epsilon: 2.3316, Loss: 0.20 - Dyn Loss: 0.80 - Tot Reward: 18.38
# EPISODE: 81 - FINAL SCORE: 23 - Temp/epsilon: 2.3092, Loss: 0.21 - Dyn Loss: 0.76 - Tot Reward: 17.60
# EPISODE: 82 - FINAL SCORE: 12 - Temp/epsilon: 2.2870, Loss: 0.21 - Dyn Loss: 0.77 - Tot Reward: 7.79
# EPISODE: 83 - FINAL SCORE: 35 - Temp/epsilon: 2.2650, Loss: 0.23 - Dyn Loss: 0.77 - Tot Reward: 26.30
# EPISODE: 84 - FINAL SCORE: 25 - Temp/epsilon: 2.2433, Loss: 0.21 - Dyn Loss: 0.77 - Tot Reward: 11.91
# EPISODE: 85 - FINAL SCORE: 14 - Temp/epsilon: 2.2217, Loss: 0.22 - Dyn Loss: 0.74 - Tot Reward: 8.56
# EPISODE: 86 - FINAL SCORE: 13 - Temp/epsilon: 2.2004, Loss: 0.17 - Dyn Loss: 0.78 - Tot Reward: 5.28
# EPISODE: 87 - FINAL SCORE: 13 - Temp/epsilon: 2.1792, Loss: 0.16 - Dyn Loss: 0.78 - Tot Reward: 8.25
# EPISODE: 88 - FINAL SCORE: 12 - Temp/epsilon: 2.1583, Loss: 0.27 - Dyn Loss: 0.69 - Tot Reward: 6.25
# EPISODE: 89 - FINAL SCORE: 21 - Temp/epsilon: 2.1375, Loss: 0.27 - Dyn Loss: 0.67 - Tot Reward: 9.96
# EPISODE: 90 - FINAL SCORE: 22 - Temp/epsilon: 2.1170, Loss: 0.19 - Dyn Loss: 0.77 - Tot Reward: 11.59
# EPISODE: 91 - FINAL SCORE: 16 - Temp/epsilon: 2.0967, Loss: 0.25 - Dyn Loss: 0.66 - Tot Reward: 8.48
# EPISODE: 92 - FINAL SCORE: 18 - Temp/epsilon: 2.0765, Loss: 0.23 - Dyn Loss: 0.68 - Tot Reward: 9.26
# EPISODE: 93 - FINAL SCORE: 28 - Temp/epsilon: 2.0565, Loss: 0.18 - Dyn Loss: 0.72 - Tot Reward: 18.88
# EPISODE: 94 - FINAL SCORE: 17 - Temp/epsilon: 2.0368, Loss: 0.18 - Dyn Loss: 0.77 - Tot Reward: 9.28
# EPISODE: 95 - FINAL SCORE: 14 - Temp/epsilon: 2.0172, Loss: 0.18 - Dyn Loss: 0.71 - Tot Reward: 9.39
# EPISODE: 96 - FINAL SCORE: 25 - Temp/epsilon: 1.9978, Loss: 0.20 - Dyn Loss: 0.68 - Tot Reward: 14.73
# EPISODE: 97 - FINAL SCORE: 21 - Temp/epsilon: 1.9786, Loss: 0.26 - Dyn Loss: 0.68 - Tot Reward: 15.58
# EPISODE: 98 - FINAL SCORE: 16 - Temp/epsilon: 1.9596, Loss: 0.23 - Dyn Loss: 0.72 - Tot Reward: 9.89
# EPISODE: 99 - FINAL SCORE: 40 - Temp/epsilon: 1.9408, Loss: 0.25 - Dyn Loss: 0.68 - Tot Reward: 23.83
# EPISODE: 100 - FINAL SCORE: 25 - Temp/epsilon: 1.9221, Loss: 0.22 - Dyn Loss: 0.69 - Tot Reward: 17.45
# EPISODE: 101 - FINAL SCORE: 15 - Temp/epsilon: 1.9037, Loss: 0.17 - Dyn Loss: 0.72 - Tot Reward: 9.23
# EPISODE: 102 - FINAL SCORE: 16 - Temp/epsilon: 1.8854, Loss: 0.25 - Dyn Loss: 0.65 - Tot Reward: 9.56
# EPISODE: 103 - FINAL SCORE: 44 - Temp/epsilon: 1.8672, Loss: 0.25 - Dyn Loss: 0.66 - Tot Reward: 27.03
# EPISODE: 104 - FINAL SCORE: 13 - Temp/epsilon: 1.8493, Loss: 0.20 - Dyn Loss: 0.70 - Tot Reward: 9.33
# EPISODE: 105 - FINAL SCORE: 55 - Temp/epsilon: 1.8315, Loss: 0.21 - Dyn Loss: 0.71 - Tot Reward: 40.70
# EPISODE: 106 - FINAL SCORE: 32 - Temp/epsilon: 1.8139, Loss: 0.23 - Dyn Loss: 0.64 - Tot Reward: 19.81
# EPISODE: 107 - FINAL SCORE: 15 - Temp/epsilon: 1.7965, Loss: 0.24 - Dyn Loss: 0.69 - Tot Reward: 10.20
# EPISODE: 108 - FINAL SCORE: 20 - Temp/epsilon: 1.7792, Loss: 0.22 - Dyn Loss: 0.69 - Tot Reward: 15.11
# EPISODE: 109 - FINAL SCORE: 18 - Temp/epsilon: 1.7621, Loss: 0.22 - Dyn Loss: 0.69 - Tot Reward: 12.48
# EPISODE: 110 - FINAL SCORE: 39 - Temp/epsilon: 1.7452, Loss: 0.22 - Dyn Loss: 0.68 - Tot Reward: 26.07
# EPISODE: 111 - FINAL SCORE: 22 - Temp/epsilon: 1.7284, Loss: 0.30 - Dyn Loss: 0.59 - Tot Reward: 13.92
# EPISODE: 112 - FINAL SCORE: 22 - Temp/epsilon: 1.7118, Loss: 0.19 - Dyn Loss: 0.70 - Tot Reward: 13.84
# EPISODE: 113 - FINAL SCORE: 17 - Temp/epsilon: 1.6954, Loss: 0.19 - Dyn Loss: 0.70 - Tot Reward: 8.98
# EPISODE: 114 - FINAL SCORE: 50 - Temp/epsilon: 1.6791, Loss: 0.22 - Dyn Loss: 0.64 - Tot Reward: 29.37
# EPISODE: 115 - FINAL SCORE: 12 - Temp/epsilon: 1.6629, Loss: 0.26 - Dyn Loss: 0.59 - Tot Reward: 6.72
# EPISODE: 116 - FINAL SCORE: 25 - Temp/epsilon: 1.6470, Loss: 0.20 - Dyn Loss: 0.70 - Tot Reward: 14.56
# EPISODE: 117 - FINAL SCORE: 12 - Temp/epsilon: 1.6311, Loss: 0.20 - Dyn Loss: 0.66 - Tot Reward: 7.78
# EPISODE: 118 - FINAL SCORE: 27 - Temp/epsilon: 1.6154, Loss: 0.20 - Dyn Loss: 0.67 - Tot Reward: 15.53
# EPISODE: 119 - FINAL SCORE: 10 - Temp/epsilon: 1.5999, Loss: 0.21 - Dyn Loss: 0.66 - Tot Reward: 5.99
# EPISODE: 120 - FINAL SCORE: 18 - Temp/epsilon: 1.5845, Loss: 0.21 - Dyn Loss: 0.67 - Tot Reward: 10.25
# EPISODE: 121 - FINAL SCORE: 17 - Temp/epsilon: 1.5693, Loss: 0.21 - Dyn Loss: 0.64 - Tot Reward: 9.17
# EPISODE: 122 - FINAL SCORE: 40 - Temp/epsilon: 1.5542, Loss: 0.21 - Dyn Loss: 0.64 - Tot Reward: 27.81
# EPISODE: 123 - FINAL SCORE: 19 - Temp/epsilon: 1.5393, Loss: 0.19 - Dyn Loss: 0.65 - Tot Reward: 11.22
# EPISODE: 124 - FINAL SCORE: 13 - Temp/epsilon: 1.5245, Loss: 0.18 - Dyn Loss: 0.67 - Tot Reward: 6.22
# EPISODE: 125 - FINAL SCORE: 13 - Temp/epsilon: 1.5099, Loss: 0.18 - Dyn Loss: 0.62 - Tot Reward: 7.95
# EPISODE: 126 - FINAL SCORE: 18 - Temp/epsilon: 1.4953, Loss: 0.19 - Dyn Loss: 0.63 - Tot Reward: 11.80
# EPISODE: 127 - FINAL SCORE: 13 - Temp/epsilon: 1.4810, Loss: 0.21 - Dyn Loss: 0.66 - Tot Reward: 7.91
# EPISODE: 128 - FINAL SCORE: 12 - Temp/epsilon: 1.4667, Loss: 0.19 - Dyn Loss: 0.62 - Tot Reward: 5.28
# EPISODE: 129 - FINAL SCORE: 26 - Temp/epsilon: 1.4527, Loss: 0.18 - Dyn Loss: 0.66 - Tot Reward: 18.90
# EPISODE: 130 - FINAL SCORE: 23 - Temp/epsilon: 1.4387, Loss: 0.20 - Dyn Loss: 0.64 - Tot Reward: 17.26
# EPISODE: 131 - FINAL SCORE: 19 - Temp/epsilon: 1.4249, Loss: 0.19 - Dyn Loss: 0.67 - Tot Reward: 12.15
# EPISODE: 132 - FINAL SCORE: 35 - Temp/epsilon: 1.4112, Loss: 0.21 - Dyn Loss: 0.65 - Tot Reward: 19.83
# EPISODE: 133 - FINAL SCORE: 24 - Temp/epsilon: 1.3976, Loss: 0.21 - Dyn Loss: 0.64 - Tot Reward: 16.72
# EPISODE: 134 - FINAL SCORE: 26 - Temp/epsilon: 1.3842, Loss: 0.20 - Dyn Loss: 0.62 - Tot Reward: 18.98
# EPISODE: 135 - FINAL SCORE: 22 - Temp/epsilon: 1.3709, Loss: 0.19 - Dyn Loss: 0.64 - Tot Reward: 13.89
# EPISODE: 136 - FINAL SCORE: 30 - Temp/epsilon: 1.3577, Loss: 0.20 - Dyn Loss: 0.62 - Tot Reward: 17.07
# EPISODE: 137 - FINAL SCORE: 22 - Temp/epsilon: 1.3447, Loss: 0.24 - Dyn Loss: 0.60 - Tot Reward: 16.55
# EPISODE: 138 - FINAL SCORE: 23 - Temp/epsilon: 1.3317, Loss: 0.20 - Dyn Loss: 0.66 - Tot Reward: 11.89
# EPISODE: 139 - FINAL SCORE: 16 - Temp/epsilon: 1.3189, Loss: 0.19 - Dyn Loss: 0.64 - Tot Reward: 9.50
# EPISODE: 140 - FINAL SCORE: 11 - Temp/epsilon: 1.3063, Loss: 0.20 - Dyn Loss: 0.62 - Tot Reward: 6.00
# EPISODE: 141 - FINAL SCORE: 11 - Temp/epsilon: 1.2937, Loss: 0.17 - Dyn Loss: 0.65 - Tot Reward: 7.20
# EPISODE: 142 - FINAL SCORE: 11 - Temp/epsilon: 1.2813, Loss: 0.22 - Dyn Loss: 0.60 - Tot Reward: 6.15
# EPISODE: 143 - FINAL SCORE: 23 - Temp/epsilon: 1.2690, Loss: 0.24 - Dyn Loss: 0.57 - Tot Reward: 16.50
# EPISODE: 144 - FINAL SCORE: 26 - Temp/epsilon: 1.2568, Loss: 0.21 - Dyn Loss: 0.66 - Tot Reward: 16.43
# EPISODE: 145 - FINAL SCORE: 20 - Temp/epsilon: 1.2447, Loss: 0.19 - Dyn Loss: 0.63 - Tot Reward: 12.49
# EPISODE: 146 - FINAL SCORE: 13 - Temp/epsilon: 1.2327, Loss: 0.22 - Dyn Loss: 0.60 - Tot Reward: 6.79
# EPISODE: 147 - FINAL SCORE: 15 - Temp/epsilon: 1.2209, Loss: 0.28 - Dyn Loss: 0.61 - Tot Reward: 8.80
# EPISODE: 148 - FINAL SCORE: 14 - Temp/epsilon: 1.2091, Loss: 0.28 - Dyn Loss: 0.55 - Tot Reward: 8.45
# EPISODE: 149 - FINAL SCORE: 61 - Temp/epsilon: 1.1975, Loss: 0.24 - Dyn Loss: 0.62 - Tot Reward: 43.09
# EPISODE: 150 - FINAL SCORE: 20 - Temp/epsilon: 1.1860, Loss: 0.24 - Dyn Loss: 0.60 - Tot Reward: 13.43
# EPISODE: 151 - FINAL SCORE: 15 - Temp/epsilon: 1.1746, Loss: 0.22 - Dyn Loss: 0.62 - Tot Reward: 9.98
# EPISODE: 152 - FINAL SCORE: 16 - Temp/epsilon: 1.1633, Loss: 0.30 - Dyn Loss: 0.58 - Tot Reward: 8.45
# EPISODE: 153 - FINAL SCORE: 25 - Temp/epsilon: 1.1522, Loss: 0.28 - Dyn Loss: 0.59 - Tot Reward: 9.80
# EPISODE: 154 - FINAL SCORE: 42 - Temp/epsilon: 1.1411, Loss: 0.28 - Dyn Loss: 0.61 - Tot Reward: 20.38
# EPISODE: 155 - FINAL SCORE: 19 - Temp/epsilon: 1.1301, Loss: 0.27 - Dyn Loss: 0.62 - Tot Reward: 12.48
# EPISODE: 156 - FINAL SCORE: 15 - Temp/epsilon: 1.1193, Loss: 0.25 - Dyn Loss: 0.65 - Tot Reward: 10.09
# EPISODE: 157 - FINAL SCORE: 15 - Temp/epsilon: 1.1085, Loss: 0.34 - Dyn Loss: 0.61 - Tot Reward: 10.35
# EPISODE: 158 - FINAL SCORE: 12 - Temp/epsilon: 1.0978, Loss: 0.31 - Dyn Loss: 0.63 - Tot Reward: 5.94
# EPISODE: 159 - FINAL SCORE: 21 - Temp/epsilon: 1.0873, Loss: 0.30 - Dyn Loss: 0.61 - Tot Reward: 13.78
# EPISODE: 160 - FINAL SCORE: 20 - Temp/epsilon: 1.0768, Loss: 0.30 - Dyn Loss: 0.63 - Tot Reward: 12.55
# EPISODE: 161 - FINAL SCORE: 34 - Temp/epsilon: 1.0665, Loss: 0.31 - Dyn Loss: 0.62 - Tot Reward: 21.41
# EPISODE: 162 - FINAL SCORE: 19 - Temp/epsilon: 1.0562, Loss: 0.34 - Dyn Loss: 0.62 - Tot Reward: 9.09
# EPISODE: 163 - FINAL SCORE: 11 - Temp/epsilon: 1.0461, Loss: 0.33 - Dyn Loss: 0.58 - Tot Reward: 6.96
# EPISODE: 164 - FINAL SCORE: 15 - Temp/epsilon: 1.0360, Loss: 0.33 - Dyn Loss: 0.60 - Tot Reward: 8.89
# EPISODE: 165 - FINAL SCORE: 27 - Temp/epsilon: 1.0261, Loss: 0.34 - Dyn Loss: 0.59 - Tot Reward: 19.56
# EPISODE: 166 - FINAL SCORE: 24 - Temp/epsilon: 1.0162, Loss: 0.35 - Dyn Loss: 0.62 - Tot Reward: 15.58
# EPISODE: 167 - FINAL SCORE: 35 - Temp/epsilon: 1.0065, Loss: 0.36 - Dyn Loss: 0.61 - Tot Reward: 19.56
# EPISODE: 168 - FINAL SCORE: 12 - Temp/epsilon: 0.9968, Loss: 0.37 - Dyn Loss: 0.65 - Tot Reward: 6.80
# EPISODE: 169 - FINAL SCORE: 18 - Temp/epsilon: 0.9872, Loss: 0.35 - Dyn Loss: 0.60 - Tot Reward: 12.21
# EPISODE: 170 - FINAL SCORE: 24 - Temp/epsilon: 0.9777, Loss: 0.34 - Dyn Loss: 0.59 - Tot Reward: 15.33
# EPISODE: 171 - FINAL SCORE: 13 - Temp/epsilon: 0.9683, Loss: 0.35 - Dyn Loss: 0.61 - Tot Reward: 7.93
# EPISODE: 172 - FINAL SCORE: 21 - Temp/epsilon: 0.9590, Loss: 0.38 - Dyn Loss: 0.59 - Tot Reward: 11.67
# EPISODE: 173 - FINAL SCORE: 19 - Temp/epsilon: 0.9498, Loss: 0.39 - Dyn Loss: 0.59 - Tot Reward: 11.75
# EPISODE: 174 - FINAL SCORE: 14 - Temp/epsilon: 0.9407, Loss: 0.40 - Dyn Loss: 0.59 - Tot Reward: 6.27
# EPISODE: 175 - FINAL SCORE: 13 - Temp/epsilon: 0.9316, Loss: 0.38 - Dyn Loss: 0.60 - Tot Reward: 7.39
# EPISODE: 176 - FINAL SCORE: 11 - Temp/epsilon: 0.9227, Loss: 0.38 - Dyn Loss: 0.59 - Tot Reward: 5.16
# EPISODE: 177 - FINAL SCORE: 13 - Temp/epsilon: 0.9138, Loss: 0.42 - Dyn Loss: 0.58 - Tot Reward: 7.67
# EPISODE: 178 - FINAL SCORE: 20 - Temp/epsilon: 0.9050, Loss: 0.41 - Dyn Loss: 0.62 - Tot Reward: 13.41
# EPISODE: 179 - FINAL SCORE: 42 - Temp/epsilon: 0.8963, Loss: 0.41 - Dyn Loss: 0.58 - Tot Reward: 34.40
# EPISODE: 180 - FINAL SCORE: 23 - Temp/epsilon: 0.8877, Loss: 0.40 - Dyn Loss: 0.60 - Tot Reward: 17.11
# EPISODE: 181 - FINAL SCORE: 27 - Temp/epsilon: 0.8792, Loss: 0.41 - Dyn Loss: 0.60 - Tot Reward: 14.99
# EPISODE: 182 - FINAL SCORE: 24 - Temp/epsilon: 0.8707, Loss: 0.45 - Dyn Loss: 0.57 - Tot Reward: 17.52
# EPISODE: 183 - FINAL SCORE: 12 - Temp/epsilon: 0.8624, Loss: 0.44 - Dyn Loss: 0.56 - Tot Reward: 6.99
# EPISODE: 184 - FINAL SCORE: 18 - Temp/epsilon: 0.8541, Loss: 0.44 - Dyn Loss: 0.62 - Tot Reward: 12.60
# EPISODE: 185 - FINAL SCORE: 12 - Temp/epsilon: 0.8459, Loss: 0.45 - Dyn Loss: 0.60 - Tot Reward: 5.30
# EPISODE: 186 - FINAL SCORE: 16 - Temp/epsilon: 0.8377, Loss: 0.43 - Dyn Loss: 0.57 - Tot Reward: 8.57
# EPISODE: 187 - FINAL SCORE: 16 - Temp/epsilon: 0.8297, Loss: 0.44 - Dyn Loss: 0.56 - Tot Reward: 11.15
# EPISODE: 188 - FINAL SCORE: 24 - Temp/epsilon: 0.8217, Loss: 0.47 - Dyn Loss: 0.58 - Tot Reward: 15.80
# EPISODE: 189 - FINAL SCORE: 12 - Temp/epsilon: 0.8138, Loss: 0.44 - Dyn Loss: 0.59 - Tot Reward: 5.85
# EPISODE: 190 - FINAL SCORE: 42 - Temp/epsilon: 0.8060, Loss: 0.43 - Dyn Loss: 0.58 - Tot Reward: 30.31
# EPISODE: 191 - FINAL SCORE: 39 - Temp/epsilon: 0.7983, Loss: 0.44 - Dyn Loss: 0.57 - Tot Reward: 30.04
# EPISODE: 192 - FINAL SCORE: 30 - Temp/epsilon: 0.7906, Loss: 0.44 - Dyn Loss: 0.60 - Tot Reward: 23.17
# EPISODE: 193 - FINAL SCORE: 16 - Temp/epsilon: 0.7830, Loss: 0.44 - Dyn Loss: 0.58 - Tot Reward: 11.04
# EPISODE: 194 - FINAL SCORE: 48 - Temp/epsilon: 0.7755, Loss: 0.44 - Dyn Loss: 0.60 - Tot Reward: 22.93
# EPISODE: 195 - FINAL SCORE: 26 - Temp/epsilon: 0.7680, Loss: 0.44 - Dyn Loss: 0.57 - Tot Reward: 15.12
# EPISODE: 196 - FINAL SCORE: 24 - Temp/epsilon: 0.7606, Loss: 0.43 - Dyn Loss: 0.60 - Tot Reward: 16.38
# EPISODE: 197 - FINAL SCORE: 19 - Temp/epsilon: 0.7533, Loss: 0.43 - Dyn Loss: 0.60 - Tot Reward: 12.02
# EPISODE: 198 - FINAL SCORE: 18 - Temp/epsilon: 0.7461, Loss: 0.43 - Dyn Loss: 0.55 - Tot Reward: 8.46
# EPISODE: 199 - FINAL SCORE: 14 - Temp/epsilon: 0.7389, Loss: 0.45 - Dyn Loss: 0.56 - Tot Reward: 6.66
# EPISODE: 200 - FINAL SCORE: 20 - Temp/epsilon: 0.7318, Loss: 0.43 - Dyn Loss: 0.55 - Tot Reward: 13.10
# EPISODE: 201 - FINAL SCORE: 14 - Temp/epsilon: 0.7248, Loss: 0.44 - Dyn Loss: 0.57 - Tot Reward: 8.43
# EPISODE: 202 - FINAL SCORE: 14 - Temp/epsilon: 0.7178, Loss: 0.41 - Dyn Loss: 0.59 - Tot Reward: 8.53
# EPISODE: 203 - FINAL SCORE: 18 - Temp/epsilon: 0.7109, Loss: 0.43 - Dyn Loss: 0.58 - Tot Reward: 11.00
# EPISODE: 204 - FINAL SCORE: 33 - Temp/epsilon: 0.7041, Loss: 0.43 - Dyn Loss: 0.56 - Tot Reward: 23.46
# EPISODE: 205 - FINAL SCORE: 11 - Temp/epsilon: 0.6973, Loss: 0.42 - Dyn Loss: 0.58 - Tot Reward: 5.50
# EPISODE: 206 - FINAL SCORE: 10 - Temp/epsilon: 0.6906, Loss: 0.39 - Dyn Loss: 0.59 - Tot Reward: 5.20
# EPISODE: 207 - FINAL SCORE: 29 - Temp/epsilon: 0.6840, Loss: 0.44 - Dyn Loss: 0.59 - Tot Reward: 22.79
# EPISODE: 208 - FINAL SCORE: 42 - Temp/epsilon: 0.6774, Loss: 0.44 - Dyn Loss: 0.57 - Tot Reward: 28.39
# EPISODE: 209 - FINAL SCORE: 21 - Temp/epsilon: 0.6709, Loss: 0.43 - Dyn Loss: 0.57 - Tot Reward: 14.50
# EPISODE: 210 - FINAL SCORE: 44 - Temp/epsilon: 0.6644, Loss: 0.44 - Dyn Loss: 0.56 - Tot Reward: 28.93
# EPISODE: 211 - FINAL SCORE: 25 - Temp/epsilon: 0.6581, Loss: 0.43 - Dyn Loss: 0.57 - Tot Reward: 15.19
# EPISODE: 212 - FINAL SCORE: 25 - Temp/epsilon: 0.6517, Loss: 0.47 - Dyn Loss: 0.57 - Tot Reward: 16.37
# EPISODE: 213 - FINAL SCORE: 44 - Temp/epsilon: 0.6455, Loss: 0.47 - Dyn Loss: 0.56 - Tot Reward: 33.56
# EPISODE: 214 - FINAL SCORE: 9 - Temp/epsilon: 0.6393, Loss: 0.46 - Dyn Loss: 0.56 - Tot Reward: 4.87
# EPISODE: 215 - FINAL SCORE: 15 - Temp/epsilon: 0.6331, Loss: 0.45 - Dyn Loss: 0.56 - Tot Reward: 9.53
# EPISODE: 216 - FINAL SCORE: 12 - Temp/epsilon: 0.6270, Loss: 0.45 - Dyn Loss: 0.58 - Tot Reward: 7.43
# EPISODE: 217 - FINAL SCORE: 11 - Temp/epsilon: 0.6210, Loss: 0.44 - Dyn Loss: 0.57 - Tot Reward: 5.69
# EPISODE: 218 - FINAL SCORE: 17 - Temp/epsilon: 0.6151, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 9.34
# EPISODE: 219 - FINAL SCORE: 21 - Temp/epsilon: 0.6091, Loss: 0.48 - Dyn Loss: 0.54 - Tot Reward: 10.86
# EPISODE: 220 - FINAL SCORE: 47 - Temp/epsilon: 0.6033, Loss: 0.46 - Dyn Loss: 0.59 - Tot Reward: 30.69
# EPISODE: 221 - FINAL SCORE: 21 - Temp/epsilon: 0.5975, Loss: 0.47 - Dyn Loss: 0.57 - Tot Reward: 15.22
# EPISODE: 222 - FINAL SCORE: 32 - Temp/epsilon: 0.5917, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 21.67
# EPISODE: 223 - FINAL SCORE: 28 - Temp/epsilon: 0.5861, Loss: 0.50 - Dyn Loss: 0.59 - Tot Reward: 16.81
# EPISODE: 224 - FINAL SCORE: 11 - Temp/epsilon: 0.5804, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 5.41
# EPISODE: 225 - FINAL SCORE: 26 - Temp/epsilon: 0.5748, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 18.57
# EPISODE: 226 - FINAL SCORE: 13 - Temp/epsilon: 0.5693, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 8.28
# EPISODE: 227 - FINAL SCORE: 31 - Temp/epsilon: 0.5639, Loss: 0.49 - Dyn Loss: 0.59 - Tot Reward: 20.99
# EPISODE: 228 - FINAL SCORE: 11 - Temp/epsilon: 0.5584, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 6.19
# EPISODE: 229 - FINAL SCORE: 20 - Temp/epsilon: 0.5531, Loss: 0.49 - Dyn Loss: 0.58 - Tot Reward: 12.73
# EPISODE: 230 - FINAL SCORE: 24 - Temp/epsilon: 0.5478, Loss: 0.47 - Dyn Loss: 0.57 - Tot Reward: 14.09
# EPISODE: 231 - FINAL SCORE: 24 - Temp/epsilon: 0.5425, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 18.22
# EPISODE: 232 - FINAL SCORE: 44 - Temp/epsilon: 0.5373, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 25.16
# EPISODE: 233 - FINAL SCORE: 14 - Temp/epsilon: 0.5321, Loss: 0.52 - Dyn Loss: 0.54 - Tot Reward: 6.68
# EPISODE: 234 - FINAL SCORE: 19 - Temp/epsilon: 0.5270, Loss: 0.53 - Dyn Loss: 0.52 - Tot Reward: 13.29
# EPISODE: 235 - FINAL SCORE: 13 - Temp/epsilon: 0.5219, Loss: 0.48 - Dyn Loss: 0.56 - Tot Reward: 7.05
# EPISODE: 236 - FINAL SCORE: 19 - Temp/epsilon: 0.5169, Loss: 0.49 - Dyn Loss: 0.52 - Tot Reward: 12.15
# EPISODE: 237 - FINAL SCORE: 21 - Temp/epsilon: 0.5120, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 12.84
# EPISODE: 238 - FINAL SCORE: 19 - Temp/epsilon: 0.5070, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 10.77
# EPISODE: 239 - FINAL SCORE: 18 - Temp/epsilon: 0.5022, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 12.95
# EPISODE: 240 - FINAL SCORE: 13 - Temp/epsilon: 0.4973, Loss: 0.54 - Dyn Loss: 0.57 - Tot Reward: 7.27
# EPISODE: 241 - FINAL SCORE: 15 - Temp/epsilon: 0.4926, Loss: 0.52 - Dyn Loss: 0.59 - Tot Reward: 9.72
# EPISODE: 242 - FINAL SCORE: 14 - Temp/epsilon: 0.4878, Loss: 0.51 - Dyn Loss: 0.54 - Tot Reward: 7.77
# EPISODE: 243 - FINAL SCORE: 23 - Temp/epsilon: 0.4831, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 17.44
# EPISODE: 244 - FINAL SCORE: 27 - Temp/epsilon: 0.4785, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 18.81
# EPISODE: 245 - FINAL SCORE: 32 - Temp/epsilon: 0.4739, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 21.27
# EPISODE: 246 - FINAL SCORE: 29 - Temp/epsilon: 0.4693, Loss: 0.54 - Dyn Loss: 0.56 - Tot Reward: 18.31
# EPISODE: 247 - FINAL SCORE: 25 - Temp/epsilon: 0.4648, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 18.73
# EPISODE: 248 - FINAL SCORE: 23 - Temp/epsilon: 0.4604, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 14.55
# EPISODE: 249 - FINAL SCORE: 12 - Temp/epsilon: 0.4559, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 6.61
# EPISODE: 250 - FINAL SCORE: 17 - Temp/epsilon: 0.4516, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 11.13
# EPISODE: 251 - FINAL SCORE: 35 - Temp/epsilon: 0.4472, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 21.08
# EPISODE: 252 - FINAL SCORE: 25 - Temp/epsilon: 0.4429, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 15.83
# EPISODE: 253 - FINAL SCORE: 30 - Temp/epsilon: 0.4387, Loss: 0.50 - Dyn Loss: 0.53 - Tot Reward: 23.35
# EPISODE: 254 - FINAL SCORE: 25 - Temp/epsilon: 0.4344, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 16.72
# EPISODE: 255 - FINAL SCORE: 17 - Temp/epsilon: 0.4303, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 11.16
# EPISODE: 256 - FINAL SCORE: 50 - Temp/epsilon: 0.4261, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 27.72
# EPISODE: 257 - FINAL SCORE: 11 - Temp/epsilon: 0.4220, Loss: 0.51 - Dyn Loss: 0.53 - Tot Reward: 5.62
# EPISODE: 258 - FINAL SCORE: 13 - Temp/epsilon: 0.4180, Loss: 0.49 - Dyn Loss: 0.53 - Tot Reward: 7.34
# EPISODE: 259 - FINAL SCORE: 42 - Temp/epsilon: 0.4140, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 27.38
# EPISODE: 260 - FINAL SCORE: 58 - Temp/epsilon: 0.4100, Loss: 0.47 - Dyn Loss: 0.56 - Tot Reward: 29.76
# EPISODE: 261 - FINAL SCORE: 17 - Temp/epsilon: 0.4060, Loss: 0.45 - Dyn Loss: 0.54 - Tot Reward: 11.30
# EPISODE: 262 - FINAL SCORE: 40 - Temp/epsilon: 0.4021, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 25.70
# EPISODE: 263 - FINAL SCORE: 11 - Temp/epsilon: 0.3983, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 6.75
# EPISODE: 264 - FINAL SCORE: 16 - Temp/epsilon: 0.3945, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 11.93
# EPISODE: 265 - FINAL SCORE: 29 - Temp/epsilon: 0.3907, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 18.87
# EPISODE: 266 - FINAL SCORE: 21 - Temp/epsilon: 0.3869, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 13.85
# EPISODE: 267 - FINAL SCORE: 14 - Temp/epsilon: 0.3832, Loss: 0.49 - Dyn Loss: 0.54 - Tot Reward: 7.07
# EPISODE: 268 - FINAL SCORE: 22 - Temp/epsilon: 0.3795, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 12.15
# EPISODE: 269 - FINAL SCORE: 32 - Temp/epsilon: 0.3759, Loss: 0.49 - Dyn Loss: 0.54 - Tot Reward: 18.96
# EPISODE: 270 - FINAL SCORE: 21 - Temp/epsilon: 0.3722, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 13.62
# EPISODE: 271 - FINAL SCORE: 34 - Temp/epsilon: 0.3687, Loss: 0.48 - Dyn Loss: 0.55 - Tot Reward: 22.84
# EPISODE: 272 - FINAL SCORE: 17 - Temp/epsilon: 0.3651, Loss: 0.50 - Dyn Loss: 0.53 - Tot Reward: 9.16
# EPISODE: 273 - FINAL SCORE: 12 - Temp/epsilon: 0.3616, Loss: 0.47 - Dyn Loss: 0.55 - Tot Reward: 7.13
# EPISODE: 274 - FINAL SCORE: 18 - Temp/epsilon: 0.3581, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 9.57
# EPISODE: 275 - FINAL SCORE: 13 - Temp/epsilon: 0.3547, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 7.64
# EPISODE: 276 - FINAL SCORE: 19 - Temp/epsilon: 0.3513, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 10.37
# EPISODE: 277 - FINAL SCORE: 13 - Temp/epsilon: 0.3479, Loss: 0.56 - Dyn Loss: 0.56 - Tot Reward: 7.21
# EPISODE: 278 - FINAL SCORE: 33 - Temp/epsilon: 0.3446, Loss: 0.54 - Dyn Loss: 0.54 - Tot Reward: 26.52
# EPISODE: 279 - FINAL SCORE: 17 - Temp/epsilon: 0.3413, Loss: 0.55 - Dyn Loss: 0.52 - Tot Reward: 10.77
# EPISODE: 280 - FINAL SCORE: 15 - Temp/epsilon: 0.3380, Loss: 0.54 - Dyn Loss: 0.54 - Tot Reward: 7.35
# EPISODE: 281 - FINAL SCORE: 18 - Temp/epsilon: 0.3347, Loss: 0.57 - Dyn Loss: 0.56 - Tot Reward: 10.41
# EPISODE: 282 - FINAL SCORE: 11 - Temp/epsilon: 0.3315, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 5.87
# EPISODE: 283 - FINAL SCORE: 57 - Temp/epsilon: 0.3283, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 44.55
# EPISODE: 284 - FINAL SCORE: 11 - Temp/epsilon: 0.3252, Loss: 0.60 - Dyn Loss: 0.53 - Tot Reward: 7.07
# EPISODE: 285 - FINAL SCORE: 38 - Temp/epsilon: 0.3221, Loss: 0.57 - Dyn Loss: 0.55 - Tot Reward: 29.48
# EPISODE: 286 - FINAL SCORE: 12 - Temp/epsilon: 0.3190, Loss: 0.57 - Dyn Loss: 0.53 - Tot Reward: 5.44
# EPISODE: 287 - FINAL SCORE: 12 - Temp/epsilon: 0.3159, Loss: 0.59 - Dyn Loss: 0.53 - Tot Reward: 8.07
# EPISODE: 288 - FINAL SCORE: 21 - Temp/epsilon: 0.3129, Loss: 0.61 - Dyn Loss: 0.55 - Tot Reward: 13.48
# EPISODE: 289 - FINAL SCORE: 15 - Temp/epsilon: 0.3098, Loss: 0.64 - Dyn Loss: 0.55 - Tot Reward: 10.89
# EPISODE: 290 - FINAL SCORE: 18 - Temp/epsilon: 0.3069, Loss: 0.62 - Dyn Loss: 0.56 - Tot Reward: 10.50
# EPISODE: 291 - FINAL SCORE: 13 - Temp/epsilon: 0.3039, Loss: 0.61 - Dyn Loss: 0.58 - Tot Reward: 7.30
# EPISODE: 292 - FINAL SCORE: 16 - Temp/epsilon: 0.3010, Loss: 0.62 - Dyn Loss: 0.54 - Tot Reward: 9.36
# EPISODE: 293 - FINAL SCORE: 30 - Temp/epsilon: 0.2981, Loss: 0.63 - Dyn Loss: 0.54 - Tot Reward: 23.09
# EPISODE: 294 - FINAL SCORE: 20 - Temp/epsilon: 0.2952, Loss: 0.64 - Dyn Loss: 0.57 - Tot Reward: 12.05
# EPISODE: 295 - FINAL SCORE: 19 - Temp/epsilon: 0.2924, Loss: 0.60 - Dyn Loss: 0.55 - Tot Reward: 8.12
# EPISODE: 296 - FINAL SCORE: 13 - Temp/epsilon: 0.2896, Loss: 0.62 - Dyn Loss: 0.53 - Tot Reward: 7.63
# EPISODE: 297 - FINAL SCORE: 27 - Temp/epsilon: 0.2868, Loss: 0.62 - Dyn Loss: 0.56 - Tot Reward: 17.76
# EPISODE: 298 - FINAL SCORE: 19 - Temp/epsilon: 0.2841, Loss: 0.61 - Dyn Loss: 0.54 - Tot Reward: 8.87
# EPISODE: 299 - FINAL SCORE: 15 - Temp/epsilon: 0.2813, Loss: 0.66 - Dyn Loss: 0.56 - Tot Reward: 8.61
# EPISODE: 300 - FINAL SCORE: 24 - Temp/epsilon: 0.2786, Loss: 0.64 - Dyn Loss: 0.56 - Tot Reward: 13.87
# EPISODE: 301 - FINAL SCORE: 19 - Temp/epsilon: 0.2759, Loss: 0.65 - Dyn Loss: 0.55 - Tot Reward: 12.19
# EPISODE: 302 - FINAL SCORE: 18 - Temp/epsilon: 0.2733, Loss: 0.65 - Dyn Loss: 0.57 - Tot Reward: 10.05
# EPISODE: 303 - FINAL SCORE: 33 - Temp/epsilon: 0.2707, Loss: 0.65 - Dyn Loss: 0.55 - Tot Reward: 25.42
# EPISODE: 304 - FINAL SCORE: 44 - Temp/epsilon: 0.2681, Loss: 0.63 - Dyn Loss: 0.54 - Tot Reward: 30.58
# EPISODE: 305 - FINAL SCORE: 18 - Temp/epsilon: 0.2655, Loss: 0.65 - Dyn Loss: 0.57 - Tot Reward: 11.30
# EPISODE: 306 - FINAL SCORE: 9 - Temp/epsilon: 0.2629, Loss: 0.61 - Dyn Loss: 0.54 - Tot Reward: 5.84
# EPISODE: 307 - FINAL SCORE: 52 - Temp/epsilon: 0.2604, Loss: 0.61 - Dyn Loss: 0.56 - Tot Reward: 21.25
# EPISODE: 308 - FINAL SCORE: 28 - Temp/epsilon: 0.2579, Loss: 0.63 - Dyn Loss: 0.55 - Tot Reward: 22.03
# EPISODE: 309 - FINAL SCORE: 20 - Temp/epsilon: 0.2554, Loss: 0.61 - Dyn Loss: 0.56 - Tot Reward: 13.46
# EPISODE: 310 - FINAL SCORE: 36 - Temp/epsilon: 0.2530, Loss: 0.61 - Dyn Loss: 0.55 - Tot Reward: 18.11
# EPISODE: 311 - FINAL SCORE: 24 - Temp/epsilon: 0.2505, Loss: 0.60 - Dyn Loss: 0.55 - Tot Reward: 15.52
# EPISODE: 312 - FINAL SCORE: 31 - Temp/epsilon: 0.2481, Loss: 0.61 - Dyn Loss: 0.54 - Tot Reward: 14.25
# EPISODE: 313 - FINAL SCORE: 28 - Temp/epsilon: 0.2458, Loss: 0.60 - Dyn Loss: 0.57 - Tot Reward: 14.57
# EPISODE: 314 - FINAL SCORE: 47 - Temp/epsilon: 0.2434, Loss: 0.58 - Dyn Loss: 0.55 - Tot Reward: 26.41
# EPISODE: 315 - FINAL SCORE: 23 - Temp/epsilon: 0.2411, Loss: 0.61 - Dyn Loss: 0.56 - Tot Reward: 15.65
# EPISODE: 316 - FINAL SCORE: 14 - Temp/epsilon: 0.2387, Loss: 0.57 - Dyn Loss: 0.59 - Tot Reward: 6.64
# EPISODE: 317 - FINAL SCORE: 23 - Temp/epsilon: 0.2364, Loss: 0.60 - Dyn Loss: 0.55 - Tot Reward: 13.70
# EPISODE: 318 - FINAL SCORE: 22 - Temp/epsilon: 0.2342, Loss: 0.59 - Dyn Loss: 0.57 - Tot Reward: 16.78
# EPISODE: 319 - FINAL SCORE: 16 - Temp/epsilon: 0.2319, Loss: 0.59 - Dyn Loss: 0.54 - Tot Reward: 10.67
# EPISODE: 320 - FINAL SCORE: 20 - Temp/epsilon: 0.2297, Loss: 0.56 - Dyn Loss: 0.57 - Tot Reward: 14.91
# EPISODE: 321 - FINAL SCORE: 12 - Temp/epsilon: 0.2275, Loss: 0.61 - Dyn Loss: 0.57 - Tot Reward: 6.62
# EPISODE: 322 - FINAL SCORE: 83 - Temp/epsilon: 0.2253, Loss: 0.56 - Dyn Loss: 0.54 - Tot Reward: 43.86
# EPISODE: 323 - FINAL SCORE: 25 - Temp/epsilon: 0.2231, Loss: 0.59 - Dyn Loss: 0.57 - Tot Reward: 16.01
# EPISODE: 324 - FINAL SCORE: 16 - Temp/epsilon: 0.2210, Loss: 0.55 - Dyn Loss: 0.55 - Tot Reward: 9.49
# EPISODE: 325 - FINAL SCORE: 16 - Temp/epsilon: 0.2189, Loss: 0.58 - Dyn Loss: 0.58 - Tot Reward: 8.24
# EPISODE: 326 - FINAL SCORE: 47 - Temp/epsilon: 0.2168, Loss: 0.57 - Dyn Loss: 0.56 - Tot Reward: 28.91
# EPISODE: 327 - FINAL SCORE: 21 - Temp/epsilon: 0.2147, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 14.89
# EPISODE: 328 - FINAL SCORE: 62 - Temp/epsilon: 0.2126, Loss: 0.54 - Dyn Loss: 0.56 - Tot Reward: 43.05
# EPISODE: 329 - FINAL SCORE: 9 - Temp/epsilon: 0.2106, Loss: 0.54 - Dyn Loss: 0.57 - Tot Reward: 3.99
# EPISODE: 330 - FINAL SCORE: 42 - Temp/epsilon: 0.2085, Loss: 0.55 - Dyn Loss: 0.57 - Tot Reward: 25.39
# EPISODE: 331 - FINAL SCORE: 19 - Temp/epsilon: 0.2065, Loss: 0.56 - Dyn Loss: 0.56 - Tot Reward: 11.54
# EPISODE: 332 - FINAL SCORE: 19 - Temp/epsilon: 0.2046, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 13.68
# EPISODE: 333 - FINAL SCORE: 23 - Temp/epsilon: 0.2026, Loss: 0.51 - Dyn Loss: 0.54 - Tot Reward: 15.33
# EPISODE: 334 - FINAL SCORE: 11 - Temp/epsilon: 0.2006, Loss: 0.53 - Dyn Loss: 0.57 - Tot Reward: 6.63
# EPISODE: 335 - FINAL SCORE: 10 - Temp/epsilon: 0.1987, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 6.04
# EPISODE: 336 - FINAL SCORE: 24 - Temp/epsilon: 0.1968, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 17.16
# EPISODE: 337 - FINAL SCORE: 15 - Temp/epsilon: 0.1949, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 8.80
# EPISODE: 338 - FINAL SCORE: 21 - Temp/epsilon: 0.1930, Loss: 0.47 - Dyn Loss: 0.55 - Tot Reward: 13.23
# EPISODE: 339 - FINAL SCORE: 27 - Temp/epsilon: 0.1912, Loss: 0.50 - Dyn Loss: 0.54 - Tot Reward: 17.45
# EPISODE: 340 - FINAL SCORE: 11 - Temp/epsilon: 0.1893, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 5.22
# EPISODE: 341 - FINAL SCORE: 23 - Temp/epsilon: 0.1875, Loss: 0.50 - Dyn Loss: 0.57 - Tot Reward: 17.63
# EPISODE: 342 - FINAL SCORE: 11 - Temp/epsilon: 0.1857, Loss: 0.54 - Dyn Loss: 0.59 - Tot Reward: 6.13
# EPISODE: 343 - FINAL SCORE: 18 - Temp/epsilon: 0.1839, Loss: 0.51 - Dyn Loss: 0.56 - Tot Reward: 11.76
# EPISODE: 344 - FINAL SCORE: 14 - Temp/epsilon: 0.1822, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 7.84
# EPISODE: 345 - FINAL SCORE: 34 - Temp/epsilon: 0.1804, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 22.64
# EPISODE: 346 - FINAL SCORE: 27 - Temp/epsilon: 0.1787, Loss: 0.50 - Dyn Loss: 0.54 - Tot Reward: 16.89
# EPISODE: 347 - FINAL SCORE: 11 - Temp/epsilon: 0.1770, Loss: 0.48 - Dyn Loss: 0.56 - Tot Reward: 5.72
# EPISODE: 348 - FINAL SCORE: 52 - Temp/epsilon: 0.1753, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 39.75
# EPISODE: 349 - FINAL SCORE: 19 - Temp/epsilon: 0.1736, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 13.49
# EPISODE: 350 - FINAL SCORE: 10 - Temp/epsilon: 0.1719, Loss: 0.47 - Dyn Loss: 0.55 - Tot Reward: 4.82
# EPISODE: 351 - FINAL SCORE: 35 - Temp/epsilon: 0.1703, Loss: 0.48 - Dyn Loss: 0.55 - Tot Reward: 21.49
# EPISODE: 352 - FINAL SCORE: 20 - Temp/epsilon: 0.1686, Loss: 0.51 - Dyn Loss: 0.56 - Tot Reward: 13.29
# EPISODE: 353 - FINAL SCORE: 29 - Temp/epsilon: 0.1670, Loss: 0.55 - Dyn Loss: 0.56 - Tot Reward: 19.17
# EPISODE: 354 - FINAL SCORE: 19 - Temp/epsilon: 0.1654, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 12.64
# EPISODE: 355 - FINAL SCORE: 14 - Temp/epsilon: 0.1638, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 6.97
# EPISODE: 356 - FINAL SCORE: 13 - Temp/epsilon: 0.1622, Loss: 0.54 - Dyn Loss: 0.56 - Tot Reward: 8.21
# EPISODE: 357 - FINAL SCORE: 19 - Temp/epsilon: 0.1607, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 10.75
# EPISODE: 358 - FINAL SCORE: 9 - Temp/epsilon: 0.1591, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 4.40
# EPISODE: 359 - FINAL SCORE: 32 - Temp/epsilon: 0.1576, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 16.89
# EPISODE: 360 - FINAL SCORE: 19 - Temp/epsilon: 0.1561, Loss: 0.46 - Dyn Loss: 0.55 - Tot Reward: 10.64
# EPISODE: 361 - FINAL SCORE: 16 - Temp/epsilon: 0.1546, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 9.50
# EPISODE: 362 - FINAL SCORE: 15 - Temp/epsilon: 0.1531, Loss: 0.49 - Dyn Loss: 0.57 - Tot Reward: 9.41
# EPISODE: 363 - FINAL SCORE: 20 - Temp/epsilon: 0.1516, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 12.28
# EPISODE: 364 - FINAL SCORE: 12 - Temp/epsilon: 0.1502, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 6.67
# EPISODE: 365 - FINAL SCORE: 9 - Temp/epsilon: 0.1487, Loss: 0.51 - Dyn Loss: 0.59 - Tot Reward: 4.28
# EPISODE: 366 - FINAL SCORE: 11 - Temp/epsilon: 0.1473, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 6.12
# EPISODE: 367 - FINAL SCORE: 27 - Temp/epsilon: 0.1459, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 16.99
# EPISODE: 368 - FINAL SCORE: 35 - Temp/epsilon: 0.1445, Loss: 0.53 - Dyn Loss: 0.57 - Tot Reward: 24.31
# EPISODE: 369 - FINAL SCORE: 10 - Temp/epsilon: 0.1431, Loss: 0.49 - Dyn Loss: 0.54 - Tot Reward: 5.91
# EPISODE: 370 - FINAL SCORE: 76 - Temp/epsilon: 0.1417, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 44.01
# EPISODE: 371 - FINAL SCORE: 12 - Temp/epsilon: 0.1404, Loss: 0.48 - Dyn Loss: 0.51 - Tot Reward: 7.96
# EPISODE: 372 - FINAL SCORE: 17 - Temp/epsilon: 0.1390, Loss: 0.57 - Dyn Loss: 0.53 - Tot Reward: 11.97
# EPISODE: 373 - FINAL SCORE: 14 - Temp/epsilon: 0.1377, Loss: 0.57 - Dyn Loss: 0.55 - Tot Reward: 6.96
# EPISODE: 374 - FINAL SCORE: 32 - Temp/epsilon: 0.1364, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 21.89
# EPISODE: 375 - FINAL SCORE: 29 - Temp/epsilon: 0.1350, Loss: 0.60 - Dyn Loss: 0.57 - Tot Reward: 21.04
# EPISODE: 376 - FINAL SCORE: 63 - Temp/epsilon: 0.1337, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 49.87
# EPISODE: 377 - FINAL SCORE: 29 - Temp/epsilon: 0.1325, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 19.53
# EPISODE: 378 - FINAL SCORE: 25 - Temp/epsilon: 0.1312, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 15.61
# EPISODE: 379 - FINAL SCORE: 39 - Temp/epsilon: 0.1299, Loss: 0.58 - Dyn Loss: 0.54 - Tot Reward: 24.64
# EPISODE: 380 - FINAL SCORE: 8 - Temp/epsilon: 0.1287, Loss: 0.61 - Dyn Loss: 0.55 - Tot Reward: 4.03
# EPISODE: 381 - FINAL SCORE: 14 - Temp/epsilon: 0.1274, Loss: 0.58 - Dyn Loss: 0.55 - Tot Reward: 8.83
# EPISODE: 382 - FINAL SCORE: 26 - Temp/epsilon: 0.1262, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 16.03
# EPISODE: 383 - FINAL SCORE: 11 - Temp/epsilon: 0.1250, Loss: 0.55 - Dyn Loss: 0.55 - Tot Reward: 6.82
# EPISODE: 384 - FINAL SCORE: 21 - Temp/epsilon: 0.1238, Loss: 0.54 - Dyn Loss: 0.54 - Tot Reward: 14.12
# EPISODE: 385 - FINAL SCORE: 58 - Temp/epsilon: 0.1226, Loss: 0.55 - Dyn Loss: 0.55 - Tot Reward: 27.97
# EPISODE: 386 - FINAL SCORE: 44 - Temp/epsilon: 0.1214, Loss: 0.56 - Dyn Loss: 0.56 - Tot Reward: 33.07
# EPISODE: 387 - FINAL SCORE: 31 - Temp/epsilon: 0.1203, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 23.51
# EPISODE: 388 - FINAL SCORE: 36 - Temp/epsilon: 0.1191, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 23.47
# EPISODE: 389 - FINAL SCORE: 25 - Temp/epsilon: 0.1180, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 17.88
# EPISODE: 390 - FINAL SCORE: 18 - Temp/epsilon: 0.1168, Loss: 0.50 - Dyn Loss: 0.54 - Tot Reward: 11.59
# EPISODE: 391 - FINAL SCORE: 17 - Temp/epsilon: 0.1157, Loss: 0.53 - Dyn Loss: 0.54 - Tot Reward: 10.12
# EPISODE: 392 - FINAL SCORE: 21 - Temp/epsilon: 0.1146, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 16.07
# EPISODE: 393 - FINAL SCORE: 12 - Temp/epsilon: 0.1135, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 6.68
# EPISODE: 394 - FINAL SCORE: 19 - Temp/epsilon: 0.1124, Loss: 0.51 - Dyn Loss: 0.57 - Tot Reward: 11.31
# EPISODE: 395 - FINAL SCORE: 40 - Temp/epsilon: 0.1113, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 22.13
# EPISODE: 396 - FINAL SCORE: 45 - Temp/epsilon: 0.1103, Loss: 0.49 - Dyn Loss: 0.55 - Tot Reward: 36.07
# EPISODE: 397 - FINAL SCORE: 38 - Temp/epsilon: 0.1092, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 26.54
# EPISODE: 398 - FINAL SCORE: 31 - Temp/epsilon: 0.1081, Loss: 0.53 - Dyn Loss: 0.54 - Tot Reward: 21.28
# EPISODE: 399 - FINAL SCORE: 33 - Temp/epsilon: 0.1071, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 18.22
# EPISODE: 400 - FINAL SCORE: 83 - Temp/epsilon: 0.1061, Loss: 0.51 - Dyn Loss: 0.56 - Tot Reward: 63.55
# EPISODE: 401 - FINAL SCORE: 47 - Temp/epsilon: 0.1051, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 32.21
# EPISODE: 402 - FINAL SCORE: 15 - Temp/epsilon: 0.1041, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 8.14
# EPISODE: 403 - FINAL SCORE: 18 - Temp/epsilon: 0.1031, Loss: 0.51 - Dyn Loss: 0.53 - Tot Reward: 11.64
# EPISODE: 404 - FINAL SCORE: 43 - Temp/epsilon: 0.1021, Loss: 0.54 - Dyn Loss: 0.56 - Tot Reward: 29.02
# EPISODE: 405 - FINAL SCORE: 16 - Temp/epsilon: 0.1011, Loss: 0.51 - Dyn Loss: 0.56 - Tot Reward: 10.68
# EPISODE: 406 - FINAL SCORE: 60 - Temp/epsilon: 0.1001, Loss: 0.51 - Dyn Loss: 0.54 - Tot Reward: 35.46
# EPISODE: 407 - FINAL SCORE: 63 - Temp/epsilon: 0.0991, Loss: 0.51 - Dyn Loss: 0.56 - Tot Reward: 35.49
# EPISODE: 408 - FINAL SCORE: 21 - Temp/epsilon: 0.0982, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 13.79
# EPISODE: 409 - FINAL SCORE: 51 - Temp/epsilon: 0.0973, Loss: 0.52 - Dyn Loss: 0.54 - Tot Reward: 39.41
# EPISODE: 410 - FINAL SCORE: 37 - Temp/epsilon: 0.0963, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 18.82
# EPISODE: 411 - FINAL SCORE: 17 - Temp/epsilon: 0.0954, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 12.33
# EPISODE: 412 - FINAL SCORE: 44 - Temp/epsilon: 0.0945, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 27.32
# EPISODE: 413 - FINAL SCORE: 60 - Temp/epsilon: 0.0936, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 42.46
# EPISODE: 414 - FINAL SCORE: 42 - Temp/epsilon: 0.0927, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 26.84
# EPISODE: 415 - FINAL SCORE: 62 - Temp/epsilon: 0.0918, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 49.83
# EPISODE: 416 - FINAL SCORE: 23 - Temp/epsilon: 0.0909, Loss: 0.49 - Dyn Loss: 0.59 - Tot Reward: 14.82
# EPISODE: 417 - FINAL SCORE: 17 - Temp/epsilon: 0.0900, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 9.61
# EPISODE: 418 - FINAL SCORE: 43 - Temp/epsilon: 0.0892, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 29.94
# EPISODE: 419 - FINAL SCORE: 23 - Temp/epsilon: 0.0883, Loss: 0.53 - Dyn Loss: 0.56 - Tot Reward: 13.15
# EPISODE: 420 - FINAL SCORE: 11 - Temp/epsilon: 0.0874, Loss: 0.51 - Dyn Loss: 0.53 - Tot Reward: 6.33
# EPISODE: 421 - FINAL SCORE: 25 - Temp/epsilon: 0.0866, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 16.21
# EPISODE: 422 - FINAL SCORE: 24 - Temp/epsilon: 0.0858, Loss: 0.54 - Dyn Loss: 0.56 - Tot Reward: 17.02
# EPISODE: 423 - FINAL SCORE: 28 - Temp/epsilon: 0.0850, Loss: 0.52 - Dyn Loss: 0.57 - Tot Reward: 18.79
# EPISODE: 424 - FINAL SCORE: 69 - Temp/epsilon: 0.0841, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: 47.80
# EPISODE: 425 - FINAL SCORE: 16 - Temp/epsilon: 0.0833, Loss: 0.54 - Dyn Loss: 0.55 - Tot Reward: 10.71
# EPISODE: 426 - FINAL SCORE: 67 - Temp/epsilon: 0.0825, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 56.84
# EPISODE: 427 - FINAL SCORE: 21 - Temp/epsilon: 0.0817, Loss: 0.53 - Dyn Loss: 0.55 - Tot Reward: 14.08
# EPISODE: 428 - FINAL SCORE: 130 - Temp/epsilon: 0.0809, Loss: 0.51 - Dyn Loss: 0.55 - Tot Reward: 98.61
# EPISODE: 429 - FINAL SCORE: 40 - Temp/epsilon: 0.0802, Loss: 0.52 - Dyn Loss: 0.56 - Tot Reward: 30.58
# EPISODE: 430 - FINAL SCORE: 42 - Temp/epsilon: 0.0794, Loss: 0.50 - Dyn Loss: 0.54 - Tot Reward: 25.94
# EPISODE: 431 - FINAL SCORE: 56 - Temp/epsilon: 0.0786, Loss: 0.50 - Dyn Loss: 0.55 - Tot Reward: 36.68
# EPISODE: 432 - FINAL SCORE: 59 - Temp/epsilon: 0.0779, Loss: 0.49 - Dyn Loss: 0.56 - Tot Reward: 42.33
# EPISODE: 433 - FINAL SCORE: 93 - Temp/epsilon: 0.0771, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 78.47
# EPISODE: 434 - FINAL SCORE: 34 - Temp/epsilon: 0.0764, Loss: 0.51 - Dyn Loss: 0.54 - Tot Reward: 23.52
# EPISODE: 435 - FINAL SCORE: 28 - Temp/epsilon: 0.0757, Loss: 0.52 - Dyn Loss: 0.55 - Tot Reward: 17.66
# EPISODE: 436 - FINAL SCORE: 54 - Temp/epsilon: 0.0749, Loss: 0.50 - Dyn Loss: 0.54 - Tot Reward: 37.27
# EPISODE: 437 - FINAL SCORE: 23 - Temp/epsilon: 0.0742, Loss: 0.58 - Dyn Loss: 0.55 - Tot Reward: 17.38
# EPISODE: 438 - FINAL SCORE: 42 - Temp/epsilon: 0.0735, Loss: 0.56 - Dyn Loss: 0.54 - Tot Reward: 29.10
# EPISODE: 439 - FINAL SCORE: 152 - Temp/epsilon: 0.0728, Loss: 0.56 - Dyn Loss: 0.55 - Tot Reward: 57.16
# EPISODE: 440 - FINAL SCORE: 26 - Temp/epsilon: 0.0721, Loss: 0.55 - Dyn Loss: 0.55 - Tot Reward: 19.16
# EPISODE: 441 - FINAL SCORE: 114 - Temp/epsilon: 0.0714, Loss: 0.56 - Dyn Loss: 0.55 - Tot Reward: 65.21
# EPISODE: 442 - FINAL SCORE: 41 - Temp/epsilon: 0.0707, Loss: 0.58 - Dyn Loss: 0.56 - Tot Reward: 30.59
# EPISODE: 443 - FINAL SCORE: 19 - Temp/epsilon: 0.0700, Loss: 0.59 - Dyn Loss: 0.55 - Tot Reward: 12.50
# EPISODE: 444 - FINAL SCORE: 58 - Temp/epsilon: 0.0694, Loss: 0.62 - Dyn Loss: 0.56 - Tot Reward: 45.53
# EPISODE: 445 - FINAL SCORE: 73 - Temp/epsilon: 0.0687, Loss: 0.59 - Dyn Loss: 0.55 - Tot Reward: 42.05
# EPISODE: 446 - FINAL SCORE: 190 - Temp/epsilon: 0.0680, Loss: 0.59 - Dyn Loss: 0.56 - Tot Reward: -1380.98
# EPISODE: 447 - FINAL SCORE: 116 - Temp/epsilon: 0.0674, Loss: 0.71 - Dyn Loss: 0.60 - Tot Reward: 48.78
# EPISODE: 448 - FINAL SCORE: 109 - Temp/epsilon: 0.0667, Loss: 0.69 - Dyn Loss: 0.60 - Tot Reward: 86.04
# EPISODE: 449 - FINAL SCORE: 73 - Temp/epsilon: 0.0661, Loss: 0.78 - Dyn Loss: 0.60 - Tot Reward: 52.08
# EPISODE: 450 - FINAL SCORE: 265 - Temp/epsilon: 0.0655, Loss: 0.72 - Dyn Loss: 0.59 - Tot Reward: -1128.01
# EPISODE: 451 - FINAL SCORE: 216 - Temp/epsilon: 0.0648, Loss: 0.88 - Dyn Loss: 0.62 - Tot Reward: 61.46
# EPISODE: 452 - FINAL SCORE: 93 - Temp/epsilon: 0.0642, Loss: 0.81 - Dyn Loss: 0.60 - Tot Reward: 39.10
# EPISODE: 453 - FINAL SCORE: 84 - Temp/epsilon: 0.0636, Loss: 0.87 - Dyn Loss: 0.61 - Tot Reward: 60.54
# EPISODE: 454 - FINAL SCORE: 75 - Temp/epsilon: 0.0630, Loss: 0.90 - Dyn Loss: 0.61 - Tot Reward: 45.85
# EPISODE: 455 - FINAL SCORE: 54 - Temp/epsilon: 0.0624, Loss: 0.83 - Dyn Loss: 0.60 - Tot Reward: 37.10
# EPISODE: 456 - FINAL SCORE: 87 - Temp/epsilon: 0.0618, Loss: 0.83 - Dyn Loss: 0.60 - Tot Reward: 39.61
# EPISODE: 457 - FINAL SCORE: 60 - Temp/epsilon: 0.0612, Loss: 0.76 - Dyn Loss: 0.58 - Tot Reward: 41.50
# EPISODE: 458 - FINAL SCORE: 45 - Temp/epsilon: 0.0606, Loss: 0.77 - Dyn Loss: 0.60 - Tot Reward: 32.08
# EPISODE: 459 - FINAL SCORE: 107 - Temp/epsilon: 0.0600, Loss: 0.75 - Dyn Loss: 0.59 - Tot Reward: 79.91
# EPISODE: 460 - FINAL SCORE: 54 - Temp/epsilon: 0.0594, Loss: 0.75 - Dyn Loss: 0.59 - Tot Reward: 36.38
# EPISODE: 461 - FINAL SCORE: 39 - Temp/epsilon: 0.0589, Loss: 0.79 - Dyn Loss: 0.58 - Tot Reward: 23.02
# EPISODE: 462 - FINAL SCORE: 52 - Temp/epsilon: 0.0583, Loss: 0.74 - Dyn Loss: 0.58 - Tot Reward: 34.33
# EPISODE: 463 - FINAL SCORE: 79 - Temp/epsilon: 0.0577, Loss: 0.78 - Dyn Loss: 0.59 - Tot Reward: 50.78
# EPISODE: 464 - FINAL SCORE: 44 - Temp/epsilon: 0.0572, Loss: 0.75 - Dyn Loss: 0.60 - Tot Reward: 28.81
# EPISODE: 465 - FINAL SCORE: 63 - Temp/epsilon: 0.0566, Loss: 0.81 - Dyn Loss: 0.58 - Tot Reward: 45.02
# EPISODE: 466 - FINAL SCORE: 87 - Temp/epsilon: 0.0561, Loss: 0.81 - Dyn Loss: 0.58 - Tot Reward: 67.99
# EPISODE: 467 - FINAL SCORE: 73 - Temp/epsilon: 0.0555, Loss: 0.69 - Dyn Loss: 0.60 - Tot Reward: 53.44
# EPISODE: 468 - FINAL SCORE: 54 - Temp/epsilon: 0.0550, Loss: 0.73 - Dyn Loss: 0.58 - Tot Reward: 36.17
# EPISODE: 469 - FINAL SCORE: 45 - Temp/epsilon: 0.0545, Loss: 0.81 - Dyn Loss: 0.57 - Tot Reward: 29.83
# EPISODE: 470 - FINAL SCORE: 39 - Temp/epsilon: 0.0540, Loss: 0.73 - Dyn Loss: 0.59 - Tot Reward: 26.37
# EPISODE: 471 - FINAL SCORE: 54 - Temp/epsilon: 0.0534, Loss: 0.67 - Dyn Loss: 0.56 - Tot Reward: 33.58
# EPISODE: 472 - FINAL SCORE: 82 - Temp/epsilon: 0.0529, Loss: 0.75 - Dyn Loss: 0.57 - Tot Reward: 57.01
# EPISODE: 473 - FINAL SCORE: 61 - Temp/epsilon: 0.0524, Loss: 0.79 - Dyn Loss: 0.58 - Tot Reward: 39.38
# EPISODE: 474 - FINAL SCORE: 54 - Temp/epsilon: 0.0519, Loss: 0.78 - Dyn Loss: 0.58 - Tot Reward: 36.20
# EPISODE: 475 - FINAL SCORE: 61 - Temp/epsilon: 0.0514, Loss: 0.71 - Dyn Loss: 0.57 - Tot Reward: 38.30
# EPISODE: 476 - FINAL SCORE: 45 - Temp/epsilon: 0.0509, Loss: 0.73 - Dyn Loss: 0.58 - Tot Reward: 23.36
# EPISODE: 477 - FINAL SCORE: 56 - Temp/epsilon: 0.0504, Loss: 0.81 - Dyn Loss: 0.57 - Tot Reward: 36.06
# EPISODE: 478 - FINAL SCORE: 61 - Temp/epsilon: 0.0499, Loss: 0.79 - Dyn Loss: 0.58 - Tot Reward: 40.21
# EPISODE: 479 - FINAL SCORE: 44 - Temp/epsilon: 0.0495, Loss: 0.77 - Dyn Loss: 0.57 - Tot Reward: 27.04
# EPISODE: 480 - FINAL SCORE: 69 - Temp/epsilon: 0.0490, Loss: 0.73 - Dyn Loss: 0.56 - Tot Reward: 45.50
# EPISODE: 481 - FINAL SCORE: 60 - Temp/epsilon: 0.0485, Loss: 0.76 - Dyn Loss: 0.57 - Tot Reward: 37.37
# EPISODE: 482 - FINAL SCORE: 75 - Temp/epsilon: 0.0481, Loss: 0.81 - Dyn Loss: 0.58 - Tot Reward: 52.68
# EPISODE: 483 - FINAL SCORE: 54 - Temp/epsilon: 0.0476, Loss: 0.77 - Dyn Loss: 0.57 - Tot Reward: 36.45
# EPISODE: 484 - FINAL SCORE: 61 - Temp/epsilon: 0.0471, Loss: 0.85 - Dyn Loss: 0.57 - Tot Reward: 38.99
# EPISODE: 485 - FINAL SCORE: 61 - Temp/epsilon: 0.0467, Loss: 0.77 - Dyn Loss: 0.57 - Tot Reward: 38.34
# EPISODE: 486 - FINAL SCORE: 56 - Temp/epsilon: 0.0462, Loss: 0.77 - Dyn Loss: 0.56 - Tot Reward: 36.14
# EPISODE: 487 - FINAL SCORE: 89 - Temp/epsilon: 0.0458, Loss: 0.65 - Dyn Loss: 0.55 - Tot Reward: 63.91
# EPISODE: 488 - FINAL SCORE: 55 - Temp/epsilon: 0.0454, Loss: 0.62 - Dyn Loss: 0.56 - Tot Reward: 35.60
# EPISODE: 489 - FINAL SCORE: 155 - Temp/epsilon: 0.0449, Loss: 0.68 - Dyn Loss: 0.57 - Tot Reward: 125.98
# EPISODE: 490 - FINAL SCORE: 77 - Temp/epsilon: 0.0445, Loss: 0.69 - Dyn Loss: 0.55 - Tot Reward: 53.92
# EPISODE: 491 - FINAL SCORE: 82 - Temp/epsilon: 0.0441, Loss: 0.62 - Dyn Loss: 0.55 - Tot Reward: 57.95
# EPISODE: 492 - FINAL SCORE: 70 - Temp/epsilon: 0.0436, Loss: 0.75 - Dyn Loss: 0.56 - Tot Reward: 47.44
# EPISODE: 493 - FINAL SCORE: 67 - Temp/epsilon: 0.0432, Loss: 0.59 - Dyn Loss: 0.54 - Tot Reward: 46.11
# EPISODE: 494 - FINAL SCORE: 76 - Temp/epsilon: 0.0428, Loss: 0.67 - Dyn Loss: 0.54 - Tot Reward: 53.85
# EPISODE: 495 - FINAL SCORE: 59 - Temp/epsilon: 0.0424, Loss: 0.61 - Dyn Loss: 0.55 - Tot Reward: 38.16
# EPISODE: 496 - FINAL SCORE: 65 - Temp/epsilon: 0.0420, Loss: 0.69 - Dyn Loss: 0.55 - Tot Reward: 40.23
# EPISODE: 497 - FINAL SCORE: 57 - Temp/epsilon: 0.0416, Loss: 0.67 - Dyn Loss: 0.53 - Tot Reward: 35.63
# EPISODE: 498 - FINAL SCORE: 81 - Temp/epsilon: 0.0412, Loss: 0.75 - Dyn Loss: 0.55 - Tot Reward: 55.23
# EPISODE: 499 - FINAL SCORE: 111 - Temp/epsilon: 0.0408, Loss: 0.65 - Dyn Loss: 0.54 - Tot Reward: 78.05
# EPISODE: 500 - FINAL SCORE: 68 - Temp/epsilon: 0.0404, Loss: 0.65 - Dyn Loss: 0.53 - Tot Reward: 48.32
# EPISODE: 501 - FINAL SCORE: 85 - Temp/epsilon: 0.0400, Loss: 0.71 - Dyn Loss: 0.53 - Tot Reward: 54.11
# EPISODE: 502 - FINAL SCORE: 114 - Temp/epsilon: 0.0396, Loss: 0.60 - Dyn Loss: 0.53 - Tot Reward: 71.28
# EPISODE: 503 - FINAL SCORE: 86 - Temp/epsilon: 0.0392, Loss: 0.59 - Dyn Loss: 0.53 - Tot Reward: 52.01
# EPISODE: 504 - FINAL SCORE: 89 - Temp/epsilon: 0.0389, Loss: 0.65 - Dyn Loss: 0.53 - Tot Reward: 60.17
# EPISODE: 505 - FINAL SCORE: 87 - Temp/epsilon: 0.0385, Loss: 0.61 - Dyn Loss: 0.53 - Tot Reward: 53.35
# EPISODE: 506 - FINAL SCORE: 143 - Temp/epsilon: 0.0381, Loss: 0.63 - Dyn Loss: 0.52 - Tot Reward: 99.87
# EPISODE: 507 - FINAL SCORE: 88 - Temp/epsilon: 0.0377, Loss: 0.48 - Dyn Loss: 0.52 - Tot Reward: 61.31
# EPISODE: 508 - FINAL SCORE: 86 - Temp/epsilon: 0.0374, Loss: 0.64 - Dyn Loss: 0.53 - Tot Reward: 49.51
# EPISODE: 509 - FINAL SCORE: 112 - Temp/epsilon: 0.0370, Loss: 0.63 - Dyn Loss: 0.52 - Tot Reward: 69.24
# EPISODE: 510 - FINAL SCORE: 101 - Temp/epsilon: 0.0367, Loss: 0.61 - Dyn Loss: 0.52 - Tot Reward: 63.80
# EPISODE: 511 - FINAL SCORE: 137 - Temp/epsilon: 0.0363, Loss: 0.61 - Dyn Loss: 0.52 - Tot Reward: 85.56
# EPISODE: 512 - FINAL SCORE: 123 - Temp/epsilon: 0.0360, Loss: 0.61 - Dyn Loss: 0.51 - Tot Reward: 78.65
# EPISODE: 513 - FINAL SCORE: 142 - Temp/epsilon: 0.0356, Loss: 0.62 - Dyn Loss: 0.50 - Tot Reward: 89.98
# EPISODE: 514 - FINAL SCORE: 221 - Temp/epsilon: 0.0353, Loss: 0.59 - Dyn Loss: 0.50 - Tot Reward: 163.73
# EPISODE: 515 - FINAL SCORE: 154 - Temp/epsilon: 0.0349, Loss: 0.56 - Dyn Loss: 0.49 - Tot Reward: 96.91
# EPISODE: 516 - FINAL SCORE: 163 - Temp/epsilon: 0.0346, Loss: 0.48 - Dyn Loss: 0.50 - Tot Reward: 91.49
# EPISODE: 517 - FINAL SCORE: 153 - Temp/epsilon: 0.0343, Loss: 0.56 - Dyn Loss: 0.50 - Tot Reward: 96.45
# EPISODE: 518 - FINAL SCORE: 226 - Temp/epsilon: 0.0339, Loss: 0.47 - Dyn Loss: 0.50 - Tot Reward: 120.13
# EPISODE: 519 - FINAL SCORE: 300 - Temp/epsilon: 0.0336, Loss: 0.36 - Dyn Loss: 0.52 - Tot Reward: 190.92
# EPISODE: 520 - FINAL SCORE: 247 - Temp/epsilon: 0.0333, Loss: 0.35 - Dyn Loss: 0.52 - Tot Reward: -1136.00
# EPISODE: 521 - FINAL SCORE: 205 - Temp/epsilon: 0.0330, Loss: 0.35 - Dyn Loss: 0.53 - Tot Reward: -1378.44
# EPISODE: 522 - FINAL SCORE: 222 - Temp/epsilon: 0.0327, Loss: 0.53 - Dyn Loss: 0.68 - Tot Reward: -932.36
# EPISODE: 523 - FINAL SCORE: 242 - Temp/epsilon: 0.0323, Loss: 0.48 - Dyn Loss: 0.73 - Tot Reward: -1451.01
# EPISODE: 524 - FINAL SCORE: 201 - Temp/epsilon: 0.0320, Loss: 0.53 - Dyn Loss: 0.75 - Tot Reward: -861.87
# EPISODE: 525 - FINAL SCORE: 402 - Temp/epsilon: 0.0317, Loss: 0.54 - Dyn Loss: 0.79 - Tot Reward: 194.40
# EPISODE: 526 - FINAL SCORE: 224 - Temp/epsilon: 0.0314, Loss: 0.48 - Dyn Loss: 0.80 - Tot Reward: -1155.62
# EPISODE: 527 - FINAL SCORE: 309 - Temp/epsilon: 0.0311, Loss: 0.70 - Dyn Loss: 0.98 - Tot Reward: 194.16
# EPISODE: 528 - FINAL SCORE: 224 - Temp/epsilon: 0.0308, Loss: 0.70 - Dyn Loss: 0.94 - Tot Reward: 49.97
# EPISODE: 529 - FINAL SCORE: 149 - Temp/epsilon: 0.0305, Loss: 0.78 - Dyn Loss: 1.02 - Tot Reward: 102.24
# EPISODE: 530 - FINAL SCORE: 252 - Temp/epsilon: 0.0302, Loss: 0.65 - Dyn Loss: 0.92 - Tot Reward: 170.02
# EPISODE: 531 - FINAL SCORE: 289 - Temp/epsilon: 0.0299, Loss: 0.68 - Dyn Loss: 0.89 - Tot Reward: 224.83
# EPISODE: 532 - FINAL SCORE: 141 - Temp/epsilon: 0.0297, Loss: 0.79 - Dyn Loss: 1.03 - Tot Reward: 76.41
# EPISODE: 533 - FINAL SCORE: 82 - Temp/epsilon: 0.0294, Loss: 1.02 - Dyn Loss: 1.09 - Tot Reward: 53.88
# EPISODE: 534 - FINAL SCORE: 69 - Temp/epsilon: 0.0291, Loss: 0.86 - Dyn Loss: 0.96 - Tot Reward: 43.89
# EPISODE: 535 - FINAL SCORE: 99 - Temp/epsilon: 0.0288, Loss: 0.90 - Dyn Loss: 1.06 - Tot Reward: 66.14
# EPISODE: 536 - FINAL SCORE: 133 - Temp/epsilon: 0.0285, Loss: 0.79 - Dyn Loss: 1.03 - Tot Reward: 96.36
# EPISODE: 537 - FINAL SCORE: 87 - Temp/epsilon: 0.0283, Loss: 1.02 - Dyn Loss: 1.15 - Tot Reward: 59.24
# EPISODE: 538 - FINAL SCORE: 114 - Temp/epsilon: 0.0280, Loss: 0.72 - Dyn Loss: 0.95 - Tot Reward: 83.55
# EPISODE: 539 - FINAL SCORE: 73 - Temp/epsilon: 0.0277, Loss: 0.98 - Dyn Loss: 1.29 - Tot Reward: 51.51
# EPISODE: 540 - FINAL SCORE: 146 - Temp/epsilon: 0.0274, Loss: 0.72 - Dyn Loss: 1.04 - Tot Reward: 84.59
# EPISODE: 541 - FINAL SCORE: 231 - Temp/epsilon: 0.0272, Loss: 0.74 - Dyn Loss: 0.96 - Tot Reward: 164.71
# EPISODE: 542 - FINAL SCORE: 195 - Temp/epsilon: 0.0269, Loss: 0.89 - Dyn Loss: 1.13 - Tot Reward: 137.18
# EPISODE: 543 - FINAL SCORE: 141 - Temp/epsilon: 0.0267, Loss: 0.75 - Dyn Loss: 1.07 - Tot Reward: 95.29
# EPISODE: 544 - FINAL SCORE: 163 - Temp/epsilon: 0.0264, Loss: 0.95 - Dyn Loss: 1.05 - Tot Reward: 115.12
# EPISODE: 545 - FINAL SCORE: 240 - Temp/epsilon: 0.0262, Loss: 0.86 - Dyn Loss: 1.15 - Tot Reward: 170.63
# EPISODE: 546 - FINAL SCORE: 218 - Temp/epsilon: 0.0259, Loss: 0.83 - Dyn Loss: 1.04 - Tot Reward: 140.56
# EPISODE: 547 - FINAL SCORE: 182 - Temp/epsilon: 0.0257, Loss: 1.19 - Dyn Loss: 1.25 - Tot Reward: 129.91
# EPISODE: 548 - FINAL SCORE: 123 - Temp/epsilon: 0.0254, Loss: 1.03 - Dyn Loss: 1.24 - Tot Reward: 92.74
# EPISODE: 549 - FINAL SCORE: 221 - Temp/epsilon: 0.0252, Loss: 0.95 - Dyn Loss: 1.18 - Tot Reward: 160.80
# EPISODE: 550 - FINAL SCORE: 228 - Temp/epsilon: 0.0249, Loss: 1.13 - Dyn Loss: 1.08 - Tot Reward: 176.09
# EPISODE: 551 - FINAL SCORE: 185 - Temp/epsilon: 0.0247, Loss: 0.92 - Dyn Loss: 1.05 - Tot Reward: 123.96
# EPISODE: 552 - FINAL SCORE: 239 - Temp/epsilon: 0.0244, Loss: 1.17 - Dyn Loss: 1.10 - Tot Reward: 182.16
# EPISODE: 553 - FINAL SCORE: 207 - Temp/epsilon: 0.0242, Loss: 1.11 - Dyn Loss: 1.20 - Tot Reward: 145.98
# EPISODE: 554 - FINAL SCORE: 245 - Temp/epsilon: 0.0240, Loss: 1.05 - Dyn Loss: 1.23 - Tot Reward: 141.38
# EPISODE: 555 - FINAL SCORE: 200 - Temp/epsilon: 0.0237, Loss: 0.94 - Dyn Loss: 1.10 - Tot Reward: 148.61
# EPISODE: 556 - FINAL SCORE: 254 - Temp/epsilon: 0.0235, Loss: 1.08 - Dyn Loss: 1.18 - Tot Reward: 181.17
# EPISODE: 557 - FINAL SCORE: 258 - Temp/epsilon: 0.0233, Loss: 1.06 - Dyn Loss: 1.14 - Tot Reward: 178.90
# EPISODE: 558 - FINAL SCORE: 243 - Temp/epsilon: 0.0231, Loss: 0.95 - Dyn Loss: 1.19 - Tot Reward: 168.32
# EPISODE: 559 - FINAL SCORE: 312 - Temp/epsilon: 0.0228, Loss: 1.19 - Dyn Loss: 1.12 - Tot Reward: 193.94
# EPISODE: 560 - FINAL SCORE: 199 - Temp/epsilon: 0.0226, Loss: 1.05 - Dyn Loss: 1.16 - Tot Reward: 141.99
# EPISODE: 561 - FINAL SCORE: 215 - Temp/epsilon: 0.0224, Loss: 1.05 - Dyn Loss: 1.05 - Tot Reward: 151.88
# EPISODE: 562 - FINAL SCORE: 264 - Temp/epsilon: 0.0222, Loss: 1.08 - Dyn Loss: 1.20 - Tot Reward: 157.73
# EPISODE: 563 - FINAL SCORE: 361 - Temp/epsilon: 0.0220, Loss: 1.40 - Dyn Loss: 1.22 - Tot Reward: 181.40
# EPISODE: 564 - FINAL SCORE: 463 - Temp/epsilon: 0.0218, Loss: 1.24 - Dyn Loss: 1.25 - Tot Reward: 309.38
# EPISODE: 565 - FINAL SCORE: 213 - Temp/epsilon: 0.0216, Loss: 1.19 - Dyn Loss: 1.05 - Tot Reward: 151.84
# EPISODE: 566 - FINAL SCORE: 301 - Temp/epsilon: 0.0214, Loss: 1.38 - Dyn Loss: 1.11 - Tot Reward: 158.47
# EPISODE: 567 - FINAL SCORE: 231 - Temp/epsilon: 0.0211, Loss: 1.21 - Dyn Loss: 1.24 - Tot Reward: 149.40
# EPISODE: 568 - FINAL SCORE: 157 - Temp/epsilon: 0.0209, Loss: 1.02 - Dyn Loss: 1.06 - Tot Reward: 83.64
# EPISODE: 569 - FINAL SCORE: 251 - Temp/epsilon: 0.0207, Loss: 0.82 - Dyn Loss: 0.78 - Tot Reward: 139.38
# EPISODE: 570 - FINAL SCORE: 291 - Temp/epsilon: 0.0205, Loss: 0.80 - Dyn Loss: 0.75 - Tot Reward: -1225.23
# EPISODE: 571 - FINAL SCORE: 255 - Temp/epsilon: 0.0203, Loss: 0.45 - Dyn Loss: 0.78 - Tot Reward: 113.36
# EPISODE: 572 - FINAL SCORE: 346 - Temp/epsilon: 0.0202, Loss: 0.50 - Dyn Loss: 0.67 - Tot Reward: 187.51
# EPISODE: 573 - FINAL SCORE: 373 - Temp/epsilon: 0.0200, Loss: 0.55 - Dyn Loss: 0.62 - Tot Reward: -458.73
# EPISODE: 574 - FINAL SCORE: 500 - Temp/epsilon: 0.0198, Loss: 0.59 - Dyn Loss: 0.54 - Tot Reward: 283.76
# EPISODE: 575 - FINAL SCORE: 343 - Temp/epsilon: 0.0196, Loss: 0.43 - Dyn Loss: 0.53 - Tot Reward: 214.77
# EPISODE: 576 - FINAL SCORE: 500 - Temp/epsilon: 0.0194, Loss: 0.57 - Dyn Loss: 0.61 - Tot Reward: 283.66
# EPISODE: 577 - FINAL SCORE: 175 - Temp/epsilon: 0.0192, Loss: 0.59 - Dyn Loss: 0.58 - Tot Reward: 124.52
# EPISODE: 578 - FINAL SCORE: 417 - Temp/epsilon: 0.0190, Loss: 0.50 - Dyn Loss: 0.56 - Tot Reward: -650.39
# EPISODE: 579 - FINAL SCORE: 500 - Temp/epsilon: 0.0188, Loss: 0.82 - Dyn Loss: 0.72 - Tot Reward: 371.74
# EPISODE: 580 - FINAL SCORE: 500 - Temp/epsilon: 0.0187, Loss: 0.73 - Dyn Loss: 0.70 - Tot Reward: 183.46
# EPISODE: 581 - FINAL SCORE: 500 - Temp/epsilon: 0.0185, Loss: 0.68 - Dyn Loss: 0.71 - Tot Reward: -798.24
# EPISODE: 582 - FINAL SCORE: 498 - Temp/epsilon: 0.0183, Loss: 0.91 - Dyn Loss: 0.85 - Tot Reward: 87.32
# EPISODE: 583 - FINAL SCORE: 413 - Temp/epsilon: 0.0181, Loss: 1.09 - Dyn Loss: 0.90 - Tot Reward: 242.69
# EPISODE: 584 - FINAL SCORE: 500 - Temp/epsilon: 0.0179, Loss: 0.86 - Dyn Loss: 0.86 - Tot Reward: 325.54
# EPISODE: 585 - FINAL SCORE: 395 - Temp/epsilon: 0.0178, Loss: 0.95 - Dyn Loss: 0.85 - Tot Reward: 183.38
# EPISODE: 586 - FINAL SCORE: 375 - Temp/epsilon: 0.0176, Loss: 1.28 - Dyn Loss: 0.86 - Tot Reward: -1197.55
# EPISODE: 587 - FINAL SCORE: 384 - Temp/epsilon: 0.0174, Loss: 0.93 - Dyn Loss: 0.98 - Tot Reward: 247.26
# EPISODE: 588 - FINAL SCORE: 387 - Temp/epsilon: 0.0173, Loss: 1.40 - Dyn Loss: 1.12 - Tot Reward: -671.76
# EPISODE: 589 - FINAL SCORE: 481 - Temp/epsilon: 0.0171, Loss: 1.63 - Dyn Loss: 1.19 - Tot Reward: -692.14
# EPISODE: 590 - FINAL SCORE: 408 - Temp/epsilon: 0.0169, Loss: 1.75 - Dyn Loss: 1.22 - Tot Reward: 255.24
# EPISODE: 591 - FINAL SCORE: 358 - Temp/epsilon: 0.0168, Loss: 2.03 - Dyn Loss: 1.17 - Tot Reward: -915.26
# EPISODE: 592 - FINAL SCORE: 500 - Temp/epsilon: 0.0166, Loss: 2.23 - Dyn Loss: 1.42 - Tot Reward: 331.67
# EPISODE: 593 - FINAL SCORE: 426 - Temp/epsilon: 0.0165, Loss: 1.82 - Dyn Loss: 1.43 - Tot Reward: -1288.44
# EPISODE: 594 - FINAL SCORE: 410 - Temp/epsilon: 0.0163, Loss: 2.05 - Dyn Loss: 1.45 - Tot Reward: -1221.13
# EPISODE: 595 - FINAL SCORE: 406 - Temp/epsilon: 0.0161, Loss: 2.35 - Dyn Loss: 1.57 - Tot Reward: -1223.24
# EPISODE: 596 - FINAL SCORE: 480 - Temp/epsilon: 0.0160, Loss: 2.35 - Dyn Loss: 1.57 - Tot Reward: -572.17
# EPISODE: 597 - FINAL SCORE: 324 - Temp/epsilon: 0.0158, Loss: 3.08 - Dyn Loss: 1.79 - Tot Reward: -751.94
# EPISODE: 598 - FINAL SCORE: 317 - Temp/epsilon: 0.0157, Loss: 3.03 - Dyn Loss: 1.63 - Tot Reward: -1078.97
# EPISODE: 599 - FINAL SCORE: 480 - Temp/epsilon: 0.0155, Loss: 2.69 - Dyn Loss: 1.87 - Tot Reward: -792.59
# EPISODE: 600 - FINAL SCORE: 349 - Temp/epsilon: 0.0154, Loss: 3.27 - Dyn Loss: 1.96 - Tot Reward: -861.44
# EPISODE: 601 - FINAL SCORE: 500 - Temp/epsilon: 0.0152, Loss: 3.57 - Dyn Loss: 1.98 - Tot Reward: 401.95

# %%
# Display the videos, not required outside Colab
if colab and show_video:
    show_videos()

# %%
#plot scores and losses
fig = plt.figure(figsize=(12,3))
plt.subplot(1,2,1)
plt.plot(scores, label='Scores')
plt.title('Scores')
plt.plot(exploration_profile, label='Exploration profile')
# plt.ylim(0, 1.8)
plt.grid()
plt.legend()
plt.subplot(1,2,2)
plt.plot(losses, label='Losses')
plt.plot(dyn_losses, label='Dynamics Losses')
plt.title('Losses and exploration profile')
plt.plot(exploration_profile, label='Exploration profile')
# plt.ylim(0,0.2)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Adding an exploration profile makes the loss go down, however the score goes down with the loss too

# %% [markdown]
# # Final test

# %%
# Initialize the Gym environment
env = gym.make('CartPole-v1') 
env.seed(1) # Set a random seed for the environment (reproducible results)
if colab:
  env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode    
 
for i in range(10):    
    if use_epsilon_greedy:
        epsilon = tau

    # Reset the environment and get the initial state
    _ = env.reset()
    state, prev_frame = get_frame(env, None, resize=(x,y))
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False

    # Go on until the pole falls off
    episode_loss = []
    while not done:
        # Choose the action following the policy
        action, q_values = choose_action_epsilon_greedy(policy_net, state, 0) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=0)
        # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
        _, reward, done, _ = env.step(action)
        score += reward
        next_state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=True)
        state = next_state
    scores.append(score)
env.close()

print(f"AVERAGE SCORE: {np.mean(scores)}")
# Out:
# AVERAGE SCORE: 416.0

# %%
# # Initialize the Gym environment
# env = gym.make('CartPole-v1') 
# env.seed(1) # Set a random seed for the environment (reproducible results)

# # This is for creating the output video in Colab, not required outside Colab
# if colab:
#   env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode

# # Let's try for a total of 10 episodes
# scores = []
# for num_episode in range(10): 
#     # Reset the environment and get the initial state
#     _ = env.reset()
#     state, prev_frame = get_frame(env, None, resize=(x,y))
#     # Reset the score. The final score will be the total amount of steps before the pole falls
#     score = 0
#     done = False
#     # Go on until the pole falls off or the score reach 490
#     while not done:
#       # Choose the best action (temperature 0)
#       action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon=0) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=0) 
#       # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
#       _, reward, done, info = env.step(action)
#       state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=True)
#       # # plot prev_frame in grayscale
#       # plt.imshow(prev_frame, cmap='gray')
#       # plt.show()
#       # plt.close()
#       # Update the final score (+1 for each step)
#       score += reward 
#     # Print the final score
#     #print(f"EPISODE {num_episode + 1} - FINAL SCORE: {score}") 
#     scores.append(score)  
# env.close()

# #print the average score
# print(f"AVERAGE SCORE: {np.mean(scores)}")

# %%
#let an agent play for a few episodes   
#doesn't work in colab, but works in local
if not colab:
    env = gym.make('CartPole-v1')
    #env.seed(42)

    show_render = True

    scores = []
    # Reset the environment and get the initial state
    _ = env.reset()
    state, prev_frame = get_frame(env, None, device=device, resize=(x,y))
    # Reset the score. The final score will be the total amount of steps before the pole falls
    # Go on
    for i in range(1000):
        # Choose the best action (temperature 0)
        action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon=0) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=0) 
        # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
        _, reward, done, info = env.step(action)
        state, prev_frame = get_frame(env, prev_frame, device=device, resize=(x,y), plot=True)

    env.close()

# %%
# Display the videos, not required outside Colab
if colab: 
    show_videos()
