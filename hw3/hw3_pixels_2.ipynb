# %% [markdown]
# # HOMEWORK 3 NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2021/22 (6 CFU) - Dr. Alberto Testolin, Dr. Umberto Michieli
# ---
# Student: Matteo Grandin
# ---
# id: 2020374

# %% [markdown]
# # Reinforced Learning

# %% [markdown]
# ### General overview
# In this homework you will learn how to implement and test neural network models for
# solving reinforcement learning problems. The basic tasks for the homework will require to implement some
# extensions to the code that you have seen in the Lab. The advanced tasks will require to train and test your
# learning agent on a different type of input (image pixels) or Gym environment. You can just choose one of
# the advanced tasks to get the maximum grade. If you are interested in improving your skills, feel free to try
# both advanced tasks. Given the higher computational complexity of RL, in this homework you don’t need to
# tune learning hyperparameters using search procedures and cross-validation; however, you are encouraged
# to play with model hyperparameters to find a satisfactory configuration.
#
#
# - 3 pt: use the notebook of Lab 07 to study how the exploration profile (either using eps-greedy or
# softmax) impacts the learning curve. Tune a bit the model hyperparameters or tweak the reward
# function to speed-up learning convergence (i.e., reach the same accuracy with fewer training episodes).
#
# YOU CAN DO JUST 1 OR BOTH
# - 5 pt: extend the notebook used in Lab 07, in order to learn to control the CartPole environment using
# directly the screen pixels, rather than the compact state representation used during the Lab (cart
# position, cart velocity, pole angle, pole angular velocity). NB: this will require to change the
# “observation_space” and to look for smart ways of encoding the pixels in a compact way to reduce
# computational complexity (e.g., crop the image around the pole, use difference of consecutive frames
# as input to consider temporal context, etc.).
#
# OR
#
# - 5 pt: train a deep RL agent on a different Gym environment. You are free to choose whatever Gym
# environment you like from the available list, or even explore other simulation platforms.

# %%
# Boolean value to check if we are in colab or not
colab = False 
show_video = False
show_render = False

# %%
if colab:
    # !pip install gym
else:
    # %pip install gym
# Out:
# Requirement already satisfied: gym in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (0.21.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (4.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from gym) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import torch
import numpy as np
import gym
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torch.nn.functional as F
import os
from torch import nn
from collections import deque # this python module implements exactly what we need for the replay memeory

#import opencv
import cv2

#use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")

#create a folder called training
if not os.path.exists('training'):
    os.makedirs('training')

# %%
if colab:
    # !apt update
    # !apt-get install python-opengl -y
    # !apt install xvfb -y
    # !pip install pyvirtualdisplay
    # !pip install piglet
    import glob
    import io
    import base64
    import os
    from IPython.display import HTML
    from IPython import display as ipythondisplay
    from pyvirtualdisplay import Display
    from gym.wrappers import Monitor

    display = Display(visible=0, size=(1400, 900))
    display.start()

    if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
        # !bash ../xvfb start
        # %env DISPLAY=:1

    """
    Utility functions to enable video recording of gym environment and displaying it
    To enable video, just do "env = wrap_env(env)""
    """

    def show_videos():
        mp4list = glob.glob('video/*.mp4')
        mp4list.sort()
        for mp4 in mp4list:
            print(f"\nSHOWING VIDEO {mp4}")
            video = io.open(mp4, 'r+b').read()
            encoded = base64.b64encode(video)
            ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                        loop controls style="height: 400px;">
                        <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                    </video>'''.format(encoded.decode('ascii'))))
            
    def wrap_env(env, video_callable=None):
        env = Monitor(env, './video', force=True, video_callable=video_callable)
        return env

# %%
class ReplayMemory(object):

    def __init__(self, capacity, x=32, y=16):
        #if x and y are small u can fit everything in gpu memory
        self.memory = torch.zeros((capacity, 3, y, x), dtype=torch.float32, device=device) #capacity, action, reward, 2 states
        self.x = x
        self.y = y 
        self.memory_index = 0
        self.capacity = capacity
        self.full = False
        #self.memory = deque(maxlen=capacity) # Define a queue with maxlen "capacity"

    def push(self, state, action, next_state, reward):
        if state is None or action is None or reward is None:
            print("WARNING: None value passed to ReplayMemory.push()")
            return
        # TODO: Add the tuple (state, action, next_state, reward) to the queue
        self.memory[self.memory_index][0] = torch.from_numpy(state).float().to(device)
        self.memory[self.memory_index][1,0,0] = action
        self.memory[self.memory_index][1,1,0] = reward
        if next_state is not None:
            self.memory[self.memory_index][2] = torch.from_numpy(next_state).float().to(device) 
            self.memory[self.memory_index][1,1,1] = 1 # bool true
        else:
            self.memory[self.memory_index][1,1,1] = 0 #mask is false
        #increase the index, and wrap it around if it is bigger than the capacity
        if self.memory_index == self.capacity-1:
            self.full = True
        self.memory_index = (self.memory_index + 1) % self.memory.shape[0]
        
        # self.memory.append((state, action, next_state, reward))
        # print(f"state: {state.shape}, action: {action}, next_state: {next_state.shape}, reward: {reward}")

    def sample(self, batch_size):
        batch_size = min(batch_size, len(self)) # Get all the samples if the requested batch_size is higher than the number of sample currently in the memory
        # select indeces
        indeces = np.random.choice(self.capacity, batch_size, replace=False)
        # return the samples
        ret = self.memory[indeces, :]
        # ret = torch.from_numpy(ret).float().to(device)
        states = ret[:,0].unsqueeze(1)
        actions = ret[:,1,0,0].long()
        rewards = ret[:,1,1,0]
        non_final_mask = ret[:,1,1,1].bool()
        non_final_next_states = ret[:,2].unsqueeze(1)
        non_final_next_states = non_final_next_states[non_final_mask]

        #print(f"states: {states.shape}, actions: {actions.shape}, rewards: {rewards.shape}, non_final_next_states: {non_final_next_states.shape}, non_final_mask: {non_final_mask.shape}")

        return states, actions, rewards, non_final_next_states, non_final_mask
        # return random.sample(self.memory, batch_size) # Randomly select "batch_size" samples

    def __len__(self):
        if self.full:
            return self.capacity
        else:
            return self.memory_index
        # return len(self.memory) # Return the number of samples currently stored in the memory

# %%
class DQN(nn.Module):

    def __init__(self, state_space_dim, action_space_dim):
        super().__init__()
        n_hid = 128
        
        self.conv = nn.Sequential( #128x64 #32x32
            # First convolutional layer
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=4, stride=2), #61x29 #15x15
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=2), #19x8 #7x7
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=2), #7x1 #3x3
            nn.ReLU(True),
        )

        self.flatten = nn.Flatten()
        
        self.linear = nn.Sequential(
            #inpt layer
            nn.Linear(64*3*3, n_hid), 
            nn.ReLU(True),
            #nn.Dropout(0.2), #bad
            #hidden layer
            nn.Linear(n_hid, n_hid),
            nn.ReLU(True),
            #nn.Dropout(0.2), #bad
            #outpt layer
            nn.Linear(n_hid, action_space_dim),
                )

    def forward(self, x):
        x = self.conv(x)
        x = self.flatten(x)
        x = self.linear(x)
        return x

# %% [markdown]
# ## Exploration Policy

# %%
def choose_action_epsilon_greedy(net, state, epsilon):
    if epsilon > 1 or epsilon < 0:
        raise Exception('The epsilon value must be between 0 and 1')
                
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = state[np.newaxis, :]
        state = torch.tensor(state, dtype=torch.float32,device=device) # Convert the state to tensor
        net_out = net(state)
        

    # Get the best action (argmax of the network output)
    best_action = int(net_out.argmax())
    # Get the number of possible actions
    action_space_dim = net_out.shape[-1]

    # Select a non optimal action with probability epsilon, otherwise choose the best action
    if random.random() < epsilon:
        # List of non-optimal actions
        non_optimal_actions = [a for a in range(action_space_dim) if a != best_action]
        # Select randomly
        action = random.choice(non_optimal_actions)
    else:
        # Select best action
        action = best_action
        
    return action, net_out.cpu().numpy()

# %%
def choose_action_softmax(net, state, temperature):
    if temperature < 0:
        raise Exception('The temperature value must be greater than or equal to 0 ')
        
    # If the temperature is 0, just select the best action using the eps-greedy policy with epsilon = 0
    if temperature == 0:
        return choose_action_epsilon_greedy(net, state, 0)
    
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(1)
        net_out = net(state)

    # Apply softmax with temp
    temperature = max(temperature, 1e-8) # set a minimum to the temperature for numerical stability
    softmax_out = F.softmax(net_out/temperature, dim=1).squeeze().cpu().numpy()
                
    # Sample the action using softmax output as mass pdf
    all_possible_actions = np.arange(0, softmax_out.shape[-1])
    # print(f"softmax_out: {softmax_out}, all_possible_actions: {all_possible_actions}")
    action = np.random.choice(all_possible_actions, p=softmax_out) # this samples a random element from "all_possible_actions" with the probability distribution p (softmax_out in this case)
    
    return action, net_out.cpu().numpy()

# %% [markdown]
# ### Exploration profile

# %%
### Define exploration profile
def get_exploration_profile(initial_value=0.5, num_iterations=1000, speed = 3): # speed = speed of convergence, bigger is faster to reach 0
    if initial_value < 0:
        raise Exception('The initial value must be > 0')
    if initial_value > 1:
        exp_decay = np.exp(-np.log(initial_value) / num_iterations * speed) # We compute the exponential decay in such a way the shape of the exploration profile does not depend on the number of iterations
    else :
        exp_decay = np.exp(np.log(initial_value) / num_iterations * speed)
    exploration_profile = [initial_value * (exp_decay ** i) for i in range(num_iterations)]
    return exploration_profile

exploration_profile = get_exploration_profile()

### Plot exploration profile
plt.figure(figsize=(12,3))
plt.plot(exploration_profile)
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Exploration profile (Softmax temperature)')
# Out:
# Text(0, 0.5, 'Exploration profile (Softmax temperature)')

# %% [markdown]
# # Gym Environment (CartPole-v1)

# %%
### Create environment
env = gym.make('CartPole-v1') # Initialize the Gym environment
env.seed(0) # Set a random seed for the environment (reproducible results)

# Get the shapes of the state space (observation_space) and action space (action_space)
# state_space_dim = env.observation_space.shape[0]
action_space_dim = env.action_space.n

if colab:
  env = wrap_env(env, video_callable=lambda episode_id: True)

# %%
#function to get the frame
def get_frame(env, prev_frame, resize=(32,32), device=device, plot=False):
    # Get the current frame 
    frame = env.render(mode='rgb_array')
    pos = env.state[0] #-2.4 to 2.4 in the frame
    c = round(pos*300/2.4 + 300) #center of the cart
    #convert to grayscale
    frame = np.mean(frame, axis=2)
    original_frame = frame
    #convert to binary
    frame[frame < 255] = 0
    frame = frame / 255
    frame = (1 - frame) 
    frame[frame==0] = 1/3
    frame[frame==1] = 2/3    

    if prev_frame is not None:
        diff = 2*frame - prev_frame
    else :
        diff = frame / 2

    prev_frame = frame

    #draw a small square in the absolute middle of diff
    diff[150:170,270:274] = 0.1
    diff[150:170,326:330] = 0.9
    
    if c < 64 or c > (600-64): #out of frame
        diff = np.zeros((300,300))
    else:
        diff = diff[150:300, (c-64):(c+64)]

    diff = cv2.resize(diff, resize, interpolation=cv2.INTER_CUBIC)
    diff = diff[np.newaxis, :]

    if plot and not colab:
        #show diff with opencv
        cv2.imshow('diff', diff[0])
        #cv2.imshow('prev_frame',prev_frame)
        cv2.waitKey(1)
    
    return diff, prev_frame

# %%
# if not colab:
#     env.seed(1)
#     observation = env.reset()
#     #set seed
#     frame, prev_frame = get_frame(env, None)
#     for t in range(500):
#         frame, prev_frame = get_frame(env, prev_frame, plot=True)
#         action = env.action_space.sample()
#         observation, reward, done, info = env.step(action)
#         done = False

#         c = env.state[0]*300/2.4 + 300
#         #if c < 64 or c > (600-64):
#             #done = True #doesn't work in colab
        
#         if done:
#             print("Episode finished after {} timesteps".format(t+1))
#             break
#     env.close()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Network update

# %%
# ### PARAMETERS
# gamma = 0.95  #0.97 gamma parameter for the long term reward #0.99999 # 0.9
# replay_memory_capacity = 10000   #10000 Replay memory capacity #10000 # 5000
# lr = 2e-2   #1e-2 Optimizer learning rate #1e-2 # 0.12
# target_net_update_steps = 10   #10 Number of episodes to wait before updating the target network #10 # 8
# batch_size = 256   #128 Number of samples to take from the replay memory for each update #256 # 256
# bad_state_penalty = 0  #0 Penalty to the reward when we are in a bad state (in this case when the pole falls down)  #0 # 0
# min_samples_for_training = 1111   #1000 Minimum samples in the replay memory to enable the training #1000 # 500
# use_epsilon_greedy = False   #False Use epsilon greedy exploration or not #True # False
# #set up exploration profile for softmax
# initial_value = 5 #5 Initial temperature/epsilon value for the exploration profile #0.5 # 5
# num_iterations = 1700 # Number of episodes 1000, #300 # 120
# convergence_speed = 6 #6 Speed of convergence of the exploration profile # 1 # 0.8
# exploration_profile = get_exploration_profile(initial_value, num_iterations, speed = convergence_speed)

# %%
# Set random seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

laod_good_model = False

x,y = 32,32 #32, 16
state_space_dim = x * y #the image is 32*16

### PARAMETERS
gamma = 0.9  #0.97 gamma parameter for the long term reward #0.99999 # 0.9
replay_memory_capacity = 15000   #10000 Replay memory capacity #10000 # 5000
lr = 5e-2   #1e-2 Optimizer learning rate #1e-2 # 0.12
target_net_update_steps = 5   #10 Number of episodes to wait before updating the target network #10 # 8
batch_size = 128   #128 Number of samples to take from the replay memory for each update #256 # 256
bad_state_penalty = 0  #0 Penalty to the reward when we are in a bad state (in this case when the pole falls down)  #0 # 0
min_samples_for_training = 1111   #1000 Minimum samples in the replay memory to enable the training #1000 # 500
use_epsilon_greedy = False   #False Use epsilon greedy exploration or not #True # False
#set up exploration profile for softmax
initial_value = 5 #5 Initial temperature/epsilon value for the exploration profile #0.5 # 5
num_iterations = 300 # Number of episodes 1000, #300 # 120
convergence_speed = 5 #6 Speed of convergence of the exploration profile # 1 # 0.8
exploration_profile = get_exploration_profile(initial_value, num_iterations, speed = convergence_speed)

# %% [markdown]
# lowering target_net_update_steps from 10 to 8 had a huge impact, learning rate could be set higher too and gamma could be lowered.

# %%
### Initialize the replay memory
replay_mem = ReplayMemory(replay_memory_capacity, x=x, y=y)

### Initialize the policy network
policy_net = DQN(state_space_dim, action_space_dim ).to(device)

### Initialize the target network with the same weights of the policy network
target_net = DQN(state_space_dim, action_space_dim).to(device)
target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

### Initialize the optimizer
optimizer = torch.optim.SGD(policy_net.parameters(), lr=lr) # The optimizer will update ONLY the parameters of the policy network

### Initialize the loss function (Huber loss)
loss_fn = nn.SmoothL1Loss()

losses, scores = [],[]

# %%
def update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size):
        
  # Sample the data from the replay memory
  states, actions, rewards, non_final_next_states, non_final_mask = replay_mem.sample(batch_size)

  #print(f"states: {states.shape}, actions: {actions.shape}, rewards: {rewards.shape}, non_final_next_states: {non_final_next_states.shape}, non_final_mask: {non_final_mask.shape}")
  
  # # Create tensors for each element of the batch
  # states      = torch.tensor([s[0] for s in batch], dtype=torch.float32, device=device)
  # actions     = torch.tensor([s[1] for s in batch], dtype=torch.int64, device=device)
  # rewards     = torch.tensor([s[3] for s in batch], dtype=torch.float32, device=device)

  # Compute a mask of non-final states (all the elements where the next state is not None)
  # non_final_next_states = torch.tensor([s[2] for s in batch if s[2] is not None], dtype=torch.float32, device=device) # the next state can be None if the game has ended
  # non_final_mask = torch.tensor([s[2] is not None for s in batch], dtype=torch.bool, device=device)

  # Compute all the Q values (forward pass)
  policy_net.train()
  q_values = policy_net(states)

  # Select the proper Q value for the corresponding action taken Q(s_t, a)
  state_action_values = q_values.gather(1, actions.unsqueeze(1))

  # Compute the value function of the next states using the target network V(s_{t+1}) = max_a( Q_target(s_{t+1}, a)) )
  with torch.no_grad():
    target_net.eval()
    q_values_target = target_net(non_final_next_states)
  next_state_max_q_values = torch.zeros(batch_size, device=device)
  next_state_max_q_values[non_final_mask] = q_values_target.max(dim=1)[0]

  # Compute the expected Q values
  expected_state_action_values = rewards + (next_state_max_q_values * gamma)
  expected_state_action_values = expected_state_action_values.unsqueeze(1) # Set the required tensor shape

  # Compute the Huber loss
  loss = loss_fn(state_action_values, expected_state_action_values)

  # Optimize the model
  optimizer.zero_grad()
  loss.backward()
  # Apply gradient clipping (clip all the gradients greater than 2 for training stability)
  nn.utils.clip_grad_norm_(policy_net.parameters(), 2)
  optimizer.step()
  return loss.item()

# %%
if not laod_good_model: #TRAIN
    # Initialize the Gym environment
    env = gym.make('CartPole-v1') 
    env.seed(0) # Set a random seed for the environment (reproducible results)

    # This is for creating the output video in Colab, not required outside Colab
    if colab:
        env = wrap_env(env, video_callable=lambda episode_id: episode_id % 100 == 0) # Save a video every 100 episodes

    good_scores_counter = 0

    #list of losses and scores
    for episode_num, tau in enumerate(tqdm(exploration_profile)):
        if use_epsilon_greedy:
            epsilon = tau

        # Reset the environment and get the initial state
        state_info = env.reset()
        state, prev_frame = get_frame(env, None, resize=(x,y))
        # Reset the score. The final score will be the total amount of steps before the pole falls
        score = 0
        done = False

        # Go on until the pole falls off
        episode_loss = []
        while not done:
            # Choose the action following the policy
            action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=tau)
            
            # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
            state_info, reward, done, info = env.step(action)
            next_state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=False)

            #penalty based on the cart being off the screen
            c = env.state[0]*300/2.4 + 300
            if c < 64 or c > (600-64):
                reward -= 100
            
            # We apply a (linear) penalty when the cart is far from center
            pos_weight = 0.1
            reward = reward - pos_weight * np.abs(state_info[0]) 

            #linear penalty for the angle
            angle_weight = 2.0
            reward = reward - angle_weight * np.abs(state_info[2])

            # Update the final score (+1 for each step)
            score += 1

            # Apply penalty for bad state
            if done: # if the pole has fallen down 
                reward += bad_state_penalty
                next_state = None

            # Update the replay memory
            replay_mem.push(state, action, next_state, reward)

            # # lower learning rate after a certain number of steps, important if the learning rate is very aggressive
            # # in the early stages of the training 
            # if episode_num > 120:
            #     for param_group in optimizer.param_groups:
            #         param_group['lr'] = 2e-3


            # Update the network
            if len(replay_mem) > min_samples_for_training: # we enable the training only if we have enough samples in the replay memory, otherwise the training will use the same samples too often
                loss = update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size)
                episode_loss.append(loss)
                
            # Visually render the environment (disable to speed up the training)
            if not colab and show_render:
                env.render()

            # Set the current state for the next iteration
            state = next_state
        #end of while loop

        #get episode loss
        average_episode_loss = np.mean(episode_loss)
        losses.append(average_episode_loss)
        #get episode score
        scores.append(score)

        # Update the target network every target_net_update_steps episodes
        if episode_num % target_net_update_steps == 0:
            #print('Updating target network...')
            target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

        if score > 200:
          optimizer = torch.optim.SGD(policy_net.parameters(), lr=1e-2) ###############################################################################
          if score > 300:
            optimizer = torch.optim.SGD(policy_net.parameters(), lr=5e-3) ###############################################################################


        #Print the final score
        print(f"EPISODE: {episode_num + 1} - FINAL SCORE: {score} - Temperature/epsilo: {tau}") # Print the final score
    env.close()


    #save the model
    torch.save(policy_net.state_dict(), f'training/cartpole_policy_net_{num_iterations}.pt')
    #save scores and losses
    np.save(f'training/cartpole_scores_{num_iterations}.npy', scores)
    np.save(f'training/cartpole_losses_{num_iterations}.npy', losses)

else: #LOAD MODEL
    #load the model
    policy_net.load_state_dict(torch.load(f'training/cartpole_policy_net_{num_iterations}.pt'))
    target_net.load_state_dict(torch.load(f'training/cartpole_policy_net_{num_iterations}.pt'))
    #load scores and losses
    scores = np.load(f'training/cartpole_scores_{num_iterations}.npy')
    losses = np.load(f'training/cartpole_losses_{num_iterations}.npy')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# EPISODE: 1 - FINAL SCORE: 12 - Temperature/epsilo: 5.0
# EPISODE: 2 - FINAL SCORE: 17 - Temperature/epsilo: 4.943985795372832
# EPISODE: 3 - FINAL SCORE: 41 - Temperature/epsilo: 4.888599108969667
# EPISODE: 4 - FINAL SCORE: 19 - Temperature/epsilo: 4.833832910803664
# EPISODE: 5 - FINAL SCORE: 24 - Temperature/epsilo: 4.779680249643805
# EPISODE: 6 - FINAL SCORE: 14 - Temperature/epsilo: 4.726134252132609
# EPISODE: 7 - FINAL SCORE: 34 - Temperature/epsilo: 4.673188121913724
# EPISODE: 8 - FINAL SCORE: 27 - Temperature/epsilo: 4.6208351387693
# EPISODE: 9 - FINAL SCORE: 15 - Temperature/epsilo: 4.569068657767013
# EPISODE: 10 - FINAL SCORE: 21 - Temperature/epsilo: 4.517882108416665
# EPISODE: 11 - FINAL SCORE: 31 - Temperature/epsilo: 4.4672689938362105
# EPISODE: 12 - FINAL SCORE: 59 - Temperature/epsilo: 4.417222889927142
# EPISODE: 13 - FINAL SCORE: 29 - Temperature/epsilo: 4.367737444559104
# EPISODE: 14 - FINAL SCORE: 26 - Temperature/epsilo: 4.318806376763649
# EPISODE: 15 - FINAL SCORE: 18 - Temperature/epsilo: 4.270423475937018
# EPISODE: 16 - FINAL SCORE: 14 - Temperature/epsilo: 4.222582601051858
# EPISODE: 17 - FINAL SCORE: 17 - Temperature/epsilo: 4.175277679877771
# EPISODE: 18 - FINAL SCORE: 27 - Temperature/epsilo: 4.128502708210587
# EPISODE: 19 - FINAL SCORE: 20 - Temperature/epsilo: 4.0822517491102825
# EPISODE: 20 - FINAL SCORE: 67 - Temperature/epsilo: 4.036518932147427
# EPISODE: 21 - FINAL SCORE: 16 - Temperature/epsilo: 3.9912984526580786
# EPISODE: 22 - FINAL SCORE: 24 - Temperature/epsilo: 3.946584571007021
# EPISODE: 23 - FINAL SCORE: 16 - Temperature/epsilo: 3.902371611859259
# EPISODE: 24 - FINAL SCORE: 52 - Temperature/epsilo: 3.8586539634596715
# EPISODE: 25 - FINAL SCORE: 16 - Temperature/epsilo: 3.8154260769207395
# EPISODE: 26 - FINAL SCORE: 11 - Temperature/epsilo: 3.772682465518246
# EPISODE: 27 - FINAL SCORE: 42 - Temperature/epsilo: 3.7304177039948723
# EPISODE: 28 - FINAL SCORE: 23 - Temperature/epsilo: 3.688626427871596
# EPISODE: 29 - FINAL SCORE: 13 - Temperature/epsilo: 3.6473033327668007
# EPISODE: 30 - FINAL SCORE: 19 - Temperature/epsilo: 3.6064431737230107
# EPISODE: 31 - FINAL SCORE: 16 - Temperature/epsilo: 3.566040764541176
# EPISODE: 32 - FINAL SCORE: 14 - Temperature/epsilo: 3.5260909771224096
# EPISODE: 33 - FINAL SCORE: 28 - Temperature/epsilo: 3.486588740817101
# EPISODE: 34 - FINAL SCORE: 26 - Temperature/epsilo: 3.447529041781319
# EPISODE: 35 - FINAL SCORE: 18 - Temperature/epsilo: 3.4089069223404307
# EPISODE: 36 - FINAL SCORE: 14 - Temperature/epsilo: 3.3707174803598416
# EPISODE: 37 - FINAL SCORE: 16 - Temperature/epsilo: 3.3329558686227925
# EPISODE: 38 - FINAL SCORE: 24 - Temperature/epsilo: 3.2956172942151207
# EPISODE: 39 - FINAL SCORE: 12 - Temperature/epsilo: 3.258697017916921
# EPISODE: 40 - FINAL SCORE: 11 - Temperature/epsilo: 3.222190353601013
# EPISODE: 41 - FINAL SCORE: 25 - Temperature/epsilo: 3.186092667638154
# EPISODE: 42 - FINAL SCORE: 17 - Temperature/epsilo: 3.150399378308914
# EPISODE: 43 - FINAL SCORE: 46 - Temperature/epsilo: 3.1151059552221345
# EPISODE: 44 - FINAL SCORE: 22 - Temperature/epsilo: 3.08020791873991
# EPISODE: 45 - FINAL SCORE: 45 - Temperature/epsilo: 3.0457008394090055
# EPISODE: 46 - FINAL SCORE: 12 - Temperature/epsilo: 3.011580337398647
# EPISODE: 47 - FINAL SCORE: 27 - Temperature/epsilo: 2.9778420819446065
# EPISODE: 48 - FINAL SCORE: 19 - Temperature/epsilo: 2.9444817907995198
# EPISODE: 49 - FINAL SCORE: 25 - Temperature/epsilo: 2.911495229689357
# EPISODE: 50 - FINAL SCORE: 15 - Temperature/epsilo: 2.878878211775988
# EPISODE: 51 - FINAL SCORE: 16 - Temperature/epsilo: 2.8466265971257654
# EPISODE: 52 - FINAL SCORE: 18 - Temperature/epsilo: 2.8147362921840573
# EPISODE: 53 - FINAL SCORE: 75 - Temperature/epsilo: 2.7832032492556746
# EPISODE: 54 - FINAL SCORE: 17 - Temperature/epsilo: 2.7520234659911136
# EPISODE: 55 - FINAL SCORE: 29 - Temperature/epsilo: 2.721192984878555
# EPISODE: 56 - FINAL SCORE: 35 - Temperature/epsilo: 2.6907078927415546
# EPISODE: 57 - FINAL SCORE: 12 - Temperature/epsilo: 2.6605643202423623
# EPISODE: 58 - FINAL SCORE: 9 - Temperature/epsilo: 2.630758441390803
# EPISODE: 59 - FINAL SCORE: 21 - Temperature/epsilo: 2.60128647305866
# EPISODE: 60 - FINAL SCORE: 11 - Temperature/epsilo: 2.572144674499502
# EPISODE: 61 - FINAL SCORE: 15 - Temperature/epsilo: 2.5433293468738825
# EPISODE: 62 - FINAL SCORE: 17 - Temperature/epsilo: 2.514836832779868
# EPISODE: 63 - FINAL SCORE: 22 - Temperature/epsilo: 2.486663515788814
# EPISODE: 64 - FINAL SCORE: 33 - Temperature/epsilo: 2.4588058199863525
# EPISODE: 65 - FINAL SCORE: 27 - Temperature/epsilo: 2.431260209518515
# EPISODE: 66 - FINAL SCORE: 19 - Temperature/epsilo: 2.404023188142943
# EPISODE: 67 - FINAL SCORE: 16 - Temperature/epsilo: 2.377091298785124
# EPISODE: 68 - FINAL SCORE: 20 - Temperature/epsilo: 2.3504611230996018
# EPISODE: 69 - FINAL SCORE: 9 - Temperature/epsilo: 2.324129281036101
# EPISODE: 70 - FINAL SCORE: 42 - Temperature/epsilo: 2.2980924304105117
# EPISODE: 71 - FINAL SCORE: 70 - Temperature/epsilo: 2.2723472664806796
# EPISODE: 72 - FINAL SCORE: 37 - Temperature/epsilo: 2.246890521526953
# EPISODE: 73 - FINAL SCORE: 16 - Temperature/epsilo: 2.221718964437422
# EPISODE: 74 - FINAL SCORE: 19 - Temperature/epsilo: 2.1968294002978106
# EPISODE: 75 - FINAL SCORE: 13 - Temperature/epsilo: 2.1722186699859587
# EPISODE: 76 - FINAL SCORE: 28 - Temperature/epsilo: 2.147883649770849
# EPISODE: 77 - FINAL SCORE: 61 - Temperature/epsilo: 2.1238212509161265
# EPISODE: 78 - FINAL SCORE: 33 - Temperature/epsilo: 2.1000284192880576
# EPISODE: 79 - FINAL SCORE: 13 - Temperature/epsilo: 2.076502134967884
# EPISODE: 80 - FINAL SCORE: 37 - Temperature/epsilo: 2.0532394118685158
# EPISODE: 81 - FINAL SCORE: 17 - Temperature/epsilo: 2.030237297355522
# EPISODE: 82 - FINAL SCORE: 20 - Temperature/epsilo: 2.007492871872366
# EPISODE: 83 - FINAL SCORE: 29 - Temperature/epsilo: 1.985003248569838
# EPISODE: 84 - FINAL SCORE: 30 - Temperature/epsilo: 1.9627655729396416
# EPISODE: 85 - FINAL SCORE: 10 - Temperature/epsilo: 1.9407770224520813
# EPISODE: 86 - FINAL SCORE: 11 - Temperature/epsilo: 1.9190348061978137
# EPISODE: 87 - FINAL SCORE: 12 - Temperature/epsilo: 1.8975361645336095
# EPISODE: 88 - FINAL SCORE: 14 - Temperature/epsilo: 1.8762783687320823
# EPISODE: 89 - FINAL SCORE: 14 - Temperature/epsilo: 1.8552587206353446
# EPISODE: 90 - FINAL SCORE: 15 - Temperature/epsilo: 1.8344745523125436
# EPISODE: 91 - FINAL SCORE: 35 - Temperature/epsilo: 1.81392322572123
# EPISODE: 92 - FINAL SCORE: 23 - Temperature/epsilo: 1.793602132372526
# EPISODE: 93 - FINAL SCORE: 30 - Temperature/epsilo: 1.7735086930000383
# EPISODE: 94 - FINAL SCORE: 14 - Temperature/epsilo: 1.7536403572324852
# EPISODE: 95 - FINAL SCORE: 17 - Temperature/epsilo: 1.733994603269989
# EPISODE: 96 - FINAL SCORE: 31 - Temperature/epsilo: 1.7145689375639952
# EPISODE: 97 - FINAL SCORE: 26 - Temperature/epsilo: 1.695360894500776
# EPISODE: 98 - FINAL SCORE: 19 - Temperature/epsilo: 1.676368036088483
# EPISODE: 99 - FINAL SCORE: 11 - Temperature/epsilo: 1.6575879516477023
# EPISODE: 100 - FINAL SCORE: 20 - Temperature/epsilo: 1.639018257505478
# EPISODE: 101 - FINAL SCORE: 39 - Temperature/epsilo: 1.6206565966927626
# EPISODE: 102 - FINAL SCORE: 26 - Temperature/epsilo: 1.6025006386452592
# EPISODE: 103 - FINAL SCORE: 13 - Temperature/epsilo: 1.5845480789076107
# EPISODE: 104 - FINAL SCORE: 28 - Temperature/epsilo: 1.5667966388409074
# EPISODE: 105 - FINAL SCORE: 39 - Temperature/epsilo: 1.5492440653334687
# EPISODE: 106 - FINAL SCORE: 25 - Temperature/epsilo: 1.531888130514866
# EPISODE: 107 - FINAL SCORE: 80 - Temperature/epsilo: 1.514726631473148
# EPISODE: 108 - FINAL SCORE: 30 - Temperature/epsilo: 1.4977573899752366
# EPISODE: 109 - FINAL SCORE: 34 - Temperature/epsilo: 1.4809782521904515
# EPISODE: 110 - FINAL SCORE: 23 - Temperature/epsilo: 1.4643870884171353
# EPISODE: 111 - FINAL SCORE: 33 - Temperature/epsilo: 1.4479817928123393
# EPISODE: 112 - FINAL SCORE: 47 - Temperature/epsilo: 1.4317602831245386
# EPISODE: 113 - FINAL SCORE: 20 - Temperature/epsilo: 1.4157205004293407
# EPISODE: 114 - FINAL SCORE: 14 - Temperature/epsilo: 1.3998604088681554
# EPISODE: 115 - FINAL SCORE: 27 - Temperature/epsilo: 1.384177995389793
# EPISODE: 116 - FINAL SCORE: 36 - Temperature/epsilo: 1.368671269494956
# EPISODE: 117 - FINAL SCORE: 17 - Temperature/epsilo: 1.3533382629835926
# EPISODE: 118 - FINAL SCORE: 19 - Temperature/epsilo: 1.338177029705085
# EPISODE: 119 - FINAL SCORE: 25 - Temperature/epsilo: 1.3231856453112298
# EPISODE: 120 - FINAL SCORE: 13 - Temperature/epsilo: 1.3083622070119907
# EPISODE: 121 - FINAL SCORE: 20 - Temperature/epsilo: 1.2937048333339862
# EPISODE: 122 - FINAL SCORE: 11 - Temperature/epsilo: 1.279211663881681
# EPISODE: 123 - FINAL SCORE: 17 - Temperature/epsilo: 1.2648808591012557
# EPISODE: 124 - FINAL SCORE: 9 - Temperature/epsilo: 1.2507106000471184
# EPISODE: 125 - FINAL SCORE: 22 - Temperature/epsilo: 1.236699088151037
# EPISODE: 126 - FINAL SCORE: 39 - Temperature/epsilo: 1.2228445449938523
# EPISODE: 127 - FINAL SCORE: 27 - Temperature/epsilo: 1.209145212079752
# EPISODE: 128 - FINAL SCORE: 21 - Temperature/epsilo: 1.1955993506130729
# EPISODE: 129 - FINAL SCORE: 32 - Temperature/epsilo: 1.182205241277603
# EPISODE: 130 - FINAL SCORE: 12 - Temperature/epsilo: 1.168961184018356
# EPISODE: 131 - FINAL SCORE: 23 - Temperature/epsilo: 1.155865497825792
# EPISODE: 132 - FINAL SCORE: 22 - Temperature/epsilo: 1.1429165205224525
# EPISODE: 133 - FINAL SCORE: 16 - Temperature/epsilo: 1.1301126085519895
# EPISODE: 134 - FINAL SCORE: 15 - Temperature/epsilo: 1.117452136770555
# EPISODE: 135 - FINAL SCORE: 13 - Temperature/epsilo: 1.1049334982405286
# EPISODE: 136 - FINAL SCORE: 11 - Temperature/epsilo: 1.092555104026557
# EPISODE: 137 - FINAL SCORE: 14 - Temperature/epsilo: 1.080315382993877
# EPISODE: 138 - FINAL SCORE: 10 - Temperature/epsilo: 1.0682127816088978
# EPISODE: 139 - FINAL SCORE: 9 - Temperature/epsilo: 1.0562457637420184
# EPISODE: 140 - FINAL SCORE: 11 - Temperature/epsilo: 1.0444128104726536
# EPISODE: 141 - FINAL SCORE: 21 - Temperature/epsilo: 1.0327124198964435
# EPISODE: 142 - FINAL SCORE: 37 - Temperature/epsilo: 1.021143106934624
# EPISODE: 143 - FINAL SCORE: 27 - Temperature/epsilo: 1.0097034031455323
# EPISODE: 144 - FINAL SCORE: 51 - Temperature/epsilo: 0.9983918565382242
# EPISODE: 145 - FINAL SCORE: 33 - Temperature/epsilo: 0.9872070313881781
# EPISODE: 146 - FINAL SCORE: 56 - Temperature/epsilo: 0.9761475080550669
# EPISODE: 147 - FINAL SCORE: 15 - Temperature/epsilo: 0.9652118828025675
# EPISODE: 148 - FINAL SCORE: 33 - Temperature/epsilo: 0.9543987676201922
# EPISODE: 149 - FINAL SCORE: 18 - Temperature/epsilo: 0.9437067900471134
# EPISODE: 150 - FINAL SCORE: 42 - Temperature/epsilo: 0.933134592997964
# EPISODE: 151 - FINAL SCORE: 35 - Temperature/epsilo: 0.9226808345905886
# EPISODE: 152 - FINAL SCORE: 33 - Temperature/epsilo: 0.9123441879757241
# EPISODE: 153 - FINAL SCORE: 43 - Temperature/epsilo: 0.9021233411685882
# EPISODE: 154 - FINAL SCORE: 23 - Temperature/epsilo: 0.8920169968823559
# EPISODE: 155 - FINAL SCORE: 17 - Temperature/epsilo: 0.8820238723634999
# EPISODE: 156 - FINAL SCORE: 11 - Temperature/epsilo: 0.8721426992289766
# EPISODE: 157 - FINAL SCORE: 18 - Temperature/epsilo: 0.8623722233052361
# EPISODE: 158 - FINAL SCORE: 36 - Temperature/epsilo: 0.8527112044690353
# EPISODE: 159 - FINAL SCORE: 22 - Temperature/epsilo: 0.8431584164900336
# EPISODE: 160 - FINAL SCORE: 18 - Temperature/epsilo: 0.8337126468751554
# EPISODE: 161 - FINAL SCORE: 45 - Temperature/epsilo: 0.8243726967146908
# EPISODE: 162 - FINAL SCORE: 40 - Temperature/epsilo: 0.8151373805301255
# EPISODE: 163 - FINAL SCORE: 15 - Temperature/epsilo: 0.8060055261236719
# EPISODE: 164 - FINAL SCORE: 15 - Temperature/epsilo: 0.796975974429488
# EPISODE: 165 - FINAL SCORE: 16 - Temperature/epsilo: 0.7880475793665621
# EPISODE: 166 - FINAL SCORE: 17 - Temperature/epsilo: 0.7792192076932456
# EPISODE: 167 - FINAL SCORE: 20 - Temperature/epsilo: 0.7704897388634158
# EPISODE: 168 - FINAL SCORE: 65 - Temperature/epsilo: 0.76185806488425
# EPISODE: 169 - FINAL SCORE: 14 - Temperature/epsilo: 0.7533230901755932
# EPISODE: 170 - FINAL SCORE: 18 - Temperature/epsilo: 0.7448837314308999
# EPISODE: 171 - FINAL SCORE: 12 - Temperature/epsilo: 0.7365389174797361
# EPISODE: 172 - FINAL SCORE: 36 - Temperature/epsilo: 0.7282875891518197
# EPISODE: 173 - FINAL SCORE: 31 - Temperature/epsilo: 0.7201286991425844
# EPISODE: 174 - FINAL SCORE: 19 - Temperature/epsilo: 0.7120612118802505
# EPISODE: 175 - FINAL SCORE: 17 - Temperature/epsilo: 0.7040841033943847
# EPISODE: 176 - FINAL SCORE: 21 - Temperature/epsilo: 0.696196361185931
# EPISODE: 177 - FINAL SCORE: 51 - Temperature/epsilo: 0.6883969840986992
# EPISODE: 178 - FINAL SCORE: 10 - Temperature/epsilo: 0.6806849821922932
# EPISODE: 179 - FINAL SCORE: 24 - Temperature/epsilo: 0.6730593766164614
# EPISODE: 180 - FINAL SCORE: 19 - Temperature/epsilo: 0.6655191994868558
# EPISODE: 181 - FINAL SCORE: 14 - Temperature/epsilo: 0.6580634937621826
# EPISODE: 182 - FINAL SCORE: 11 - Temperature/epsilo: 0.6506913131227299
# EPISODE: 183 - FINAL SCORE: 15 - Temperature/epsilo: 0.6434017218502543
# EPISODE: 184 - FINAL SCORE: 33 - Temperature/epsilo: 0.636193794709216
# EPISODE: 185 - FINAL SCORE: 11 - Temperature/epsilo: 0.6290666168293407
# EPISODE: 186 - FINAL SCORE: 15 - Temperature/epsilo: 0.622019283589501
# EPISODE: 187 - FINAL SCORE: 17 - Temperature/epsilo: 0.6150509005028957
# EPISODE: 188 - FINAL SCORE: 16 - Temperature/epsilo: 0.6081605831035171
# EPISODE: 189 - FINAL SCORE: 10 - Temperature/epsilo: 0.6013474568338893
# EPISODE: 190 - FINAL SCORE: 9 - Temperature/epsilo: 0.5946106569340653
# EPISODE: 191 - FINAL SCORE: 12 - Temperature/epsilo: 0.5879493283318654
# EPISODE: 192 - FINAL SCORE: 10 - Temperature/epsilo: 0.581362625534348
# EPISODE: 193 - FINAL SCORE: 26 - Temperature/epsilo: 0.5748497125204943
# EPISODE: 194 - FINAL SCORE: 9 - Temperature/epsilo: 0.568409762635096
# EPISODE: 195 - FINAL SCORE: 23 - Temperature/epsilo: 0.5620419584838316
# EPISODE: 196 - FINAL SCORE: 30 - Temperature/epsilo: 0.5557454918295182
# EPISODE: 197 - FINAL SCORE: 17 - Temperature/epsilo: 0.5495195634895252
# EPISODE: 198 - FINAL SCORE: 11 - Temperature/epsilo: 0.5433633832343383
# EPISODE: 199 - FINAL SCORE: 68 - Temperature/epsilo: 0.5372761696872587
# EPISODE: 200 - FINAL SCORE: 11 - Temperature/epsilo: 0.531257150225226
# EPISODE: 201 - FINAL SCORE: 14 - Temperature/epsilo: 0.5253055608807538
# EPISODE: 202 - FINAL SCORE: 15 - Temperature/epsilo: 0.519420646244961
# EPISODE: 203 - FINAL SCORE: 17 - Temperature/epsilo: 0.5136016593716928
# EPISODE: 204 - FINAL SCORE: 13 - Temperature/epsilo: 0.507847861682713
# EPISODE: 205 - FINAL SCORE: 22 - Temperature/epsilo: 0.50215852287396
# EPISODE: 206 - FINAL SCORE: 36 - Temperature/epsilo: 0.4965329208228523
# EPISODE: 207 - FINAL SCORE: 13 - Temperature/epsilo: 0.490970341496633
# EPISODE: 208 - FINAL SCORE: 33 - Temperature/epsilo: 0.4854700788617405
# EPISODE: 209 - FINAL SCORE: 9 - Temperature/epsilo: 0.4800314347941947
# EPISODE: 210 - FINAL SCORE: 16 - Temperature/epsilo: 0.4746537189909877
# EPISODE: 211 - FINAL SCORE: 10 - Temperature/epsilo: 0.4693362488824662
# EPISODE: 212 - FINAL SCORE: 11 - Temperature/epsilo: 0.46407834954569627
# EPISODE: 213 - FINAL SCORE: 12 - Temperature/epsilo: 0.45887935361879806
# EPISODE: 214 - FINAL SCORE: 16 - Temperature/epsilo: 0.4537386012162409
# EPISODE: 215 - FINAL SCORE: 15 - Temperature/epsilo: 0.4486554398450866
# EPISODE: 216 - FINAL SCORE: 16 - Temperature/epsilo: 0.4436292243221717
# EPISODE: 217 - FINAL SCORE: 15 - Temperature/epsilo: 0.4386593166922169
# EPISODE: 218 - FINAL SCORE: 17 - Temperature/epsilo: 0.4337450861468546
# EPISODE: 219 - FINAL SCORE: 28 - Temperature/epsilo: 0.42888590894456297
# EPISODE: 220 - FINAL SCORE: 17 - Temperature/epsilo: 0.42408116833149706
# EPISODE: 221 - FINAL SCORE: 18 - Temperature/epsilo: 0.41933025446320726
# EPISODE: 222 - FINAL SCORE: 16 - Temperature/epsilo: 0.4146325643272344
# EPISODE: 223 - FINAL SCORE: 25 - Temperature/epsilo: 0.4099875016665717
# EPISODE: 224 - FINAL SCORE: 23 - Temperature/epsilo: 0.4053944769039852
# EPISODE: 225 - FINAL SCORE: 21 - Temperature/epsilo: 0.4008529070671806
# EPISODE: 226 - FINAL SCORE: 14 - Temperature/epsilo: 0.39636221571480934
# EPISODE: 227 - FINAL SCORE: 11 - Temperature/epsilo: 0.39192183286330395
# EPISODE: 228 - FINAL SCORE: 30 - Temperature/epsilo: 0.38753119491453203
# EPISODE: 229 - FINAL SCORE: 23 - Temperature/epsilo: 0.3831897445842613
# EPISODE: 230 - FINAL SCORE: 14 - Temperature/epsilo: 0.37889693083142634
# EPISODE: 231 - FINAL SCORE: 12 - Temperature/epsilo: 0.37465220878818684
# EPISODE: 232 - FINAL SCORE: 15 - Temperature/epsilo: 0.3704550396907705
# EPISODE: 233 - FINAL SCORE: 19 - Temperature/epsilo: 0.36630489081108963
# EPISODE: 234 - FINAL SCORE: 10 - Temperature/epsilo: 0.36220123538912463
# EPISODE: 235 - FINAL SCORE: 32 - Temperature/epsilo: 0.3581435525660648
# EPISODE: 236 - FINAL SCORE: 13 - Temperature/epsilo: 0.3541313273181975
# EPISODE: 237 - FINAL SCORE: 9 - Temperature/epsilo: 0.3501640503915391
# EPISODE: 238 - FINAL SCORE: 12 - Temperature/epsilo: 0.34624121823719717
# EPISODE: 239 - FINAL SCORE: 43 - Temperature/epsilo: 0.34236233294745755
# EPISODE: 240 - FINAL SCORE: 16 - Temperature/epsilo: 0.33852690219258685
# EPISODE: 241 - FINAL SCORE: 14 - Temperature/epsilo: 0.3347344391583435
# EPISODE: 242 - FINAL SCORE: 31 - Temperature/epsilo: 0.3309844624841884
# EPISODE: 243 - FINAL SCORE: 23 - Temperature/epsilo: 0.32727649620218785
# EPISODE: 244 - FINAL SCORE: 13 - Temperature/epsilo: 0.3236100696766015
# EPISODE: 245 - FINAL SCORE: 24 - Temperature/epsilo: 0.3199847175441461
# EPISODE: 246 - FINAL SCORE: 20 - Temperature/epsilo: 0.31639997965492916
# EPISODE: 247 - FINAL SCORE: 19 - Temperature/epsilo: 0.31285540101404463
# EPISODE: 248 - FINAL SCORE: 38 - Temperature/epsilo: 0.30935053172382154
# EPISODE: 249 - FINAL SCORE: 16 - Temperature/epsilo: 0.3058849269267213
# EPISODE: 250 - FINAL SCORE: 13 - Temperature/epsilo: 0.3024581467488734
# EPISODE: 251 - FINAL SCORE: 11 - Temperature/epsilo: 0.29906975624424426
# EPISODE: 252 - FINAL SCORE: 21 - Temperature/epsilo: 0.29571932533943185
# EPISODE: 253 - FINAL SCORE: 9 - Temperature/epsilo: 0.29240642877907763
# EPISODE: 254 - FINAL SCORE: 13 - Temperature/epsilo: 0.28913064607189154
# EPISODE: 255 - FINAL SCORE: 29 - Temperature/epsilo: 0.2858915614372803
# EPISODE: 256 - FINAL SCORE: 9 - Temperature/epsilo: 0.2826887637525746
# EPISODE: 257 - FINAL SCORE: 21 - Temperature/epsilo: 0.27952184650084705
# EPISODE: 258 - FINAL SCORE: 13 - Temperature/epsilo: 0.2763904077193146
# EPISODE: 259 - FINAL SCORE: 42 - Temperature/epsilo: 0.2732940499483194
# EPISODE: 260 - FINAL SCORE: 9 - Temperature/epsilo: 0.2702323801808809
# EPISODE: 261 - FINAL SCORE: 15 - Temperature/epsilo: 0.2672050098128132
# EPISODE: 262 - FINAL SCORE: 14 - Temperature/epsilo: 0.2642115545934014
# EPISODE: 263 - FINAL SCORE: 17 - Temperature/epsilo: 0.26125163457663
# EPISODE: 264 - FINAL SCORE: 17 - Temperature/epsilo: 0.2583248740729585
# EPISODE: 265 - FINAL SCORE: 13 - Temperature/epsilo: 0.25543090160163645
# EPISODE: 266 - FINAL SCORE: 30 - Temperature/epsilo: 0.2525693498435533
# EPISODE: 267 - FINAL SCORE: 18 - Temperature/epsilo: 0.24973985559461578
# EPISODE: 268 - FINAL SCORE: 24 - Temperature/epsilo: 0.24694205971964855
# EPISODE: 269 - FINAL SCORE: 10 - Temperature/epsilo: 0.2441756071068104
# EPISODE: 270 - FINAL SCORE: 43 - Temperature/epsilo: 0.24144014662252164
# EPISODE: 271 - FINAL SCORE: 13 - Temperature/epsilo: 0.23873533106689618
# EPISODE: 272 - FINAL SCORE: 49 - Temperature/epsilo: 0.23606081712967303
# EPISODE: 273 - FINAL SCORE: 11 - Temperature/epsilo: 0.23341626534664145
# EPISODE: 274 - FINAL SCORE: 27 - Temperature/epsilo: 0.23080134005655423
# EPISODE: 275 - FINAL SCORE: 15 - Temperature/epsilo: 0.22821570935852378
# EPISODE: 276 - FINAL SCORE: 13 - Temperature/epsilo: 0.22565904506989526
# EPISODE: 277 - FINAL SCORE: 12 - Temperature/epsilo: 0.22313102268459198
# EPISODE: 278 - FINAL SCORE: 11 - Temperature/epsilo: 0.22063132133192717
# EPISODE: 279 - FINAL SCORE: 49 - Temperature/epsilo: 0.21815962373587738
# EPISODE: 280 - FINAL SCORE: 18 - Temperature/epsilo: 0.2157156161748119
# EPISODE: 281 - FINAL SCORE: 14 - Temperature/epsilo: 0.2132989884416736
# EPISODE: 282 - FINAL SCORE: 13 - Temperature/epsilo: 0.21090943380460564
# EPISODE: 283 - FINAL SCORE: 30 - Temperature/epsilo: 0.2085466489680194
# EPISODE: 284 - FINAL SCORE: 43 - Temperature/epsilo: 0.20621033403409844
# EPISODE: 285 - FINAL SCORE: 31 - Temperature/epsilo: 0.20390019246473393
# EPISODE: 286 - FINAL SCORE: 37 - Temperature/epsilo: 0.2016159310438862
# EPISODE: 287 - FINAL SCORE: 27 - Temperature/epsilo: 0.1993572598403684
# EPISODE: 288 - FINAL SCORE: 13 - Temperature/epsilo: 0.1971238921710464
# EPISODE: 289 - FINAL SCORE: 11 - Temperature/epsilo: 0.19491554456445184
# EPISODE: 290 - FINAL SCORE: 18 - Temperature/epsilo: 0.19273193672480204
# EPISODE: 291 - FINAL SCORE: 50 - Temperature/epsilo: 0.19057279149642337
# EPISODE: 292 - FINAL SCORE: 13 - Temperature/epsilo: 0.18843783482857313
# EPISODE: 293 - FINAL SCORE: 19 - Temperature/epsilo: 0.18632679574065547
# EPISODE: 294 - FINAL SCORE: 51 - Temperature/epsilo: 0.18423940628782717
# EPISODE: 295 - FINAL SCORE: 12 - Temperature/epsilo: 0.18217540152698833
# EPISODE: 296 - FINAL SCORE: 12 - Temperature/epsilo: 0.1801345194831545
# EPISODE: 297 - FINAL SCORE: 16 - Temperature/epsilo: 0.1781165011162053
# EPISODE: 298 - FINAL SCORE: 29 - Temperature/epsilo: 0.17612109028800563
# EPISODE: 299 - FINAL SCORE: 42 - Temperature/epsilo: 0.1741480337298952
# EPISODE: 300 - FINAL SCORE: 25 - Temperature/epsilo: 0.17219708101054215
# EPISODE: 301 - FINAL SCORE: 13 - Temperature/epsilo: 0.17026798450415703
# EPISODE: 302 - FINAL SCORE: 19 - Temperature/epsilo: 0.16836049935906278
# EPISODE: 303 - FINAL SCORE: 11 - Temperature/epsilo: 0.16647438346661664
# EPISODE: 304 - FINAL SCORE: 21 - Temperature/epsilo: 0.1646093974304805
# EPISODE: 305 - FINAL SCORE: 15 - Temperature/epsilo: 0.1627653045362354
# EPISODE: 306 - FINAL SCORE: 14 - Temperature/epsilo: 0.16094187072133617
# EPISODE: 307 - FINAL SCORE: 13 - Temperature/epsilo: 0.15913886454540335
# EPISODE: 308 - FINAL SCORE: 22 - Temperature/epsilo: 0.15735605716084708
# EPISODE: 309 - FINAL SCORE: 25 - Temperature/epsilo: 0.1555932222838207
# EPISODE: 310 - FINAL SCORE: 27 - Temperature/epsilo: 0.15385013616549942
# EPISODE: 311 - FINAL SCORE: 14 - Temperature/epsilo: 0.15212657756368103
# EPISODE: 312 - FINAL SCORE: 13 - Temperature/epsilo: 0.15042232771470448
# EPISODE: 313 - FINAL SCORE: 23 - Temperature/epsilo: 0.14873717030568323
# EPISODE: 314 - FINAL SCORE: 19 - Temperature/epsilo: 0.14707089144704955
# EPISODE: 315 - FINAL SCORE: 15 - Temperature/epsilo: 0.14542327964540652
# EPISODE: 316 - FINAL SCORE: 19 - Temperature/epsilo: 0.1437941257766842
# EPISODE: 317 - FINAL SCORE: 20 - Temperature/epsilo: 0.14218322305959621
# EPISODE: 318 - FINAL SCORE: 12 - Temperature/epsilo: 0.14059036702939415
# EPISODE: 319 - FINAL SCORE: 15 - Temperature/epsilo: 0.13901535551191552
# EPISODE: 320 - FINAL SCORE: 18 - Temperature/epsilo: 0.13745798859792294
# EPISODE: 321 - FINAL SCORE: 12 - Temperature/epsilo: 0.13591806861773034
# EPISODE: 322 - FINAL SCORE: 13 - Temperature/epsilo: 0.13439540011611376
# EPISODE: 323 - FINAL SCORE: 21 - Temperature/epsilo: 0.13288978982750294
# EPISODE: 324 - FINAL SCORE: 10 - Temperature/epsilo: 0.13140104665145114
# EPISODE: 325 - FINAL SCORE: 16 - Temperature/epsilo: 0.12992898162837943
# EPISODE: 326 - FINAL SCORE: 17 - Temperature/epsilo: 0.1284734079155931
# EPISODE: 327 - FINAL SCORE: 15 - Temperature/epsilo: 0.1270341407635664
# EPISODE: 328 - FINAL SCORE: 63 - Temperature/epsilo: 0.12561099749249302
# EPISODE: 329 - FINAL SCORE: 40 - Temperature/epsilo: 0.1242037974690996
# EPISODE: 330 - FINAL SCORE: 10 - Temperature/epsilo: 0.1228123620837185
# EPISODE: 331 - FINAL SCORE: 13 - Temperature/epsilo: 0.12143651472761786
# EPISODE: 332 - FINAL SCORE: 27 - Temperature/epsilo: 0.12007608077058529
# EPISODE: 333 - FINAL SCORE: 9 - Temperature/epsilo: 0.11873088753876292
# EPISODE: 334 - FINAL SCORE: 14 - Temperature/epsilo: 0.11740076429273061
# EPISODE: 335 - FINAL SCORE: 14 - Temperature/epsilo: 0.11608554220583482
# EPISODE: 336 - FINAL SCORE: 26 - Temperature/epsilo: 0.11478505434276016
# EPISODE: 337 - FINAL SCORE: 24 - Temperature/epsilo: 0.11349913563834096
# EPISODE: 338 - FINAL SCORE: 17 - Temperature/epsilo: 0.11222762287661044
# EPISODE: 339 - FINAL SCORE: 38 - Temperature/epsilo: 0.11097035467008422
# EPISODE: 340 - FINAL SCORE: 11 - Temperature/epsilo: 0.10972717143927632
# EPISODE: 341 - FINAL SCORE: 29 - Temperature/epsilo: 0.10849791539244433
# EPISODE: 342 - FINAL SCORE: 12 - Temperature/epsilo: 0.10728243050556162
# EPISODE: 343 - FINAL SCORE: 13 - Temperature/epsilo: 0.10608056250251394
# EPISODE: 344 - FINAL SCORE: 12 - Temperature/epsilo: 0.10489215883551777
# EPISODE: 345 - FINAL SCORE: 69 - Temperature/epsilo: 0.10371706866575814
# EPISODE: 346 - FINAL SCORE: 23 - Temperature/epsilo: 0.10255514284424339
# EPISODE: 347 - FINAL SCORE: 14 - Temperature/epsilo: 0.10140623389287422
# EPISODE: 348 - FINAL SCORE: 11 - Temperature/epsilo: 0.10027019598572504
# EPISODE: 349 - FINAL SCORE: 14 - Temperature/epsilo: 0.09914688493053492
# EPISODE: 350 - FINAL SCORE: 25 - Temperature/epsilo: 0.09803615815040587
# EPISODE: 351 - FINAL SCORE: 18 - Temperature/epsilo: 0.09693787466570623
# EPISODE: 352 - FINAL SCORE: 10 - Temperature/epsilo: 0.0958518950761767
# EPISODE: 353 - FINAL SCORE: 10 - Temperature/epsilo: 0.09477808154323696
# EPISODE: 354 - FINAL SCORE: 19 - Temperature/epsilo: 0.09371629777249028
# EPISODE: 355 - FINAL SCORE: 12 - Temperature/epsilo: 0.09266640899642452
# EPISODE: 356 - FINAL SCORE: 29 - Temperature/epsilo: 0.0916282819573064
# EPISODE: 357 - FINAL SCORE: 12 - Temperature/epsilo: 0.09060178489026793
# EPISODE: 358 - FINAL SCORE: 10 - Temperature/epsilo: 0.08958678750658192
# EPISODE: 359 - FINAL SCORE: 12 - Temperature/epsilo: 0.08858316097712507
# EPISODE: 360 - FINAL SCORE: 26 - Temperature/epsilo: 0.08759077791602626
# EPISODE: 361 - FINAL SCORE: 10 - Temperature/epsilo: 0.08660951236449803
# EPISODE: 362 - FINAL SCORE: 39 - Temperature/epsilo: 0.08563923977484919
# EPISODE: 363 - FINAL SCORE: 53 - Temperature/epsilo: 0.08467983699467649
# EPISODE: 364 - FINAL SCORE: 31 - Temperature/epsilo: 0.0837311822512335
# EPISODE: 365 - FINAL SCORE: 53 - Temperature/epsilo: 0.08279315513597443
# EPISODE: 366 - FINAL SCORE: 12 - Temperature/epsilo: 0.08186563658927137
# EPISODE: 367 - FINAL SCORE: 22 - Temperature/epsilo: 0.08094850888530242
# EPISODE: 368 - FINAL SCORE: 73 - Temperature/epsilo: 0.08004165561710933
# EPISODE: 369 - FINAL SCORE: 29 - Temperature/epsilo: 0.07914496168182251
# EPISODE: 370 - FINAL SCORE: 24 - Temperature/epsilo: 0.07825831326605152
# EPISODE: 371 - FINAL SCORE: 31 - Temperature/epsilo: 0.0773815978314392
# EPISODE: 372 - FINAL SCORE: 43 - Temperature/epsilo: 0.07651470410037771
# EPISODE: 373 - FINAL SCORE: 25 - Temperature/epsilo: 0.07565752204188456
# EPISODE: 374 - FINAL SCORE: 25 - Temperature/epsilo: 0.07480994285763684
# EPISODE: 375 - FINAL SCORE: 36 - Temperature/epsilo: 0.07397185896816197
# EPISODE: 376 - FINAL SCORE: 12 - Temperature/epsilo: 0.07314316399918304
# EPISODE: 377 - FINAL SCORE: 28 - Temperature/epsilo: 0.0723237527681173
# EPISODE: 378 - FINAL SCORE: 33 - Temperature/epsilo: 0.07151352127072569
# EPISODE: 379 - FINAL SCORE: 11 - Temperature/epsilo: 0.07071236666791214
# EPISODE: 380 - FINAL SCORE: 51 - Temperature/epsilo: 0.06992018727267059
# EPISODE: 381 - FINAL SCORE: 11 - Temperature/epsilo: 0.06913688253717834
# EPISODE: 382 - FINAL SCORE: 26 - Temperature/epsilo: 0.06836235304003395
# EPISODE: 383 - FINAL SCORE: 46 - Temperature/epsilo: 0.06759650047363812
# EPISODE: 384 - FINAL SCORE: 11 - Temperature/epsilo: 0.06683922763171596
# EPISODE: 385 - FINAL SCORE: 45 - Temperature/epsilo: 0.066090438396979
# EPISODE: 386 - FINAL SCORE: 46 - Temperature/epsilo: 0.06535003772892548
# EPISODE: 387 - FINAL SCORE: 12 - Temperature/epsilo: 0.06461793165177725
# EPISODE: 388 - FINAL SCORE: 14 - Temperature/epsilo: 0.06389402724255185
# EPISODE: 389 - FINAL SCORE: 45 - Temperature/epsilo: 0.06317823261926822
# EPISODE: 390 - FINAL SCORE: 15 - Temperature/epsilo: 0.06247045692928452
# EPISODE: 391 - FINAL SCORE: 19 - Temperature/epsilo: 0.061770610337766596
# EPISODE: 392 - FINAL SCORE: 10 - Temperature/epsilo: 0.06107860401628566
# EPISODE: 393 - FINAL SCORE: 36 - Temperature/epsilo: 0.060394350131543664
# EPISODE: 394 - FINAL SCORE: 10 - Temperature/epsilo: 0.059717761834225044
# EPISODE: 395 - FINAL SCORE: 96 - Temperature/epsilo: 0.05904875324797329
# EPISODE: 396 - FINAL SCORE: 38 - Temperature/epsilo: 0.05838723945849107
# EPISODE: 397 - FINAL SCORE: 14 - Temperature/epsilo: 0.05773313650276239
# EPISODE: 398 - FINAL SCORE: 12 - Temperature/epsilo: 0.05708636135839561
# EPISODE: 399 - FINAL SCORE: 45 - Temperature/epsilo: 0.05644683193308568
# EPISODE: 400 - FINAL SCORE: 10 - Temperature/epsilo: 0.05581446705419464
# EPISODE: 401 - FINAL SCORE: 47 - Temperature/epsilo: 0.05518918645844865
# EPISODE: 402 - FINAL SCORE: 24 - Temperature/epsilo: 0.05457091078175055
# EPISODE: 403 - FINAL SCORE: 35 - Temperature/epsilo: 0.053959561549106576
# EPISODE: 404 - FINAL SCORE: 23 - Temperature/epsilo: 0.0533550611646658
# EPISODE: 405 - FINAL SCORE: 80 - Temperature/epsilo: 0.05275733290187126
# EPISODE: 406 - FINAL SCORE: 36 - Temperature/epsilo: 0.05216630089372146
# EPISODE: 407 - FINAL SCORE: 71 - Temperature/epsilo: 0.0515818901231408
# EPISODE: 408 - FINAL SCORE: 39 - Temperature/epsilo: 0.05100402641345806
# EPISODE: 409 - FINAL SCORE: 33 - Temperature/epsilo: 0.050432636418991476
# EPISODE: 410 - FINAL SCORE: 51 - Temperature/epsilo: 0.049867647615739294
# EPISODE: 411 - FINAL SCORE: 91 - Temperature/epsilo: 0.04930898829217459
# EPISODE: 412 - FINAL SCORE: 13 - Temperature/epsilo: 0.04875658754014329
# EPISODE: 413 - FINAL SCORE: 33 - Temperature/epsilo: 0.048210375245864086
# EPISODE: 414 - FINAL SCORE: 17 - Temperature/epsilo: 0.04767028208102922
# EPISODE: 415 - FINAL SCORE: 33 - Temperature/epsilo: 0.047136239494004896
# EPISODE: 416 - FINAL SCORE: 13 - Temperature/epsilo: 0.046608179701130424
# EPISODE: 417 - FINAL SCORE: 43 - Temperature/epsilo: 0.04608603567811464
# EPISODE: 418 - FINAL SCORE: 45 - Temperature/epsilo: 0.04556974115152886
# EPISODE: 419 - FINAL SCORE: 58 - Temperature/epsilo: 0.045059230590395107
# EPISODE: 420 - FINAL SCORE: 95 - Temperature/epsilo: 0.04455443919786847
# EPISODE: 421 - FINAL SCORE: 57 - Temperature/epsilo: 0.04405530290301285
# EPISODE: 422 - FINAL SCORE: 65 - Temperature/epsilo: 0.04356175835266861
# EPISODE: 423 - FINAL SCORE: 312 - Temperature/epsilo: 0.04307374290341149
# EPISODE: 424 - FINAL SCORE: 97 - Temperature/epsilo: 0.04259119461360154
# EPISODE: 425 - FINAL SCORE: 202 - Temperature/epsilo: 0.042114052235521185
# EPISODE: 426 - FINAL SCORE: 233 - Temperature/epsilo: 0.04164225520760124
# EPISODE: 427 - FINAL SCORE: 41 - Temperature/epsilo: 0.04117574364673418
# EPISODE: 428 - FINAL SCORE: 199 - Temperature/epsilo: 0.04071445834067339
# EPISODE: 429 - FINAL SCORE: 165 - Temperature/epsilo: 0.04025834074051763
# EPISODE: 430 - FINAL SCORE: 500 - Temperature/epsilo: 0.039807332953279706
# EPISODE: 431 - FINAL SCORE: 380 - Temperature/epsilo: 0.03936137773453835
# EPISODE: 432 - FINAL SCORE: 368 - Temperature/epsilo: 0.03892041848117241
# EPISODE: 433 - FINAL SCORE: 401 - Temperature/epsilo: 0.03848439922417653
# EPISODE: 434 - FINAL SCORE: 355 - Temperature/epsilo: 0.038053264621557205
# EPISODE: 435 - FINAL SCORE: 247 - Temperature/epsilo: 0.03762695995130847
# EPISODE: 436 - FINAL SCORE: 353 - Temperature/epsilo: 0.0372054311044663
# EPISODE: 437 - FINAL SCORE: 233 - Temperature/epsilo: 0.03678862457824079
# EPISODE: 438 - FINAL SCORE: 276 - Temperature/epsilo: 0.03637648746922526
# EPISODE: 439 - FINAL SCORE: 282 - Temperature/epsilo: 0.0359689674666815
# EPISODE: 440 - FINAL SCORE: 158 - Temperature/epsilo: 0.03556601284590018
# EPISODE: 441 - FINAL SCORE: 189 - Temperature/epsilo: 0.035167572461635634
# EPISODE: 442 - FINAL SCORE: 173 - Temperature/epsilo: 0.03477359574161427
# EPISODE: 443 - FINAL SCORE: 143 - Temperature/epsilo: 0.03438403268011563
# EPISODE: 444 - FINAL SCORE: 155 - Temperature/epsilo: 0.033998833831625386
# EPISODE: 445 - FINAL SCORE: 119 - Temperature/epsilo: 0.033617950304559434
# EPISODE: 446 - FINAL SCORE: 160 - Temperature/epsilo: 0.03324133375505833
# EPISODE: 447 - FINAL SCORE: 98 - Temperature/epsilo: 0.032868936380851164
# EPISODE: 448 - FINAL SCORE: 113 - Temperature/epsilo: 0.03250071091518829
# EPISODE: 449 - FINAL SCORE: 87 - Temperature/epsilo: 0.032136610620841936
# EPISODE: 450 - FINAL SCORE: 123 - Temperature/epsilo: 0.031776589284174046
# EPISODE: 451 - FINAL SCORE: 134 - Temperature/epsilo: 0.03142060120927061
# EPISODE: 452 - FINAL SCORE: 103 - Temperature/epsilo: 0.031068601212141667
# EPISODE: 453 - FINAL SCORE: 95 - Temperature/epsilo: 0.030720544614986307
# EPISODE: 454 - FINAL SCORE: 138 - Temperature/epsilo: 0.030376387240521933
# EPISODE: 455 - FINAL SCORE: 120 - Temperature/epsilo: 0.030036085406376995
# EPISODE: 456 - FINAL SCORE: 143 - Temperature/epsilo: 0.029699595919546618
# EPISODE: 457 - FINAL SCORE: 79 - Temperature/epsilo: 0.029366876070910285
# EPISODE: 458 - FINAL SCORE: 109 - Temperature/epsilo: 0.029037883629810954
# EPISODE: 459 - FINAL SCORE: 92 - Temperature/epsilo: 0.02871257683869493
# EPISODE: 460 - FINAL SCORE: 76 - Temperature/epsilo: 0.028390914407811742
# EPISODE: 461 - FINAL SCORE: 127 - Temperature/epsilo: 0.02807285550997343
# EPISODE: 462 - FINAL SCORE: 104 - Temperature/epsilo: 0.027758359775372516
# EPISODE: 463 - FINAL SCORE: 97 - Temperature/epsilo: 0.027447387286458066
# EPISODE: 464 - FINAL SCORE: 113 - Temperature/epsilo: 0.02713989857286911
# EPISODE: 465 - FINAL SCORE: 99 - Temperature/epsilo: 0.02683585460642485
# EPISODE: 466 - FINAL SCORE: 84 - Temperature/epsilo: 0.02653521679617101
# EPISODE: 467 - FINAL SCORE: 71 - Temperature/epsilo: 0.026237946983481614
# EPISODE: 468 - FINAL SCORE: 104 - Temperature/epsilo: 0.02594400743721571
# EPISODE: 469 - FINAL SCORE: 81 - Temperature/epsilo: 0.02565336084892832
# EPISODE: 470 - FINAL SCORE: 109 - Temperature/epsilo: 0.02536597032813503
# EPISODE: 471 - FINAL SCORE: 91 - Temperature/epsilo: 0.025081799397629664
# EPISODE: 472 - FINAL SCORE: 122 - Temperature/epsilo: 0.024800811988854383
# EPISODE: 473 - FINAL SCORE: 89 - Temperature/epsilo: 0.024522972437321662
# EPISODE: 474 - FINAL SCORE: 138 - Temperature/epsilo: 0.024248245478087557
# EPISODE: 475 - FINAL SCORE: 98 - Temperature/epsilo: 0.023976596241275683
# EPISODE: 476 - FINAL SCORE: 90 - Temperature/epsilo: 0.02370799024765132
# EPISODE: 477 - FINAL SCORE: 172 - Temperature/epsilo: 0.02344239340424515
# EPISODE: 478 - FINAL SCORE: 93 - Temperature/epsilo: 0.023179772000025963
# EPISODE: 479 - FINAL SCORE: 110 - Temperature/epsilo: 0.02292009270162185
# EPISODE: 480 - FINAL SCORE: 118 - Temperature/epsilo: 0.02266332254908939
# EPISODE: 481 - FINAL SCORE: 90 - Temperature/epsilo: 0.02240942895173015
# EPISODE: 482 - FINAL SCORE: 154 - Temperature/epsilo: 0.02215837968395411
# EPISODE: 483 - FINAL SCORE: 127 - Temperature/epsilo: 0.021910142881189417
# EPISODE: 484 - FINAL SCORE: 107 - Temperature/epsilo: 0.021664687035837932
# EPISODE: 485 - FINAL SCORE: 104 - Temperature/epsilo: 0.021421980993276135
# EPISODE: 486 - FINAL SCORE: 102 - Temperature/epsilo: 0.021181993947900803
# EPISODE: 487 - FINAL SCORE: 120 - Temperature/epsilo: 0.020944695439218973
# EPISODE: 488 - FINAL SCORE: 94 - Temperature/epsilo: 0.02071005534798175
# EPISODE: 489 - FINAL SCORE: 104 - Temperature/epsilo: 0.020478043892361384
# EPISODE: 490 - FINAL SCORE: 173 - Temperature/epsilo: 0.020248631624171214
# EPISODE: 491 - FINAL SCORE: 109 - Temperature/epsilo: 0.02002178942512792
# EPISODE: 492 - FINAL SCORE: 162 - Temperature/epsilo: 0.019797488503155686
# EPISODE: 493 - FINAL SCORE: 138 - Temperature/epsilo: 0.019575700388731736
# EPISODE: 494 - FINAL SCORE: 164 - Temperature/epsilo: 0.019356396931272824
# EPISODE: 495 - FINAL SCORE: 116 - Temperature/epsilo: 0.019139550295562226
# EPISODE: 496 - FINAL SCORE: 132 - Temperature/epsilo: 0.018925132958216705
# EPISODE: 497 - FINAL SCORE: 117 - Temperature/epsilo: 0.018713117704193125
# EPISODE: 498 - FINAL SCORE: 112 - Temperature/epsilo: 0.018503477623334135
# EPISODE: 499 - FINAL SCORE: 128 - Temperature/epsilo: 0.018296186106952602
# EPISODE: 500 - FINAL SCORE: 134 - Temperature/epsilo: 0.018091216844454285
# EPISODE: 501 - FINAL SCORE: 125 - Temperature/epsilo: 0.01788854381999834
# EPISODE: 502 - FINAL SCORE: 127 - Temperature/epsilo: 0.01768814130919525
# EPISODE: 503 - FINAL SCORE: 180 - Temperature/epsilo: 0.017489983875841747
# EPISODE: 504 - FINAL SCORE: 225 - Temperature/epsilo: 0.017294046368692292
# EPISODE: 505 - FINAL SCORE: 162 - Temperature/epsilo: 0.017100303918266762
# EPISODE: 506 - FINAL SCORE: 118 - Temperature/epsilo: 0.01690873193369385
# EPISODE: 507 - FINAL SCORE: 121 - Temperature/epsilo: 0.01671930609958988
# EPISODE: 508 - FINAL SCORE: 160 - Temperature/epsilo: 0.016532002372972546
# EPISODE: 509 - FINAL SCORE: 125 - Temperature/epsilo: 0.016346796980209244
# EPISODE: 510 - FINAL SCORE: 113 - Temperature/epsilo: 0.0161636664139996
# EPISODE: 511 - FINAL SCORE: 136 - Temperature/epsilo: 0.01598258743039179
# EPISODE: 512 - FINAL SCORE: 147 - Temperature/epsilo: 0.01580353704583228
# EPISODE: 513 - FINAL SCORE: 149 - Temperature/epsilo: 0.015626492534248623
# EPISODE: 514 - FINAL SCORE: 153 - Temperature/epsilo: 0.01545143142416496
# EPISODE: 515 - FINAL SCORE: 122 - Temperature/epsilo: 0.015278331495849794
# EPISODE: 516 - FINAL SCORE: 148 - Temperature/epsilo: 0.015107170778495748
# EPISODE: 517 - FINAL SCORE: 142 - Temperature/epsilo: 0.014937927547430901
# EPISODE: 518 - FINAL SCORE: 243 - Temperature/epsilo: 0.014770580321361382
# EPISODE: 519 - FINAL SCORE: 180 - Temperature/epsilo: 0.01460510785964483
# EPISODE: 520 - FINAL SCORE: 158 - Temperature/epsilo: 0.01444148915959443
# EPISODE: 521 - FINAL SCORE: 133 - Temperature/epsilo: 0.01427970345381312
# EPISODE: 522 - FINAL SCORE: 136 - Temperature/epsilo: 0.014119730207557689
# EPISODE: 523 - FINAL SCORE: 140 - Temperature/epsilo: 0.013961549116132382
# EPISODE: 524 - FINAL SCORE: 185 - Temperature/epsilo: 0.013805140102311722
# EPISODE: 525 - FINAL SCORE: 266 - Temperature/epsilo: 0.0136504833137922
# EPISODE: 526 - FINAL SCORE: 381 - Temperature/epsilo: 0.0134975591206725
# EPISODE: 527 - FINAL SCORE: 93 - Temperature/epsilo: 0.013346348112961972
# EPISODE: 528 - FINAL SCORE: 185 - Temperature/epsilo: 0.013196831098117
# EPISODE: 529 - FINAL SCORE: 58 - Temperature/epsilo: 0.01304898909860498
# EPISODE: 530 - FINAL SCORE: 204 - Temperature/epsilo: 0.012902803349495591
# EPISODE: 531 - FINAL SCORE: 91 - Temperature/epsilo: 0.012758255296079041
# EPISODE: 532 - FINAL SCORE: 207 - Temperature/epsilo: 0.012615326591510996
# EPISODE: 533 - FINAL SCORE: 233 - Temperature/epsilo: 0.01247399909448391
# EPISODE: 534 - FINAL SCORE: 195 - Temperature/epsilo: 0.012334254866924403
# EPISODE: 535 - FINAL SCORE: 205 - Temperature/epsilo: 0.012196076171716495
# EPISODE: 536 - FINAL SCORE: 99 - Temperature/epsilo: 0.012059445470450285
# EPISODE: 537 - FINAL SCORE: 111 - Temperature/epsilo: 0.011924345421195888
# EPISODE: 538 - FINAL SCORE: 63 - Temperature/epsilo: 0.01179075887630231
# EPISODE: 539 - FINAL SCORE: 55 - Temperature/epsilo: 0.01165866888022095
# EPISODE: 540 - FINAL SCORE: 54 - Temperature/epsilo: 0.011528058667353533
# EPISODE: 541 - FINAL SCORE: 147 - Temperature/epsilo: 0.011398911659924106
# EPISODE: 542 - FINAL SCORE: 98 - Temperature/epsilo: 0.011271211465874906
# EPISODE: 543 - FINAL SCORE: 66 - Temperature/epsilo: 0.011144941876785788
# EPISODE: 544 - FINAL SCORE: 62 - Temperature/epsilo: 0.011020086865816955
# EPISODE: 545 - FINAL SCORE: 92 - Temperature/epsilo: 0.010896630585674746
# EPISODE: 546 - FINAL SCORE: 173 - Temperature/epsilo: 0.010774557366600218
# EPISODE: 547 - FINAL SCORE: 81 - Temperature/epsilo: 0.010653851714380238
# EPISODE: 548 - FINAL SCORE: 144 - Temperature/epsilo: 0.010534498308380876
# EPISODE: 549 - FINAL SCORE: 95 - Temperature/epsilo: 0.010416481999602838
# EPISODE: 550 - FINAL SCORE: 185 - Temperature/epsilo: 0.010299787808758646
# EPISODE: 551 - FINAL SCORE: 135 - Temperature/epsilo: 0.010184400924371402
# EPISODE: 552 - FINAL SCORE: 122 - Temperature/epsilo: 0.010070306700894831
# EPISODE: 553 - FINAL SCORE: 61 - Temperature/epsilo: 0.00995749065685438
# EPISODE: 554 - FINAL SCORE: 86 - Temperature/epsilo: 0.00984593847300915
# EPISODE: 555 - FINAL SCORE: 85 - Temperature/epsilo: 0.009735635990534421
# EPISODE: 556 - FINAL SCORE: 125 - Temperature/epsilo: 0.009626569209224537
# EPISODE: 557 - FINAL SCORE: 170 - Temperature/epsilo: 0.009518724285715919
# EPISODE: 558 - FINAL SCORE: 166 - Temperature/epsilo: 0.009412087531729982
# EPISODE: 559 - FINAL SCORE: 117 - Temperature/epsilo: 0.009306645412335755
# EPISODE: 560 - FINAL SCORE: 97 - Temperature/epsilo: 0.009202384544231942
# EPISODE: 561 - FINAL SCORE: 134 - Temperature/epsilo: 0.009099291694048241
# EPISODE: 562 - FINAL SCORE: 96 - Temperature/epsilo: 0.008997353776665702
# EPISODE: 563 - FINAL SCORE: 81 - Temperature/epsilo: 0.008896557853555866
# EPISODE: 564 - FINAL SCORE: 64 - Temperature/epsilo: 0.008796891131138563
# EPISODE: 565 - FINAL SCORE: 91 - Temperature/epsilo: 0.00869834095915806
# EPISODE: 566 - FINAL SCORE: 69 - Temperature/epsilo: 0.00860089482907743
# EPISODE: 567 - FINAL SCORE: 87 - Temperature/epsilo: 0.008504540372490892
# EPISODE: 568 - FINAL SCORE: 97 - Temperature/epsilo: 0.008409265359553948
# EPISODE: 569 - FINAL SCORE: 122 - Temperature/epsilo: 0.008315057697431107
# EPISODE: 570 - FINAL SCORE: 78 - Temperature/epsilo: 0.008221905428760985
# EPISODE: 571 - FINAL SCORE: 83 - Temperature/epsilo: 0.008129796730138616
# EPISODE: 572 - FINAL SCORE: 118 - Temperature/epsilo: 0.008038719910614764
# EPISODE: 573 - FINAL SCORE: 103 - Temperature/epsilo: 0.007948663410212031
# EPISODE: 574 - FINAL SCORE: 143 - Temperature/epsilo: 0.007859615798457613
# EPISODE: 575 - FINAL SCORE: 93 - Temperature/epsilo: 0.007771565772932466
# EPISODE: 576 - FINAL SCORE: 101 - Temperature/epsilo: 0.00768450215783676
# EPISODE: 577 - FINAL SCORE: 174 - Temperature/epsilo: 0.007598413902571364
# EPISODE: 578 - FINAL SCORE: 86 - Temperature/epsilo: 0.007513290080335254
# EPISODE: 579 - FINAL SCORE: 115 - Temperature/epsilo: 0.0074291198867386206
# EPISODE: 580 - FINAL SCORE: 140 - Temperature/epsilo: 0.007345892638431512
# EPISODE: 581 - FINAL SCORE: 138 - Temperature/epsilo: 0.0072635977717478515
# EPISODE: 582 - FINAL SCORE: 69 - Temperature/epsilo: 0.0071822248413646265
# EPISODE: 583 - FINAL SCORE: 103 - Temperature/epsilo: 0.007101763518976121
# EPISODE: 584 - FINAL SCORE: 89 - Temperature/epsilo: 0.007022203591982985
# EPISODE: 585 - FINAL SCORE: 158 - Temperature/epsilo: 0.006943534962195992
# EPISODE: 586 - FINAL SCORE: 101 - Temperature/epsilo: 0.006865747644554322
# EPISODE: 587 - FINAL SCORE: 83 - Temperature/epsilo: 0.0067888317658582106
# EPISODE: 588 - FINAL SCORE: 97 - Temperature/epsilo: 0.006712777563515772
# EPISODE: 589 - FINAL SCORE: 213 - Temperature/epsilo: 0.0066375753843038844
# EPISODE: 590 - FINAL SCORE: 65 - Temperature/epsilo: 0.006563215683142954
# EPISODE: 591 - FINAL SCORE: 94 - Temperature/epsilo: 0.0064896890218853935
# EPISODE: 592 - FINAL SCORE: 109 - Temperature/epsilo: 0.0064169860681176786
# EPISODE: 593 - FINAL SCORE: 163 - Temperature/epsilo: 0.006345097593975833
# EPISODE: 594 - FINAL SCORE: 182 - Temperature/epsilo: 0.006274014474974171
# EPISODE: 595 - FINAL SCORE: 116 - Temperature/epsilo: 0.006203727688847168
# EPISODE: 596 - FINAL SCORE: 136 - Temperature/epsilo: 0.006134228314404305
# EPISODE: 597 - FINAL SCORE: 210 - Temperature/epsilo: 0.006065507530397743
# EPISODE: 598 - FINAL SCORE: 104 - Temperature/epsilo: 0.005997556614402677
# EPISODE: 599 - FINAL SCORE: 247 - Temperature/epsilo: 0.005930366941710243
# EPISODE: 600 - FINAL SCORE: 103 - Temperature/epsilo: 0.005863929984232814
# EPISODE: 601 - FINAL SCORE: 185 - Temperature/epsilo: 0.005798237309421573
# EPISODE: 602 - FINAL SCORE: 104 - Temperature/epsilo: 0.0057332805791962095
# EPISODE: 603 - FINAL SCORE: 180 - Temperature/epsilo: 0.005669051548886596
# EPISODE: 604 - FINAL SCORE: 138 - Temperature/epsilo: 0.0056055420661863375
# EPISODE: 605 - FINAL SCORE: 107 - Temperature/epsilo: 0.005542744070118025
# EPISODE: 606 - FINAL SCORE: 91 - Temperature/epsilo: 0.005480649590010104
# EPISODE: 607 - FINAL SCORE: 184 - Temperature/epsilo: 0.005419250744485177
# EPISODE: 608 - FINAL SCORE: 129 - Temperature/epsilo: 0.005358539740459673
# EPISODE: 609 - FINAL SCORE: 208 - Temperature/epsilo: 0.005298508872154688
# EPISODE: 610 - FINAL SCORE: 104 - Temperature/epsilo: 0.0052391505201179415
# EPISODE: 611 - FINAL SCORE: 229 - Temperature/epsilo: 0.005180457150256658
# EPISODE: 612 - FINAL SCORE: 168 - Temperature/epsilo: 0.005122421312881308
# EPISODE: 613 - FINAL SCORE: 228 - Temperature/epsilo: 0.005065035641760048
# EPISODE: 614 - FINAL SCORE: 144 - Temperature/epsilo: 0.005008292853183759
# EPISODE: 615 - FINAL SCORE: 109 - Temperature/epsilo: 0.004952185745041556
# EPISODE: 616 - FINAL SCORE: 252 - Temperature/epsilo: 0.004896707195906655
# EPISODE: 617 - FINAL SCORE: 106 - Temperature/epsilo: 0.004841850164132487
# EPISODE: 618 - FINAL SCORE: 120 - Temperature/epsilo: 0.0047876076869589265
# EPISODE: 619 - FINAL SCORE: 154 - Temperature/epsilo: 0.004733972879628543
# EPISODE: 620 - FINAL SCORE: 112 - Temperature/epsilo: 0.0046809389345127475
# EPISODE: 621 - FINAL SCORE: 130 - Temperature/epsilo: 0.004628499120247733
# EPISODE: 622 - FINAL SCORE: 115 - Temperature/epsilo: 0.004576646780880088
# EPISODE: 623 - FINAL SCORE: 135 - Temperature/epsilo: 0.004525375335021991
# EPISODE: 624 - FINAL SCORE: 134 - Temperature/epsilo: 0.004474678275015859
# EPISODE: 625 - FINAL SCORE: 288 - Temperature/epsilo: 0.004424549166108363
# EPISODE: 626 - FINAL SCORE: 118 - Temperature/epsilo: 0.0043749816456336915
# EPISODE: 627 - FINAL SCORE: 142 - Temperature/epsilo: 0.004325969422205965
# EPISODE: 628 - FINAL SCORE: 126 - Temperature/epsilo: 0.004277506274920703
# EPISODE: 629 - FINAL SCORE: 222 - Temperature/epsilo: 0.004229586052565222
# EPISODE: 630 - FINAL SCORE: 142 - Temperature/epsilo: 0.004182202672837901
# EPISODE: 631 - FINAL SCORE: 257 - Temperature/epsilo: 0.004135350121576176
# EPISODE: 632 - FINAL SCORE: 169 - Temperature/epsilo: 0.004089022451993185
# EPISODE: 633 - FINAL SCORE: 176 - Temperature/epsilo: 0.004043213783922979
# EPISODE: 634 - FINAL SCORE: 191 - Temperature/epsilo: 0.0039979183030741695
# EPISODE: 635 - FINAL SCORE: 126 - Temperature/epsilo: 0.00395313026029195
# EPISODE: 636 - FINAL SCORE: 248 - Temperature/epsilo: 0.0039088439708283825
# EPISODE: 637 - FINAL SCORE: 179 - Temperature/epsilo: 0.003865053813620852
# EPISODE: 638 - FINAL SCORE: 280 - Temperature/epsilo: 0.003821754230578617
# EPISODE: 639 - FINAL SCORE: 120 - Temperature/epsilo: 0.003778939725877342
# EPISODE: 640 - FINAL SCORE: 143 - Temperature/epsilo: 0.0037366048652615366
# EPISODE: 641 - FINAL SCORE: 230 - Temperature/epsilo: 0.0036947442753548104
# EPISODE: 642 - FINAL SCORE: 211 - Temperature/epsilo: 0.0036533526429778545
# EPISODE: 643 - FINAL SCORE: 261 - Temperature/epsilo: 0.0036124247144740614
# EPISODE: 644 - FINAL SCORE: 120 - Temperature/epsilo: 0.0035719552950427037
# EPISODE: 645 - FINAL SCORE: 175 - Temperature/epsilo: 0.00353193924807958
# EPISODE: 646 - FINAL SCORE: 181 - Temperature/epsilo: 0.003492371494525049
# EPISODE: 647 - FINAL SCORE: 212 - Temperature/epsilo: 0.003453247012219366
# EPISODE: 648 - FINAL SCORE: 235 - Temperature/epsilo: 0.003414560835265244
# EPISODE: 649 - FINAL SCORE: 227 - Temperature/epsilo: 0.003376308053397552
# EPISODE: 650 - FINAL SCORE: 171 - Temperature/epsilo: 0.0033384838113600795
# EPISODE: 651 - FINAL SCORE: 251 - Temperature/epsilo: 0.0033010833082892767
# EPISODE: 652 - FINAL SCORE: 151 - Temperature/epsilo: 0.0032641017971049083
# EPISODE: 653 - FINAL SCORE: 221 - Temperature/epsilo: 0.00322753458390752
# ...
# EPISODE: 792 - FINAL SCORE: 424 - Temperature/epsilo: 0.0006741756931353079
# EPISODE: 793 - FINAL SCORE: 200 - Temperature/epsilo: 0.0006666230100893191
# EPISODE: 794 - FINAL SCORE: 152 - Temperature/epsilo: 0.0006591549385500549
# EPISODE: 795 - FINAL SCORE: 154 - Temperature/epsilo: 0.0006517705306282646
# EPISODE: 796 - FINAL SCORE: 178 - Temperature/epsilo: 0.0006444688490537507
# EPISODE: 797 - FINAL SCORE: 243 - Temperature/epsilo: 0.0006372489670564043
# EPISODE: 798 - FINAL SCORE: 219 - Temperature/epsilo: 0.0006301099682485746
# EPISODE: 799 - FINAL SCORE: 197 - Temperature/epsilo: 0.0006230509465087558
# EPISODE: 800 - FINAL SCORE: 196 - Temperature/epsilo: 0.0006160710058665775
# EPISODE: 801 - FINAL SCORE: 159 - Temperature/epsilo: 0.0006091692603890824
# EPISODE: 802 - FINAL SCORE: 203 - Temperature/epsilo: 0.0006023448340682794
# EPISODE: 803 - FINAL SCORE: 247 - Temperature/epsilo: 0.0005955968607099559
# EPISODE: 804 - FINAL SCORE: 224 - Temperature/epsilo: 0.0005889244838237345
# EPISODE: 805 - FINAL SCORE: 268 - Temperature/epsilo: 0.0005823268565143642
# EPISODE: 806 - FINAL SCORE: 282 - Temperature/epsilo: 0.0005758031413742261
# EPISODE: 807 - FINAL SCORE: 322 - Temperature/epsilo: 0.0005693525103770456
# EPISODE: 808 - FINAL SCORE: 180 - Temperature/epsilo: 0.0005629741447727953
# EPISODE: 809 - FINAL SCORE: 216 - Temperature/epsilo: 0.0005566672349837737
# EPISODE: 810 - FINAL SCORE: 287 - Temperature/epsilo: 0.0005504309805018496
# EPISODE: 811 - FINAL SCORE: 157 - Temperature/epsilo: 0.0005442645897868569
# EPISODE: 812 - FINAL SCORE: 252 - Temperature/epsilo: 0.0005381672801661285
# EPISODE: 813 - FINAL SCORE: 249 - Temperature/epsilo: 0.000532138277735154
# EPISODE: 814 - FINAL SCORE: 262 - Temperature/epsilo: 0.0005261768172593529
# EPISODE: 815 - FINAL SCORE: 167 - Temperature/epsilo: 0.0005202821420769454
# EPISODE: 816 - FINAL SCORE: 201 - Temperature/epsilo: 0.0005144535040029136
# EPISODE: 817 - FINAL SCORE: 378 - Temperature/epsilo: 0.0005086901632340371
# EPISODE: 818 - FINAL SCORE: 273 - Temperature/epsilo: 0.0005029913882549933
# EPISODE: 819 - FINAL SCORE: 290 - Temperature/epsilo: 0.0004973564557455097
# EPISODE: 820 - FINAL SCORE: 243 - Temperature/epsilo: 0.0004917846504885553
# EPISODE: 821 - FINAL SCORE: 226 - Temperature/epsilo: 0.00048627526527956203
# EPISODE: 822 - FINAL SCORE: 232 - Temperature/epsilo: 0.00048082760083666213
# EPISODE: 823 - FINAL SCORE: 245 - Temperature/epsilo: 0.00047544096571193115
# EPISODE: 824 - FINAL SCORE: 355 - Temperature/epsilo: 0.00047011467620362585
# EPISODE: 825 - FINAL SCORE: 279 - Temperature/epsilo: 0.00046484805626940495
# EPISODE: 826 - FINAL SCORE: 300 - Temperature/epsilo: 0.0004596404374405218
# EPISODE: 827 - FINAL SCORE: 192 - Temperature/epsilo: 0.000454491158736979
# EPISODE: 828 - FINAL SCORE: 157 - Temperature/epsilo: 0.0004493995665836326
# EPISODE: 829 - FINAL SCORE: 196 - Temperature/epsilo: 0.0004443650147272374
# EPISODE: 830 - FINAL SCORE: 367 - Temperature/epsilo: 0.0004393868641544202
# EPISODE: 831 - FINAL SCORE: 275 - Temperature/epsilo: 0.0004344644830105732
# EPISODE: 832 - FINAL SCORE: 276 - Temperature/epsilo: 0.00042959724651965494
# EPISODE: 833 - FINAL SCORE: 166 - Temperature/epsilo: 0.00042478453690489103
# EPISODE: 834 - FINAL SCORE: 215 - Temperature/epsilo: 0.00042002574331036154
# EPISODE: 835 - FINAL SCORE: 189 - Temperature/epsilo: 0.0004153202617234686
# EPISODE: 836 - FINAL SCORE: 197 - Temperature/epsilo: 0.00041066749489827116
# EPISODE: 837 - FINAL SCORE: 211 - Temperature/epsilo: 0.0004060668522796795
# EPISODE: 838 - FINAL SCORE: 304 - Temperature/epsilo: 0.00040151774992849875
# EPISODE: 839 - FINAL SCORE: 197 - Temperature/epsilo: 0.0003970196104473118
# EPISODE: 840 - FINAL SCORE: 272 - Temperature/epsilo: 0.00039257186290719294
# EPISODE: 841 - FINAL SCORE: 431 - Temperature/epsilo: 0.00038817394277524254
# EPISODE: 842 - FINAL SCORE: 303 - Temperature/epsilo: 0.00038382529184293314
# EPISODE: 843 - FINAL SCORE: 223 - Temperature/epsilo: 0.0003795253581552586
# EPISODE: 844 - FINAL SCORE: 200 - Temperature/epsilo: 0.00037527359594067715
# EPISODE: 845 - FINAL SCORE: 248 - Temperature/epsilo: 0.0003710694655418383
# EPISODE: 846 - FINAL SCORE: 229 - Temperature/epsilo: 0.0003669124333470874
# EPISODE: 847 - FINAL SCORE: 309 - Temperature/epsilo: 0.00036280197172273624
# EPISODE: 848 - FINAL SCORE: 391 - Temperature/epsilo: 0.00035873755894609284
# EPISODE: 849 - FINAL SCORE: 330 - Temperature/epsilo: 0.0003547186791392414
# EPISODE: 850 - FINAL SCORE: 235 - Temperature/epsilo: 0.00035074482220356457
# EPISODE: 851 - FINAL SCORE: 353 - Temperature/epsilo: 0.0003468154837549985
# EPISODE: 852 - FINAL SCORE: 272 - Temperature/epsilo: 0.00034293016506001397
# EPISODE: 853 - FINAL SCORE: 387 - Temperature/epsilo: 0.00033908837297231403
# EPISODE: 854 - FINAL SCORE: 269 - Temperature/epsilo: 0.0003352896198702411
# EPISODE: 855 - FINAL SCORE: 304 - Temperature/epsilo: 0.0003315334235948857
# EPISODE: 856 - FINAL SCORE: 303 - Temperature/epsilo: 0.0003278193073888878
# EPISODE: 857 - FINAL SCORE: 254 - Temperature/epsilo: 0.00032414679983592425
# EPISODE: 858 - FINAL SCORE: 261 - Temperature/epsilo: 0.0003205154348008741
# EPISODE: 859 - FINAL SCORE: 318 - Temperature/epsilo: 0.0003169247513706537
# EPISODE: 860 - FINAL SCORE: 287 - Temperature/epsilo: 0.00031337429379571573
# EPISODE: 861 - FINAL SCORE: 289 - Temperature/epsilo: 0.0003098636114322022
# EPISODE: 862 - FINAL SCORE: 244 - Temperature/epsilo: 0.0003063922586847469
# EPISODE: 863 - FINAL SCORE: 294 - Temperature/epsilo: 0.00030295979494991736
# EPISODE: 864 - FINAL SCORE: 279 - Temperature/epsilo: 0.00029956578456029147
# EPISODE: 865 - FINAL SCORE: 198 - Temperature/epsilo: 0.0002962097967291599
# EPISODE: 866 - FINAL SCORE: 235 - Temperature/epsilo: 0.00029289140549584804
# EPISODE: 867 - FINAL SCORE: 273 - Temperature/epsilo: 0.0002896101896716514
# EPISODE: 868 - FINAL SCORE: 285 - Temperature/epsilo: 0.00028636573278637527
# EPISODE: 869 - FINAL SCORE: 258 - Temperature/epsilo: 0.0002831576230354743
# EPISODE: 870 - FINAL SCORE: 287 - Temperature/epsilo: 0.00027998545322778404
# EPISODE: 871 - FINAL SCORE: 175 - Temperature/epsilo: 0.0002768488207338377
# EPISODE: 872 - FINAL SCORE: 284 - Temperature/epsilo: 0.00027374732743476265
# EPISODE: 873 - FINAL SCORE: 279 - Temperature/epsilo: 0.00027068057967174846
# EPISODE: 874 - FINAL SCORE: 205 - Temperature/epsilo: 0.0002676481881960817
# EPISODE: 875 - FINAL SCORE: 303 - Temperature/epsilo: 0.0002646497681197405
# EPISODE: 876 - FINAL SCORE: 209 - Temperature/epsilo: 0.00026168493886654217
# EPISODE: 877 - FINAL SCORE: 207 - Temperature/epsilo: 0.00025875332412383847
# EPISODE: 878 - FINAL SCORE: 276 - Temperature/epsilo: 0.00025585455179475195
# EPISODE: 879 - FINAL SCORE: 260 - Temperature/epsilo: 0.0002529882539509473
# EPISODE: 880 - FINAL SCORE: 253 - Temperature/epsilo: 0.00025015406678593165
# EPISODE: 881 - FINAL SCORE: 201 - Temperature/epsilo: 0.00024735163056887856
# EPISODE: 882 - FINAL SCORE: 500 - Temperature/epsilo: 0.0002445805895989688
# EPISODE: 883 - FINAL SCORE: 184 - Temperature/epsilo: 0.0002418405921602428
# EPISODE: 884 - FINAL SCORE: 264 - Temperature/epsilo: 0.00023913129047695896
# EPISODE: 885 - FINAL SCORE: 373 - Temperature/epsilo: 0.00023645234066945194
# EPISODE: 886 - FINAL SCORE: 171 - Temperature/epsilo: 0.00023380340271048566
# EPISODE: 887 - FINAL SCORE: 238 - Temperature/epsilo: 0.00023118414038209497
# EPISODE: 888 - FINAL SCORE: 186 - Temperature/epsilo: 0.00022859422123291126
# EPISODE: 889 - FINAL SCORE: 192 - Temperature/epsilo: 0.00022603331653596562
# EPISODE: 890 - FINAL SCORE: 151 - Temperature/epsilo: 0.00022350110124696502
# EPISODE: 891 - FINAL SCORE: 165 - Temperature/epsilo: 0.00022099725396303605
# EPISODE: 892 - FINAL SCORE: 169 - Temperature/epsilo: 0.0002185214568819305
# EPISODE: 893 - FINAL SCORE: 176 - Temperature/epsilo: 0.00021607339576168824
# EPISODE: 894 - FINAL SCORE: 139 - Temperature/epsilo: 0.0002136527598807518
# EPISODE: 895 - FINAL SCORE: 193 - Temperature/epsilo: 0.00021125924199852792
# EPISODE: 896 - FINAL SCORE: 209 - Temperature/epsilo: 0.00020889253831639072
# EPISODE: 897 - FINAL SCORE: 223 - Temperature/epsilo: 0.00020655234843912216
# EPISODE: 898 - FINAL SCORE: 203 - Temperature/epsilo: 0.00020423837533678393
# EPISODE: 899 - FINAL SCORE: 158 - Temperature/epsilo: 0.00020195032530701695
# EPISODE: 900 - FINAL SCORE: 203 - Temperature/epsilo: 0.00019968790793776288
# EPISODE: 901 - FINAL SCORE: 184 - Temperature/epsilo: 0.00019745083607040353
# EPISODE: 902 - FINAL SCORE: 155 - Temperature/epsilo: 0.00019523882576331293
# EPISODE: 903 - FINAL SCORE: 179 - Temperature/epsilo: 0.00019305159625581812
# EPISODE: 904 - FINAL SCORE: 154 - Temperature/epsilo: 0.00019088886993256314
# EPISODE: 905 - FINAL SCORE: 155 - Temperature/epsilo: 0.0001887503722882729
# EPISODE: 906 - FINAL SCORE: 172 - Temperature/epsilo: 0.000186635831892911
# EPISODE: 907 - FINAL SCORE: 164 - Temperature/epsilo: 0.00018454498035722875
# EPISODE: 908 - FINAL SCORE: 339 - Temperature/epsilo: 0.00018247755229869946
# EPISODE: 909 - FINAL SCORE: 205 - Temperature/epsilo: 0.00018043328530783462
# EPISODE: 910 - FINAL SCORE: 272 - Temperature/epsilo: 0.00017841191991487757
# EPISODE: 911 - FINAL SCORE: 255 - Temperature/epsilo: 0.00017641319955687002
# EPISODE: 912 - FINAL SCORE: 325 - Temperature/epsilo: 0.00017443687054508763
# EPISODE: 913 - FINAL SCORE: 286 - Temperature/epsilo: 0.00017248268203284058
# EPISODE: 914 - FINAL SCORE: 233 - Temperature/epsilo: 0.00017055038598363454
# EPISODE: 915 - FINAL SCORE: 366 - Temperature/epsilo: 0.00016863973713968859
# EPISODE: 916 - FINAL SCORE: 229 - Temperature/epsilo: 0.00016675049299080574
# EPISODE: 917 - FINAL SCORE: 204 - Temperature/epsilo: 0.00016488241374359213
# EPISODE: 918 - FINAL SCORE: 318 - Temperature/epsilo: 0.0001630352622910211
# EPISODE: 919 - FINAL SCORE: 225 - Temperature/epsilo: 0.00016120880418233848
# EPISODE: 920 - FINAL SCORE: 190 - Temperature/epsilo: 0.00015940280759330435
# EPISODE: 921 - FINAL SCORE: 189 - Temperature/epsilo: 0.0001576170432967691
# EPISODE: 922 - FINAL SCORE: 260 - Temperature/epsilo: 0.00015585128463357822
# EPISODE: 923 - FINAL SCORE: 193 - Temperature/epsilo: 0.00015410530748380378
# EPISODE: 924 - FINAL SCORE: 210 - Temperature/epsilo: 0.00015237889023829768
# EPISODE: 925 - FINAL SCORE: 122 - Temperature/epsilo: 0.00015067181377056394
# EPISODE: 926 - FINAL SCORE: 183 - Temperature/epsilo: 0.00014898386140894577
# EPISODE: 927 - FINAL SCORE: 171 - Temperature/epsilo: 0.00014731481890912452
# EPISODE: 928 - FINAL SCORE: 261 - Temperature/epsilo: 0.00014566447442692656
# EPISODE: 929 - FINAL SCORE: 191 - Temperature/epsilo: 0.00014403261849143482
# EPISODE: 930 - FINAL SCORE: 217 - Temperature/epsilo: 0.0001424190439784016
# EPISODE: 931 - FINAL SCORE: 229 - Temperature/epsilo: 0.00014082354608395924
# EPISODE: 932 - FINAL SCORE: 224 - Temperature/epsilo: 0.00013924592229862517
# EPISODE: 933 - FINAL SCORE: 182 - Temperature/epsilo: 0.00013768597238159838
# EPISODE: 934 - FINAL SCORE: 202 - Temperature/epsilo: 0.00013614349833534372
# EPISODE: 935 - FINAL SCORE: 168 - Temperature/epsilo: 0.00013461830438046084
# EPISODE: 936 - FINAL SCORE: 180 - Temperature/epsilo: 0.00013311019693083493
# EPISODE: 937 - FINAL SCORE: 160 - Temperature/epsilo: 0.00013161898456906567
# EPISODE: 938 - FINAL SCORE: 228 - Temperature/epsilo: 0.00013014447802217133
# EPISODE: 939 - FINAL SCORE: 190 - Temperature/epsilo: 0.00012868649013756533
# EPISODE: 940 - FINAL SCORE: 176 - Temperature/epsilo: 0.00012724483585930182
# EPISODE: 941 - FINAL SCORE: 192 - Temperature/epsilo: 0.00012581933220458719
# EPISODE: 942 - FINAL SCORE: 229 - Temperature/epsilo: 0.0001244097982405549
# EPISODE: 943 - FINAL SCORE: 220 - Temperature/epsilo: 0.00012301605506130067
# EPISODE: 944 - FINAL SCORE: 168 - Temperature/epsilo: 0.00012163792576517456
# EPISODE: 945 - FINAL SCORE: 158 - Temperature/epsilo: 0.0001202752354323276
# EPISODE: 946 - FINAL SCORE: 182 - Temperature/epsilo: 0.00011892781110251017
# EPISODE: 947 - FINAL SCORE: 131 - Temperature/epsilo: 0.00011759548175311874
# EPISODE: 948 - FINAL SCORE: 152 - Temperature/epsilo: 0.00011627807827748883
# EPISODE: 949 - FINAL SCORE: 147 - Temperature/epsilo: 0.000114975433463431
# EPISODE: 950 - FINAL SCORE: 192 - Temperature/epsilo: 0.00011368738197200742
# EPISODE: 951 - FINAL SCORE: 156 - Temperature/epsilo: 0.00011241376031654602
# EPISODE: 952 - FINAL SCORE: 187 - Temperature/epsilo: 0.00011115440684188994
# EPISODE: 953 - FINAL SCORE: 155 - Temperature/epsilo: 0.00010990916170387931
# EPISODE: 954 - FINAL SCORE: 153 - Temperature/epsilo: 0.000108677866849063
# EPISODE: 955 - FINAL SCORE: 173 - Temperature/epsilo: 0.0001074603659946375
# EPISODE: 956 - FINAL SCORE: 200 - Temperature/epsilo: 0.00010625650460861071
# EPISODE: 957 - FINAL SCORE: 163 - Temperature/epsilo: 0.00010506612989018784
# EPISODE: 958 - FINAL SCORE: 137 - Temperature/epsilo: 0.00010388909075037712
# EPISODE: 959 - FINAL SCORE: 173 - Temperature/epsilo: 0.00010272523779281273
# EPISODE: 960 - FINAL SCORE: 165 - Temperature/epsilo: 0.00010157442329479253
# EPISODE: 961 - FINAL SCORE: 131 - Temperature/epsilo: 0.00010043650118852831
# EPISODE: 962 - FINAL SCORE: 166 - Temperature/epsilo: 9.93113270426061e-05
# EPISODE: 963 - FINAL SCORE: 147 - Temperature/epsilo: 9.819875804365408e-05
# EPISODE: 964 - FINAL SCORE: 154 - Temperature/epsilo: 9.709865297821588e-05
# EPISODE: 965 - FINAL SCORE: 132 - Temperature/epsilo: 9.601087221482705e-05
# EPISODE: 966 - FINAL SCORE: 154 - Temperature/epsilo: 9.493527768629221e-05
# EPISODE: 967 - FINAL SCORE: 176 - Temperature/epsilo: 9.387173287216082e-05
# EPISODE: 968 - FINAL SCORE: 143 - Temperature/epsilo: 9.282010278139922e-05
# EPISODE: 969 - FINAL SCORE: 148 - Temperature/epsilo: 9.17802539352568e-05
# EPISODE: 970 - FINAL SCORE: 156 - Temperature/epsilo: 9.075205435032422e-05
# EPISODE: 971 - FINAL SCORE: 148 - Temperature/epsilo: 8.973537352178125e-05
# EPISODE: 972 - FINAL SCORE: 134 - Temperature/epsilo: 8.873008240683236e-05
# EPISODE: 973 - FINAL SCORE: 188 - Temperature/epsilo: 8.773605340832801e-05
# EPISODE: 974 - FINAL SCORE: 182 - Temperature/epsilo: 8.675316035856917e-05
# EPISODE: 975 - FINAL SCORE: 159 - Temperature/epsilo: 8.578127850329349e-05
# EPISODE: 976 - FINAL SCORE: 134 - Temperature/epsilo: 8.48202844858408e-05
# EPISODE: 977 - FINAL SCORE: 172 - Temperature/epsilo: 8.387005633149589e-05
# EPISODE: 978 - FINAL SCORE: 110 - Temperature/epsilo: 8.2930473432007e-05
# EPISODE: 979 - FINAL SCORE: 142 - Temperature/epsilo: 8.200141653027731e-05
# EPISODE: 980 - FINAL SCORE: 152 - Temperature/epsilo: 8.10827677052284e-05
# EPISODE: 981 - FINAL SCORE: 145 - Temperature/epsilo: 8.017441035683285e-05
# EPISODE: 982 - FINAL SCORE: 147 - Temperature/epsilo: 7.927622919131483e-05
# EPISODE: 983 - FINAL SCORE: 148 - Temperature/epsilo: 7.838811020651631e-05
# EPISODE: 984 - FINAL SCORE: 168 - Temperature/epsilo: 7.750994067742736e-05
# EPISODE: 985 - FINAL SCORE: 154 - Temperature/epsilo: 7.664160914187834e-05
# EPISODE: 986 - FINAL SCORE: 164 - Temperature/epsilo: 7.578300538639263e-05
# EPISODE: 987 - FINAL SCORE: 139 - Temperature/epsilo: 7.49340204321976e-05
# EPISODE: 988 - FINAL SCORE: 159 - Temperature/epsilo: 7.40945465213925e-05
# EPISODE: 989 - FINAL SCORE: 151 - Temperature/epsilo: 7.32644771032712e-05
# EPISODE: 990 - FINAL SCORE: 153 - Temperature/epsilo: 7.244370682079819e-05
# EPISODE: 991 - FINAL SCORE: 211 - Temperature/epsilo: 7.163213149723604e-05
# EPISODE: 992 - FINAL SCORE: 186 - Temperature/epsilo: 7.082964812292277e-05
# EPISODE: 993 - FINAL SCORE: 182 - Temperature/epsilo: 7.003615484219723e-05
# EPISODE: 994 - FINAL SCORE: 189 - Temperature/epsilo: 6.925155094047107e-05
# EPISODE: 995 - FINAL SCORE: 159 - Temperature/epsilo: 6.84757368314454e-05
# EPISODE: 996 - FINAL SCORE: 204 - Temperature/epsilo: 6.770861404447087e-05
# EPISODE: 997 - FINAL SCORE: 182 - Temperature/epsilo: 6.695008521204909e-05
# EPISODE: 998 - FINAL SCORE: 184 - Temperature/epsilo: 6.620005405747427e-05
# EPISODE: 999 - FINAL SCORE: 326 - Temperature/epsilo: 6.545842538261328e-05
# EPISODE: 1000 - FINAL SCORE: 269 - Temperature/epsilo: 6.472510505582251e-05

# %%
# Display the videos, not required outside Colab
if colab and show_video:
    show_videos()

# %%
#plot scores and losses
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(scores)
plt.title('Scores')
plt.subplot(1,2,2)
plt.plot(losses)
plt.title('Losses')
plt.show()

# %% [markdown]
# Adding an exploration profile makes the loss go down, however the score goes down with the loss too

# %% [markdown]
# # Final test

# %%
# Initialize the Gym environment
env = gym.make('CartPole-v1') 
env.seed(1) # Set a random seed for the environment (reproducible results)
if colab:
  env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode    
 
for i in range(10):    
    if use_epsilon_greedy:
        epsilon = tau

    # Reset the environment and get the initial state
    _ = env.reset()
    state, prev_frame = get_frame(env, None, resize=(x,y))
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False

    # Go on until the pole falls off
    episode_loss = []
    while not done:
        # Choose the action following the policy
        action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=tau)
        # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
        _, reward, done, _ = env.step(action)
        score += reward
        next_state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=True)
        state = next_state
    scores.append(score)
env.close()

print(f"AVERAGE SCORE: {np.mean(scores)}")
# Out:
# AVERAGE SCORE: 119.4920792079208

# %%
# # Initialize the Gym environment
# env = gym.make('CartPole-v1') 
# env.seed(1) # Set a random seed for the environment (reproducible results)

# # This is for creating the output video in Colab, not required outside Colab
# if colab:
#   env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode

# # Let's try for a total of 10 episodes
# scores = []
# for num_episode in range(10): 
#     # Reset the environment and get the initial state
#     _ = env.reset()
#     state, prev_frame = get_frame(env, None, resize=(x,y))
#     # Reset the score. The final score will be the total amount of steps before the pole falls
#     score = 0
#     done = False
#     # Go on until the pole falls off or the score reach 490
#     while not done:
#       # Choose the best action (temperature 0)
#       action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon=0) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=0) 
#       # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
#       _, reward, done, info = env.step(action)
#       state, prev_frame = get_frame(env, prev_frame, resize=(x,y), plot=True)
#       # # plot prev_frame in grayscale
#       # plt.imshow(prev_frame, cmap='gray')
#       # plt.show()
#       # plt.close()
#       # Update the final score (+1 for each step)
#       score += reward 
#     # Print the final score
#     #print(f"EPISODE {num_episode + 1} - FINAL SCORE: {score}") 
#     scores.append(score)  
# env.close()

# #print the average score
# print(f"AVERAGE SCORE: {np.mean(scores)}")

# %%
#let an agent play for a few episodes   
#doesn't work in colab, but works in local
if not colab:
    env = gym.make('CartPole-v1')
    #env.seed(42)

    show_render = True

    scores = []
    # Reset the environment and get the initial state
    _ = env.reset()
    state, prev_frame = get_frame(env, None, device=device, resize=(x,y))
    # Reset the score. The final score will be the total amount of steps before the pole falls
    # Go on
    for i in range(1000):
        # Choose the best action (temperature 0)
        action, q_values = choose_action_epsilon_greedy(policy_net, state, epsilon=0) if use_epsilon_greedy else choose_action_softmax(policy_net, state, temperature=0) 
        # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
        _, reward, done, info = env.step(action)
        state, prev_frame = get_frame(env, prev_frame, device=device, resize=(x,y), plot=True)

    env.close()
# Out:
# /home/irong/nn_deep_learning_2021/dl_env/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py:151: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   "You are calling 'step()' even though this "

# %%
# Display the videos, not required outside Colab
if colab: 
    show_videos()
